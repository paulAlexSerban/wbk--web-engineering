# %% [markdown]
# # Path 2: Order checkout flow (happy path)
#
# Simulates a single customer's end-to-end shopping journey:
#
# `signup -> create order -> add catalog products as line items -> read order/items -> check pending totals -> ship -> deliver -> re-check totals`
#
# Covers `POST /customers`, `POST /products`, `POST/GET /orders`, `GET /orders/pending-totals`,
# `GET /orders/:id/items`, `PATCH /orders/:id`, `POST/GET /order-items`,
# `GET /customers/:id/orders`.
#
# Run top-to-bottom (e.g. `jupyter nbconvert --to notebook --execute 02_order_checkout_flow.ipynb`).

# %%
import os

import requests
from faker import Faker

BASE_URL = os.environ.get("API_BASE_URL", "http://localhost:3002/api")
fake = Faker()


def fake_product():
    return {
        "sku": f"SKU-{fake.unique.bothify(text='???-####').upper()}",
        "name": fake.unique.catch_phrase(),
        "unit_price_cents": fake.random_int(min=199, max=9999),
    }


def create_product():
    resp = requests.post(f"{BASE_URL}/products", json=fake_product())
    assert resp.status_code == 201, resp.text
    return resp.json()


def fake_order_item(order_id, product):
    return {
        "order_id": order_id,
        "product_id": product["id"],
        "quantity": fake.random_int(min=1, max=5),
        "unit_price_cents": product["unit_price_cents"],
    }


print(f"BASE_URL={BASE_URL}")
# Out:
# BASE_URL=http://api-service:5000/api

# %% [markdown]
# ## Step 1 - A new customer signs up

# %%
resp = requests.post(
    f"{BASE_URL}/customers",
    json={"email": fake.unique.email(), "password": fake.password(length=14)},
)
assert resp.status_code == 201, resp.text
customer = resp.json()
print("Customer:", customer)
# Out:
# Customer: {'id': 553, 'email': 'fleonard@example.com', 'created_at': '2026-09-03T13:40:02.008Z'}

# %% [markdown]
# ## Step 2 - Customer places a new order (defaults to `pending`)

# %%
resp = requests.post(f"{BASE_URL}/orders", json={"customer_id": customer["id"]})
assert resp.status_code == 201, resp.text
order = resp.json()
assert order["status"] == "pending"
print("Order:", order)
# Out:
# Order: {'id': 4012, 'customer_id': 553, 'status': 'pending', 'created_at': '2026-09-03T13:40:02.176Z'}

# %% [markdown]
# ## Step 3 - Create catalog products, then add them as order line items

# %%
PRODUCT_COUNT = int(os.environ.get("PRODUCT_COUNT", "400"))

products = []
order_items = []
for _ in range(PRODUCT_COUNT):
    product = create_product()
    products.append(product)
    resp = requests.post(f"{BASE_URL}/order-items", json=fake_order_item(order["id"], product))
    assert resp.status_code == 201, resp.text
    order_items.append(resp.json())

expected_total_cents = sum(i["quantity"] * i["unit_price_cents"] for i in order_items)
print(f"Added {len(order_items)} line items from {len(products)} catalog products, expected total = {expected_total_cents} cents")
order_items
# Out:
# Added 400 line items from 400 catalog products, expected total = 6474583 cents
# [{'id': 3019,
#   'order_id': 4012,
#   'product_id': 9731,
#   'quantity': 2,
#   'unit_price_cents': 4454},
#  {'id': 3020,
#   'order_id': 4012,
#   'product_id': 9732,
#   'quantity': 1,
#   'unit_price_cents': 1475},
#  {'id': 3021,
#   'order_id': 4012,
#   'product_id': 9733,
#   'quantity': 3,
#   'unit_price_cents': 6816},
#  {'id': 3022,
#   'order_id': 4012,
#   'product_id': 9734,
#   'quantity': 1,
#   'unit_price_cents': 6458},
#  {'id': 3023,
#   'order_id': 4012,
#   'product_id': 9735,
#   'quantity': 4,
#   'unit_price_cents': 857},
#  {'id': 3024,
#   'order_id': 4012,
#   'product_id': 9736,
#   'quantity': 4,
#   'unit_price_cents': 8101},
#  {'id': 3025,
#   'order_id': 4012,
#   'product_id': 9737,
#   'quantity': 1,
#   'unit_price_cents': 8983},
#  {'id': 3026,
#   'order_id': 4012,
#   'product_id': 9738,
#   'quantity': 5,
#   'unit_price_cents': 2237},
#  {'id': 3027,
#   'order_id': 4012,
#   'product_id': 9739,
#   'quantity': 4,
#   'unit_price_cents': 8541},
#  {'id': 3028,
#   'order_id': 4012,
#   'product_id': 9740,
#   'quantity': 5,
#   'unit_price_cents': 4214},
#  {'id': 3029,
#   'order_id': 4012,
#   'product_id': 9741,
#   'quantity': 4,
#   'unit_price_cents': 4140},
#  {'id': 3030,
#   'order_id': 4012,
#   'product_id': 9742,
#   'quantity': 3,
#   'unit_price_cents': 5983},
#  {'id': 3031,
#   'order_id': 4012,
#   'product_id': 9743,
#   'quantity': 2,
#   'unit_price_cents': 4117},
#  {'id': 3032,
#   'order_id': 4012,
#   'product_id': 9744,
#   'quantity': 2,
#   'unit_price_cents': 9684},
#  {'id': 3033,
#   'order_id': 4012,
#   'product_id': 9745,
#   'quantity': 2,
#   'unit_price_cents': 1941},
#  {'id': 3034,
#   'order_id': 4012,
#   'product_id': 9746,
#   'quantity': 3,
#   'unit_price_cents': 9141},
#  {'id': 3035,
#   'order_id': 4012,
#   'product_id': 9747,
#   'quantity': 5,
#   'unit_price_cents': 8718},
#  {'id': 3036,
#   'order_id': 4012,
#   'product_id': 9748,
#   'quantity': 2,
#   'unit_price_cents': 9420},
#  {'id': 3037,
#   'order_id': 4012,
#   'product_id': 9749,
#   'quantity': 2,
#   'unit_price_cents': 1814},
#  {'id': 3038,
#   'order_id': 4012,
#   'product_id': 9750,
#   'quantity': 5,
#   'unit_price_cents': 7499},
#  {'id': 3039,
#   'order_id': 4012,
#   'product_id': 9751,
#   'quantity': 2,
#   'unit_price_cents': 1629},
#  {'id': 3040,
#   'order_id': 4012,
#   'product_id': 9752,
#   'quantity': 3,
#   'unit_price_cents': 9632},
#  {'id': 3041,
#   'order_id': 4012,
#   'product_id': 9753,
#   'quantity': 3,
#   'unit_price_cents': 7489},
#  {'id': 3042,
#   'order_id': 4012,
#   'product_id': 9754,
#   'quantity': 5,
#   'unit_price_cents': 955},
#  {'id': 3043,
#   'order_id': 4012,
#   'product_id': 9755,
#   'quantity': 4,
#   'unit_price_cents': 2331},
#  {'id': 3044,
#   'order_id': 4012,
#   'product_id': 9756,
#   'quantity': 4,
#   'unit_price_cents': 7912},
#  {'id': 3045,
#   'order_id': 4012,
#   'product_id': 9757,
#   'quantity': 4,
#   'unit_price_cents': 4229},
#  {'id': 3046,
#   'order_id': 4012,
#   'product_id': 9758,
#   'quantity': 3,
#   'unit_price_cents': 5549},
#  {'id': 3047,
#   'order_id': 4012,
#   'product_id': 9759,
#   'quantity': 4,
#   'unit_price_cents': 4642},
#  {'id': 3048,
#   'order_id': 4012,
#   'product_id': 9760,
#   'quantity': 3,
#   'unit_price_cents': 1112},
#  {'id': 3049,
#   'order_id': 4012,
#   'product_id': 9761,
#   'quantity': 4,
#   'unit_price_cents': 2084},
#  {'id': 3050,
#   'order_id': 4012,
#   'product_id': 9762,
#   'quantity': 4,
#   'unit_price_cents': 9324},
#  {'id': 3051,
#   'order_id': 4012,
#   'product_id': 9763,
#   'quantity': 4,
#   'unit_price_cents': 9303},
#  {'id': 3052,
#   'order_id': 4012,
#   'product_id': 9764,
#   'quantity': 4,
#   'unit_price_cents': 7329},
#  {'id': 3053,
#   'order_id': 4012,
#   'product_id': 9765,
#   'quantity': 1,
#   'unit_price_cents': 3884},
#  {'id': 3054,
#   'order_id': 4012,
#   'product_id': 9766,
#   'quantity': 1,
#   'unit_price_cents': 3542},
#  {'id': 3055,
#   'order_id': 4012,
#   'product_id': 9767,
#   'quantity': 4,
#   'unit_price_cents': 745},
#  {'id': 3056,
#   'order_id': 4012,
#   'product_id': 9768,
#   'quantity': 3,
#   'unit_price_cents': 5950},
#  {'id': 3057,
#   'order_id': 4012,
#   'product_id': 9769,
#   'quantity': 2,
#   'unit_price_cents': 4031},
#  {'id': 3058,
#   'order_id': 4012,
#   'product_id': 9770,
#   'quantity': 4,
#   'unit_price_cents': 518},
#  {'id': 3059,
#   'order_id': 4012,
#   'product_id': 9771,
#   'quantity': 2,
#   'unit_price_cents': 662},
#  {'id': 3060,
#   'order_id': 4012,
#   'product_id': 9772,
#   'quantity': 4,
#   'unit_price_cents': 9499},
#  {'id': 3061,
#   'order_id': 4012,
#   'product_id': 9773,
#   'quantity': 5,
#   'unit_price_cents': 2636},
#  {'id': 3062,
#   'order_id': 4012,
#   'product_id': 9774,
#   'quantity': 2,
#   'unit_price_cents': 2592},
#  {'id': 3063,
#   'order_id': 4012,
#   'product_id': 9775,
#   'quantity': 1,
#   'unit_price_cents': 7913},
#  {'id': 3064,
#   'order_id': 4012,
#   'product_id': 9776,
#   'quantity': 2,
#   'unit_price_cents': 8776},
#  {'id': 3065,
#   'order_id': 4012,
#   'product_id': 9777,
#   'quantity': 4,
#   'unit_price_cents': 4102},
#  {'id': 3066,
#   'order_id': 4012,
#   'product_id': 9778,
#   'quantity': 3,
#   'unit_price_cents': 8989},
#  {'id': 3067,
#   'order_id': 4012,
#   'product_id': 9779,
#   'quantity': 1,
#   'unit_price_cents': 3992},
#  {'id': 3068,
#   'order_id': 4012,
#   'product_id': 9780,
#   'quantity': 5,
#   'unit_price_cents': 3210},
#  {'id': 3069,
#   'order_id': 4012,
#   'product_id': 9781,
#   'quantity': 3,
#   'unit_price_cents': 5458},
#  {'id': 3070,
#   'order_id': 4012,
#   'product_id': 9782,
#   'quantity': 5,
#   'unit_price_cents': 5354},
#  {'id': 3071,
#   'order_id': 4012,
#   'product_id': 9783,
#   'quantity': 3,
#   'unit_price_cents': 1305},
#  {'id': 3072,
#   'order_id': 4012,
#   'product_id': 9784,
#   'quantity': 4,
#   'unit_price_cents': 7911},
#  {'id': 3073,
#   'order_id': 4012,
#   'product_id': 9785,
#   'quantity': 1,
#   'unit_price_cents': 7010},
#  {'id': 3074,
#   'order_id': 4012,
#   'product_id': 9786,
#   'quantity': 1,
#   'unit_price_cents': 1913},
#  {'id': 3075,
#   'order_id': 4012,
#   'product_id': 9787,
#   'quantity': 4,
#   'unit_price_cents': 7554},
#  {'id': 3076,
#   'order_id': 4012,
#   'product_id': 9788,
#   'quantity': 3,
#   'unit_price_cents': 1043},
#  {'id': 3077,
#   'order_id': 4012,
#   'product_id': 9789,
#   'quantity': 1,
#   'unit_price_cents': 471},
#  {'id': 3078,
#   'order_id': 4012,
#   'product_id': 9790,
#   'quantity': 5,
#   'unit_price_cents': 4668},
#  {'id': 3079,
#   'order_id': 4012,
#   'product_id': 9791,
#   'quantity': 4,
#   'unit_price_cents': 7720},
#  {'id': 3080,
#   'order_id': 4012,
#   'product_id': 9792,
#   'quantity': 5,
#   'unit_price_cents': 8230},
#  {'id': 3081,
#   'order_id': 4012,
#   'product_id': 9793,
#   'quantity': 3,
#   'unit_price_cents': 6306},
#  {'id': 3082,
#   'order_id': 4012,
#   'product_id': 9794,
#   'quantity': 5,
#   'unit_price_cents': 5502},
#  {'id': 3083,
#   'order_id': 4012,
#   'product_id': 9795,
#   'quantity': 2,
#   'unit_price_cents': 5443},
#  {'id': 3084,
#   'order_id': 4012,
#   'product_id': 9796,
#   'quantity': 1,
#   'unit_price_cents': 7205},
#  {'id': 3085,
#   'order_id': 4012,
#   'product_id': 9797,
#   'quantity': 1,
#   'unit_price_cents': 4079},
#  {'id': 3086,
#   'order_id': 4012,
#   'product_id': 9798,
#   'quantity': 1,
#   'unit_price_cents': 8656},
#  {'id': 3087,
#   'order_id': 4012,
#   'product_id': 9799,
#   'quantity': 4,
#   'unit_price_cents': 9514},
#  {'id': 3088,
#   'order_id': 4012,
#   'product_id': 9800,
#   'quantity': 5,
#   'unit_price_cents': 9497},
#  {'id': 3089,
#   'order_id': 4012,
#   'product_id': 9801,
#   'quantity': 3,
#   'unit_price_cents': 2836},
#  {'id': 3090,
#   'order_id': 4012,
#   'product_id': 9802,
#   'quantity': 2,
#   'unit_price_cents': 764},
#  {'id': 3091,
#   'order_id': 4012,
#   'product_id': 9803,
#   'quantity': 2,
#   'unit_price_cents': 9594},
#  {'id': 3092,
#   'order_id': 4012,
#   'product_id': 9804,
#   'quantity': 5,
#   'unit_price_cents': 1065},
#  {'id': 3093,
#   'order_id': 4012,
#   'product_id': 9805,
#   'quantity': 4,
#   'unit_price_cents': 9818},
#  {'id': 3094,
#   'order_id': 4012,
#   'product_id': 9806,
#   'quantity': 1,
#   'unit_price_cents': 7867},
#  {'id': 3095,
#   'order_id': 4012,
#   'product_id': 9807,
#   'quantity': 4,
#   'unit_price_cents': 9804},
#  {'id': 3096,
#   'order_id': 4012,
#   'product_id': 9808,
#   'quantity': 2,
#   'unit_price_cents': 8931},
#  {'id': 3097,
#   'order_id': 4012,
#   'product_id': 9809,
#   'quantity': 1,
#   'unit_price_cents': 6614},
#  {'id': 3098,
#   'order_id': 4012,
#   'product_id': 9810,
#   'quantity': 2,
#   'unit_price_cents': 2010},
#  {'id': 3099,
#   'order_id': 4012,
#   'product_id': 9811,
#   'quantity': 2,
#   'unit_price_cents': 5582},
#  {'id': 3100,
#   'order_id': 4012,
#   'product_id': 9812,
#   'quantity': 2,
#   'unit_price_cents': 7020},
#  {'id': 3101,
#   'order_id': 4012,
#   'product_id': 9813,
#   'quantity': 5,
#   'unit_price_cents': 3194},
#  {'id': 3102,
#   'order_id': 4012,
#   'product_id': 9814,
#   'quantity': 4,
#   'unit_price_cents': 2730},
#  {'id': 3103,
#   'order_id': 4012,
#   'product_id': 9815,
#   'quantity': 5,
#   'unit_price_cents': 398},
#  {'id': 3104,
#   'order_id': 4012,
#   'product_id': 9816,
#   'quantity': 1,
#   'unit_price_cents': 2799},
#  {'id': 3105,
#   'order_id': 4012,
#   'product_id': 9817,
#   'quantity': 3,
#   'unit_price_cents': 6815},
#  {'id': 3106,
#   'order_id': 4012,
#   'product_id': 9818,
#   'quantity': 3,
#   'unit_price_cents': 7960},
#  {'id': 3107,
#   'order_id': 4012,
#   'product_id': 9819,
#   'quantity': 5,
#   'unit_price_cents': 9698},
#  {'id': 3108,
#   'order_id': 4012,
#   'product_id': 9820,
#   'quantity': 5,
#   'unit_price_cents': 8215},
#  {'id': 3109,
#   'order_id': 4012,
#   'product_id': 9821,
#   'quantity': 3,
#   'unit_price_cents': 1821},
#  {'id': 3110,
#   'order_id': 4012,
#   'product_id': 9822,
#   'quantity': 5,
#   'unit_price_cents': 9141},
#  {'id': 3111,
#   'order_id': 4012,
#   'product_id': 9823,
#   'quantity': 4,
#   'unit_price_cents': 1845},
#  {'id': 3112,
#   'order_id': 4012,
#   'product_id': 9824,
#   'quantity': 1,
#   'unit_price_cents': 4205},
#  {'id': 3113,
#   'order_id': 4012,
#   'product_id': 9825,
#   'quantity': 3,
#   'unit_price_cents': 8893},
#  {'id': 3114,
#   'order_id': 4012,
#   'product_id': 9826,
#   'quantity': 1,
#   'unit_price_cents': 9553},
#  {'id': 3115,
#   'order_id': 4012,
#   'product_id': 9827,
#   'quantity': 3,
#   'unit_price_cents': 8807},
#  {'id': 3116,
#   'order_id': 4012,
#   'product_id': 9828,
#   'quantity': 1,
#   'unit_price_cents': 563},
#  {'id': 3117,
#   'order_id': 4012,
#   'product_id': 9829,
#   'quantity': 3,
#   'unit_price_cents': 8833},
#  {'id': 3118,
#   'order_id': 4012,
#   'product_id': 9830,
#   'quantity': 2,
#   'unit_price_cents': 7442},
#  {'id': 3119,
#   'order_id': 4012,
#   'product_id': 9831,
#   'quantity': 2,
#   'unit_price_cents': 7781},
#  {'id': 3120,
#   'order_id': 4012,
#   'product_id': 9832,
#   'quantity': 1,
#   'unit_price_cents': 7293},
#  {'id': 3121,
#   'order_id': 4012,
#   'product_id': 9833,
#   'quantity': 3,
#   'unit_price_cents': 3568},
#  {'id': 3122,
#   'order_id': 4012,
#   'product_id': 9834,
#   'quantity': 4,
#   'unit_price_cents': 7787},
#  {'id': 3123,
#   'order_id': 4012,
#   'product_id': 9835,
#   'quantity': 5,
#   'unit_price_cents': 5429},
#  {'id': 3124,
#   'order_id': 4012,
#   'product_id': 9836,
#   'quantity': 4,
#   'unit_price_cents': 9199},
#  {'id': 3125,
#   'order_id': 4012,
#   'product_id': 9837,
#   'quantity': 1,
#   'unit_price_cents': 7359},
#  {'id': 3126,
#   'order_id': 4012,
#   'product_id': 9838,
#   'quantity': 2,
#   'unit_price_cents': 2621},
#  {'id': 3127,
#   'order_id': 4012,
#   'product_id': 9839,
#   'quantity': 2,
#   'unit_price_cents': 3635},
#  {'id': 3128,
#   'order_id': 4012,
#   'product_id': 9840,
#   'quantity': 4,
#   'unit_price_cents': 8809},
#  {'id': 3129,
#   'order_id': 4012,
#   'product_id': 9841,
#   'quantity': 1,
#   'unit_price_cents': 2471},
#  {'id': 3130,
#   'order_id': 4012,
#   'product_id': 9842,
#   'quantity': 3,
#   'unit_price_cents': 7533},
#  {'id': 3131,
#   'order_id': 4012,
#   'product_id': 9843,
#   'quantity': 1,
#   'unit_price_cents': 5837},
#  {'id': 3132,
#   'order_id': 4012,
#   'product_id': 9844,
#   'quantity': 2,
#   'unit_price_cents': 8195},
#  {'id': 3133,
#   'order_id': 4012,
#   'product_id': 9845,
#   'quantity': 1,
#   'unit_price_cents': 5260},
#  {'id': 3134,
#   'order_id': 4012,
#   'product_id': 9846,
#   'quantity': 3,
#   'unit_price_cents': 677},
#  {'id': 3135,
#   'order_id': 4012,
#   'product_id': 9847,
#   'quantity': 1,
#   'unit_price_cents': 7796},
#  {'id': 3136,
#   'order_id': 4012,
#   'product_id': 9848,
#   'quantity': 5,
#   'unit_price_cents': 2013},
#  {'id': 3137,
#   'order_id': 4012,
#   'product_id': 9849,
#   'quantity': 1,
#   'unit_price_cents': 8990},
#  {'id': 3138,
#   'order_id': 4012,
#   'product_id': 9850,
#   'quantity': 2,
#   'unit_price_cents': 5721},
#  {'id': 3139,
#   'order_id': 4012,
#   'product_id': 9851,
#   'quantity': 4,
#   'unit_price_cents': 2845},
#  {'id': 3140,
#   'order_id': 4012,
#   'product_id': 9852,
#   'quantity': 2,
#   'unit_price_cents': 4377},
#  {'id': 3141,
#   'order_id': 4012,
#   'product_id': 9853,
#   'quantity': 1,
#   'unit_price_cents': 5075},
#  {'id': 3142,
#   'order_id': 4012,
#   'product_id': 9854,
#   'quantity': 5,
#   'unit_price_cents': 7101},
#  {'id': 3143,
#   'order_id': 4012,
#   'product_id': 9855,
#   'quantity': 5,
#   'unit_price_cents': 2651},
#  {'id': 3144,
#   'order_id': 4012,
#   'product_id': 9856,
#   'quantity': 3,
#   'unit_price_cents': 7562},
#  {'id': 3145,
#   'order_id': 4012,
#   'product_id': 9857,
#   'quantity': 2,
#   'unit_price_cents': 2454},
#  {'id': 3146,
#   'order_id': 4012,
#   'product_id': 9858,
#   'quantity': 4,
#   'unit_price_cents': 4417},
#  {'id': 3147,
#   'order_id': 4012,
#   'product_id': 9859,
#   'quantity': 3,
#   'unit_price_cents': 6050},
#  {'id': 3148,
#   'order_id': 4012,
#   'product_id': 9860,
#   'quantity': 1,
#   'unit_price_cents': 7122},
#  {'id': 3149,
#   'order_id': 4012,
#   'product_id': 9861,
#   'quantity': 4,
#   'unit_price_cents': 8965},
#  {'id': 3150,
#   'order_id': 4012,
#   'product_id': 9862,
#   'quantity': 5,
#   'unit_price_cents': 1046},
#  {'id': 3151,
#   'order_id': 4012,
#   'product_id': 9863,
#   'quantity': 2,
#   'unit_price_cents': 4123},
#  {'id': 3152,
#   'order_id': 4012,
#   'product_id': 9864,
#   'quantity': 2,
#   'unit_price_cents': 9524},
#  {'id': 3153,
#   'order_id': 4012,
#   'product_id': 9865,
#   'quantity': 3,
#   'unit_price_cents': 2147},
#  {'id': 3154,
#   'order_id': 4012,
#   'product_id': 9866,
#   'quantity': 5,
#   'unit_price_cents': 4257},
#  {'id': 3155,
#   'order_id': 4012,
#   'product_id': 9867,
#   'quantity': 1,
#   'unit_price_cents': 7260},
#  {'id': 3156,
#   'order_id': 4012,
#   'product_id': 9868,
#   'quantity': 4,
#   'unit_price_cents': 8618},
#  {'id': 3157,
#   'order_id': 4012,
#   'product_id': 9869,
#   'quantity': 3,
#   'unit_price_cents': 291},
#  {'id': 3158,
#   'order_id': 4012,
#   'product_id': 9870,
#   'quantity': 2,
#   'unit_price_cents': 900},
#  {'id': 3159,
#   'order_id': 4012,
#   'product_id': 9871,
#   'quantity': 1,
#   'unit_price_cents': 2380},
#  {'id': 3160,
#   'order_id': 4012,
#   'product_id': 9872,
#   'quantity': 3,
#   'unit_price_cents': 2463},
#  {'id': 3161,
#   'order_id': 4012,
#   'product_id': 9873,
#   'quantity': 3,
#   'unit_price_cents': 4629},
#  {'id': 3162,
#   'order_id': 4012,
#   'product_id': 9874,
#   'quantity': 4,
#   'unit_price_cents': 8230},
#  {'id': 3163,
#   'order_id': 4012,
#   'product_id': 9875,
#   'quantity': 4,
#   'unit_price_cents': 9989},
#  {'id': 3164,
#   'order_id': 4012,
#   'product_id': 9876,
#   'quantity': 4,
#   'unit_price_cents': 9103},
#  {'id': 3165,
#   'order_id': 4012,
#   'product_id': 9877,
#   'quantity': 4,
#   'unit_price_cents': 2347},
#  {'id': 3166,
#   'order_id': 4012,
#   'product_id': 9878,
#   'quantity': 2,
#   'unit_price_cents': 8701},
#  {'id': 3167,
#   'order_id': 4012,
#   'product_id': 9879,
#   'quantity': 1,
#   'unit_price_cents': 7651},
#  {'id': 3168,
#   'order_id': 4012,
#   'product_id': 9880,
#   'quantity': 4,
#   'unit_price_cents': 9791},
#  {'id': 3169,
#   'order_id': 4012,
#   'product_id': 9881,
#   'quantity': 3,
#   'unit_price_cents': 4935},
#  {'id': 3170,
#   'order_id': 4012,
#   'product_id': 9882,
#   'quantity': 3,
#   'unit_price_cents': 5970},
#  {'id': 3171,
#   'order_id': 4012,
#   'product_id': 9883,
#   'quantity': 2,
#   'unit_price_cents': 7976},
#  {'id': 3172,
#   'order_id': 4012,
#   'product_id': 9884,
#   'quantity': 3,
#   'unit_price_cents': 838},
#  {'id': 3173,
#   'order_id': 4012,
#   'product_id': 9885,
#   'quantity': 4,
#   'unit_price_cents': 8445},
#  {'id': 3174,
#   'order_id': 4012,
#   'product_id': 9886,
#   'quantity': 5,
#   'unit_price_cents': 9874},
#  {'id': 3175,
#   'order_id': 4012,
#   'product_id': 9887,
#   'quantity': 4,
#   'unit_price_cents': 480},
#  {'id': 3176,
#   'order_id': 4012,
#   'product_id': 9888,
#   'quantity': 5,
#   'unit_price_cents': 6941},
#  {'id': 3177,
#   'order_id': 4012,
#   'product_id': 9889,
#   'quantity': 3,
#   'unit_price_cents': 6139},
#  {'id': 3178,
#   'order_id': 4012,
#   'product_id': 9890,
#   'quantity': 2,
#   'unit_price_cents': 3443},
#  {'id': 3179,
#   'order_id': 4012,
#   'product_id': 9891,
#   'quantity': 4,
#   'unit_price_cents': 4378},
#  {'id': 3180,
#   'order_id': 4012,
#   'product_id': 9892,
#   'quantity': 2,
#   'unit_price_cents': 6522},
#  {'id': 3181,
#   'order_id': 4012,
#   'product_id': 9893,
#   'quantity': 4,
#   'unit_price_cents': 2803},
#  {'id': 3182,
#   'order_id': 4012,
#   'product_id': 9894,
#   'quantity': 3,
#   'unit_price_cents': 3280},
#  {'id': 3183,
#   'order_id': 4012,
#   'product_id': 9895,
#   'quantity': 1,
#   'unit_price_cents': 8683},
#  {'id': 3184,
#   'order_id': 4012,
#   'product_id': 9896,
#   'quantity': 1,
#   'unit_price_cents': 5282},
#  {'id': 3185,
#   'order_id': 4012,
#   'product_id': 9897,
#   'quantity': 1,
#   'unit_price_cents': 2012},
#  {'id': 3186,
#   'order_id': 4012,
#   'product_id': 9898,
#   'quantity': 3,
#   'unit_price_cents': 8045},
#  {'id': 3187,
#   'order_id': 4012,
#   'product_id': 9899,
#   'quantity': 5,
#   'unit_price_cents': 8763},
#  {'id': 3188,
#   'order_id': 4012,
#   'product_id': 9900,
#   'quantity': 5,
#   'unit_price_cents': 6513},
#  {'id': 3189,
#   'order_id': 4012,
#   'product_id': 9901,
#   'quantity': 2,
#   'unit_price_cents': 6112},
#  {'id': 3190,
#   'order_id': 4012,
#   'product_id': 9902,
#   'quantity': 3,
#   'unit_price_cents': 2331},
#  {'id': 3191,
#   'order_id': 4012,
#   'product_id': 9903,
#   'quantity': 5,
#   'unit_price_cents': 2989},
#  {'id': 3192,
#   'order_id': 4012,
#   'product_id': 9904,
#   'quantity': 1,
#   'unit_price_cents': 922},
#  {'id': 3193,
#   'order_id': 4012,
#   'product_id': 9905,
#   'quantity': 5,
#   'unit_price_cents': 6119},
#  {'id': 3194,
#   'order_id': 4012,
#   'product_id': 9906,
#   'quantity': 5,
#   'unit_price_cents': 2818},
#  {'id': 3195,
#   'order_id': 4012,
#   'product_id': 9907,
#   'quantity': 5,
#   'unit_price_cents': 2357},
#  {'id': 3196,
#   'order_id': 4012,
#   'product_id': 9908,
#   'quantity': 1,
#   'unit_price_cents': 1792},
#  {'id': 3197,
#   'order_id': 4012,
#   'product_id': 9909,
#   'quantity': 4,
#   'unit_price_cents': 6014},
#  {'id': 3198,
#   'order_id': 4012,
#   'product_id': 9910,
#   'quantity': 5,
#   'unit_price_cents': 3863},
#  {'id': 3199,
#   'order_id': 4012,
#   'product_id': 9911,
#   'quantity': 4,
#   'unit_price_cents': 9138},
#  {'id': 3200,
#   'order_id': 4012,
#   'product_id': 9912,
#   'quantity': 1,
#   'unit_price_cents': 4256},
#  {'id': 3201,
#   'order_id': 4012,
#   'product_id': 9913,
#   'quantity': 1,
#   'unit_price_cents': 8479},
#  {'id': 3202,
#   'order_id': 4012,
#   'product_id': 9914,
#   'quantity': 2,
#   'unit_price_cents': 8953},
#  {'id': 3203,
#   'order_id': 4012,
#   'product_id': 9915,
#   'quantity': 5,
#   'unit_price_cents': 7502},
#  {'id': 3204,
#   'order_id': 4012,
#   'product_id': 9916,
#   'quantity': 2,
#   'unit_price_cents': 7264},
#  {'id': 3205,
#   'order_id': 4012,
#   'product_id': 9917,
#   'quantity': 3,
#   'unit_price_cents': 9967},
#  {'id': 3206,
#   'order_id': 4012,
#   'product_id': 9918,
#   'quantity': 3,
#   'unit_price_cents': 2151},
#  {'id': 3207,
#   'order_id': 4012,
#   'product_id': 9919,
#   'quantity': 2,
#   'unit_price_cents': 1946},
#  {'id': 3208,
#   'order_id': 4012,
#   'product_id': 9920,
#   'quantity': 3,
#   'unit_price_cents': 4502},
#  {'id': 3209,
#   'order_id': 4012,
#   'product_id': 9921,
#   'quantity': 3,
#   'unit_price_cents': 9454},
#  {'id': 3210,
#   'order_id': 4012,
#   'product_id': 9922,
#   'quantity': 4,
#   'unit_price_cents': 4164},
#  {'id': 3211,
#   'order_id': 4012,
#   'product_id': 9923,
#   'quantity': 5,
#   'unit_price_cents': 7157},
#  {'id': 3212,
#   'order_id': 4012,
#   'product_id': 9924,
#   'quantity': 3,
#   'unit_price_cents': 2876},
#  {'id': 3213,
#   'order_id': 4012,
#   'product_id': 9925,
#   'quantity': 5,
#   'unit_price_cents': 7404},
#  {'id': 3214,
#   'order_id': 4012,
#   'product_id': 9926,
#   'quantity': 3,
#   'unit_price_cents': 545},
#  {'id': 3215,
#   'order_id': 4012,
#   'product_id': 9927,
#   'quantity': 5,
#   'unit_price_cents': 9020},
#  {'id': 3216,
#   'order_id': 4012,
#   'product_id': 9928,
#   'quantity': 1,
#   'unit_price_cents': 9612},
#  {'id': 3217,
#   'order_id': 4012,
#   'product_id': 9929,
#   'quantity': 5,
#   'unit_price_cents': 7258},
#  {'id': 3218,
#   'order_id': 4012,
#   'product_id': 9930,
#   'quantity': 3,
#   'unit_price_cents': 7537},
#  {'id': 3219,
#   'order_id': 4012,
#   'product_id': 9931,
#   'quantity': 2,
#   'unit_price_cents': 4908},
#  {'id': 3220,
#   'order_id': 4012,
#   'product_id': 9932,
#   'quantity': 3,
#   'unit_price_cents': 3865},
#  {'id': 3221,
#   'order_id': 4012,
#   'product_id': 9933,
#   'quantity': 1,
#   'unit_price_cents': 1712},
#  {'id': 3222,
#   'order_id': 4012,
#   'product_id': 9934,
#   'quantity': 4,
#   'unit_price_cents': 5896},
#  {'id': 3223,
#   'order_id': 4012,
#   'product_id': 9935,
#   'quantity': 3,
#   'unit_price_cents': 4896},
#  {'id': 3224,
#   'order_id': 4012,
#   'product_id': 9936,
#   'quantity': 3,
#   'unit_price_cents': 3336},
#  {'id': 3225,
#   'order_id': 4012,
#   'product_id': 9937,
#   'quantity': 5,
#   'unit_price_cents': 6220},
#  {'id': 3226,
#   'order_id': 4012,
#   'product_id': 9938,
#   'quantity': 2,
#   'unit_price_cents': 1325},
#  {'id': 3227,
#   'order_id': 4012,
#   'product_id': 9939,
#   'quantity': 5,
#   'unit_price_cents': 5010},
#  {'id': 3228,
#   'order_id': 4012,
#   'product_id': 9940,
#   'quantity': 4,
#   'unit_price_cents': 9433},
#  {'id': 3229,
#   'order_id': 4012,
#   'product_id': 9941,
#   'quantity': 2,
#   'unit_price_cents': 9548},
#  {'id': 3230,
#   'order_id': 4012,
#   'product_id': 9942,
#   'quantity': 1,
#   'unit_price_cents': 5034},
#  {'id': 3231,
#   'order_id': 4012,
#   'product_id': 9943,
#   'quantity': 3,
#   'unit_price_cents': 6292},
#  {'id': 3232,
#   'order_id': 4012,
#   'product_id': 9944,
#   'quantity': 4,
#   'unit_price_cents': 3912},
#  {'id': 3233,
#   'order_id': 4012,
#   'product_id': 9945,
#   'quantity': 3,
#   'unit_price_cents': 5353},
#  {'id': 3234,
#   'order_id': 4012,
#   'product_id': 9946,
#   'quantity': 4,
#   'unit_price_cents': 2808},
#  {'id': 3235,
#   'order_id': 4012,
#   'product_id': 9947,
#   'quantity': 5,
#   'unit_price_cents': 1557},
#  {'id': 3236,
#   'order_id': 4012,
#   'product_id': 9948,
#   'quantity': 1,
#   'unit_price_cents': 4985},
#  {'id': 3237,
#   'order_id': 4012,
#   'product_id': 9949,
#   'quantity': 2,
#   'unit_price_cents': 7572},
#  {'id': 3238,
#   'order_id': 4012,
#   'product_id': 9950,
#   'quantity': 2,
#   'unit_price_cents': 3281},
#  {'id': 3239,
#   'order_id': 4012,
#   'product_id': 9951,
#   'quantity': 3,
#   'unit_price_cents': 1077},
#  {'id': 3240,
#   'order_id': 4012,
#   'product_id': 9952,
#   'quantity': 1,
#   'unit_price_cents': 1552},
#  {'id': 3241,
#   'order_id': 4012,
#   'product_id': 9953,
#   'quantity': 5,
#   'unit_price_cents': 3800},
#  {'id': 3242,
#   'order_id': 4012,
#   'product_id': 9954,
#   'quantity': 2,
#   'unit_price_cents': 6074},
#  {'id': 3243,
#   'order_id': 4012,
#   'product_id': 9955,
#   'quantity': 5,
#   'unit_price_cents': 5548},
#  {'id': 3244,
#   'order_id': 4012,
#   'product_id': 9956,
#   'quantity': 1,
#   'unit_price_cents': 7180},
#  {'id': 3245,
#   'order_id': 4012,
#   'product_id': 9957,
#   'quantity': 4,
#   'unit_price_cents': 3954},
#  {'id': 3246,
#   'order_id': 4012,
#   'product_id': 9958,
#   'quantity': 4,
#   'unit_price_cents': 6919},
#  {'id': 3247,
#   'order_id': 4012,
#   'product_id': 9959,
#   'quantity': 3,
#   'unit_price_cents': 4404},
#  {'id': 3248,
#   'order_id': 4012,
#   'product_id': 9960,
#   'quantity': 2,
#   'unit_price_cents': 6279},
#  {'id': 3249,
#   'order_id': 4012,
#   'product_id': 9961,
#   'quantity': 5,
#   'unit_price_cents': 7470},
#  {'id': 3250,
#   'order_id': 4012,
#   'product_id': 9962,
#   'quantity': 5,
#   'unit_price_cents': 5568},
#  {'id': 3251,
#   'order_id': 4012,
#   'product_id': 9963,
#   'quantity': 1,
#   'unit_price_cents': 5855},
#  {'id': 3252,
#   'order_id': 4012,
#   'product_id': 9964,
#   'quantity': 3,
#   'unit_price_cents': 3548},
#  {'id': 3253,
#   'order_id': 4012,
#   'product_id': 9965,
#   'quantity': 4,
#   'unit_price_cents': 9888},
#  {'id': 3254,
#   'order_id': 4012,
#   'product_id': 9966,
#   'quantity': 4,
#   'unit_price_cents': 5218},
#  {'id': 3255,
#   'order_id': 4012,
#   'product_id': 9967,
#   'quantity': 1,
#   'unit_price_cents': 1636},
#  {'id': 3256,
#   'order_id': 4012,
#   'product_id': 9968,
#   'quantity': 4,
#   'unit_price_cents': 6416},
#  {'id': 3257,
#   'order_id': 4012,
#   'product_id': 9969,
#   'quantity': 1,
#   'unit_price_cents': 9028},
#  {'id': 3258,
#   'order_id': 4012,
#   'product_id': 9970,
#   'quantity': 3,
#   'unit_price_cents': 5268},
#  {'id': 3259,
#   'order_id': 4012,
#   'product_id': 9971,
#   'quantity': 5,
#   'unit_price_cents': 2347},
#  {'id': 3260,
#   'order_id': 4012,
#   'product_id': 9972,
#   'quantity': 5,
#   'unit_price_cents': 4896},
#  {'id': 3261,
#   'order_id': 4012,
#   'product_id': 9973,
#   'quantity': 4,
#   'unit_price_cents': 6944},
#  {'id': 3262,
#   'order_id': 4012,
#   'product_id': 9974,
#   'quantity': 1,
#   'unit_price_cents': 6531},
#  {'id': 3263,
#   'order_id': 4012,
#   'product_id': 9975,
#   'quantity': 4,
#   'unit_price_cents': 6941},
#  {'id': 3264,
#   'order_id': 4012,
#   'product_id': 9976,
#   'quantity': 5,
#   'unit_price_cents': 6543},
#  {'id': 3265,
#   'order_id': 4012,
#   'product_id': 9977,
#   'quantity': 1,
#   'unit_price_cents': 7957},
#  {'id': 3266,
#   'order_id': 4012,
#   'product_id': 9978,
#   'quantity': 2,
#   'unit_price_cents': 6892},
#  {'id': 3267,
#   'order_id': 4012,
#   'product_id': 9979,
#   'quantity': 1,
#   'unit_price_cents': 1220},
#  {'id': 3268,
#   'order_id': 4012,
#   'product_id': 9980,
#   'quantity': 1,
#   'unit_price_cents': 8117},
#  {'id': 3269,
#   'order_id': 4012,
#   'product_id': 9981,
#   'quantity': 4,
#   'unit_price_cents': 3636},
#  {'id': 3270,
#   'order_id': 4012,
#   'product_id': 9982,
#   'quantity': 4,
#   'unit_price_cents': 7804},
#  {'id': 3271,
#   'order_id': 4012,
#   'product_id': 9983,
#   'quantity': 3,
#   'unit_price_cents': 3634},
#  {'id': 3272,
#   'order_id': 4012,
#   'product_id': 9984,
#   'quantity': 3,
#   'unit_price_cents': 8975},
#  {'id': 3273,
#   'order_id': 4012,
#   'product_id': 9985,
#   'quantity': 2,
#   'unit_price_cents': 4383},
#  {'id': 3274,
#   'order_id': 4012,
#   'product_id': 9986,
#   'quantity': 5,
#   'unit_price_cents': 1495},
#  {'id': 3275,
#   'order_id': 4012,
#   'product_id': 9987,
#   'quantity': 3,
#   'unit_price_cents': 1921},
#  {'id': 3276,
#   'order_id': 4012,
#   'product_id': 9988,
#   'quantity': 1,
#   'unit_price_cents': 8726},
#  {'id': 3277,
#   'order_id': 4012,
#   'product_id': 9989,
#   'quantity': 4,
#   'unit_price_cents': 655},
#  {'id': 3278,
#   'order_id': 4012,
#   'product_id': 9990,
#   'quantity': 1,
#   'unit_price_cents': 6332},
#  {'id': 3279,
#   'order_id': 4012,
#   'product_id': 9991,
#   'quantity': 5,
#   'unit_price_cents': 9597},
#  {'id': 3280,
#   'order_id': 4012,
#   'product_id': 9992,
#   'quantity': 1,
#   'unit_price_cents': 1085},
#  {'id': 3281,
#   'order_id': 4012,
#   'product_id': 9993,
#   'quantity': 2,
#   'unit_price_cents': 5896},
#  {'id': 3282,
#   'order_id': 4012,
#   'product_id': 9994,
#   'quantity': 1,
#   'unit_price_cents': 1424},
#  {'id': 3283,
#   'order_id': 4012,
#   'product_id': 9995,
#   'quantity': 5,
#   'unit_price_cents': 5601},
#  {'id': 3284,
#   'order_id': 4012,
#   'product_id': 9996,
#   'quantity': 2,
#   'unit_price_cents': 2974},
#  {'id': 3285,
#   'order_id': 4012,
#   'product_id': 9997,
#   'quantity': 2,
#   'unit_price_cents': 4967},
#  {'id': 3286,
#   'order_id': 4012,
#   'product_id': 9998,
#   'quantity': 4,
#   'unit_price_cents': 6817},
#  {'id': 3287,
#   'order_id': 4012,
#   'product_id': 9999,
#   'quantity': 3,
#   'unit_price_cents': 546},
#  {'id': 3288,
#   'order_id': 4012,
#   'product_id': 10000,
#   'quantity': 1,
#   'unit_price_cents': 7123},
#  {'id': 3289,
#   'order_id': 4012,
#   'product_id': 10001,
#   'quantity': 1,
#   'unit_price_cents': 4297},
#  {'id': 3290,
#   'order_id': 4012,
#   'product_id': 10002,
#   'quantity': 4,
#   'unit_price_cents': 3680},
#  {'id': 3291,
#   'order_id': 4012,
#   'product_id': 10003,
#   'quantity': 5,
#   'unit_price_cents': 4856},
#  {'id': 3292,
#   'order_id': 4012,
#   'product_id': 10004,
#   'quantity': 1,
#   'unit_price_cents': 9708},
#  {'id': 3293,
#   'order_id': 4012,
#   'product_id': 10005,
#   'quantity': 3,
#   'unit_price_cents': 6193},
#  {'id': 3294,
#   'order_id': 4012,
#   'product_id': 10006,
#   'quantity': 2,
#   'unit_price_cents': 7221},
#  {'id': 3295,
#   'order_id': 4012,
#   'product_id': 10007,
#   'quantity': 3,
#   'unit_price_cents': 9949},
#  {'id': 3296,
#   'order_id': 4012,
#   'product_id': 10008,
#   'quantity': 3,
#   'unit_price_cents': 1205},
#  {'id': 3297,
#   'order_id': 4012,
#   'product_id': 10009,
#   'quantity': 5,
#   'unit_price_cents': 7507},
#  {'id': 3298,
#   'order_id': 4012,
#   'product_id': 10010,
#   'quantity': 5,
#   'unit_price_cents': 7311},
#  {'id': 3299,
#   'order_id': 4012,
#   'product_id': 10011,
#   'quantity': 2,
#   'unit_price_cents': 1919},
#  {'id': 3300,
#   'order_id': 4012,
#   'product_id': 10012,
#   'quantity': 2,
#   'unit_price_cents': 7721},
#  {'id': 3301,
#   'order_id': 4012,
#   'product_id': 10013,
#   'quantity': 4,
#   'unit_price_cents': 4830},
#  {'id': 3302,
#   'order_id': 4012,
#   'product_id': 10014,
#   'quantity': 4,
#   'unit_price_cents': 6636},
#  {'id': 3303,
#   'order_id': 4012,
#   'product_id': 10015,
#   'quantity': 4,
#   'unit_price_cents': 1406},
#  {'id': 3304,
#   'order_id': 4012,
#   'product_id': 10016,
#   'quantity': 4,
#   'unit_price_cents': 7490},
#  {'id': 3305,
#   'order_id': 4012,
#   'product_id': 10017,
#   'quantity': 1,
#   'unit_price_cents': 1668},
#  {'id': 3306,
#   'order_id': 4012,
#   'product_id': 10018,
#   'quantity': 4,
#   'unit_price_cents': 5541},
#  {'id': 3307,
#   'order_id': 4012,
#   'product_id': 10019,
#   'quantity': 3,
#   'unit_price_cents': 2805},
#  {'id': 3308,
#   'order_id': 4012,
#   'product_id': 10020,
#   'quantity': 4,
#   'unit_price_cents': 9702},
#  {'id': 3309,
#   'order_id': 4012,
#   'product_id': 10021,
#   'quantity': 3,
#   'unit_price_cents': 8498},
#  {'id': 3310,
#   'order_id': 4012,
#   'product_id': 10022,
#   'quantity': 5,
#   'unit_price_cents': 4381},
#  {'id': 3311,
#   'order_id': 4012,
#   'product_id': 10023,
#   'quantity': 1,
#   'unit_price_cents': 5280},
#  {'id': 3312,
#   'order_id': 4012,
#   'product_id': 10024,
#   'quantity': 5,
#   'unit_price_cents': 787},
#  {'id': 3313,
#   'order_id': 4012,
#   'product_id': 10025,
#   'quantity': 1,
#   'unit_price_cents': 7978},
#  {'id': 3314,
#   'order_id': 4012,
#   'product_id': 10026,
#   'quantity': 1,
#   'unit_price_cents': 3451},
#  {'id': 3315,
#   'order_id': 4012,
#   'product_id': 10027,
#   'quantity': 2,
#   'unit_price_cents': 5629},
#  {'id': 3316,
#   'order_id': 4012,
#   'product_id': 10028,
#   'quantity': 5,
#   'unit_price_cents': 7404},
#  {'id': 3317,
#   'order_id': 4012,
#   'product_id': 10029,
#   'quantity': 5,
#   'unit_price_cents': 2997},
#  {'id': 3318,
#   'order_id': 4012,
#   'product_id': 10030,
#   'quantity': 2,
#   'unit_price_cents': 3185},
#  {'id': 3319,
#   'order_id': 4012,
#   'product_id': 10031,
#   'quantity': 5,
#   'unit_price_cents': 1854},
#  {'id': 3320,
#   'order_id': 4012,
#   'product_id': 10032,
#   'quantity': 5,
#   'unit_price_cents': 8676},
#  {'id': 3321,
#   'order_id': 4012,
#   'product_id': 10033,
#   'quantity': 1,
#   'unit_price_cents': 6336},
#  {'id': 3322,
#   'order_id': 4012,
#   'product_id': 10034,
#   'quantity': 4,
#   'unit_price_cents': 3615},
#  {'id': 3323,
#   'order_id': 4012,
#   'product_id': 10035,
#   'quantity': 1,
#   'unit_price_cents': 9549},
#  {'id': 3324,
#   'order_id': 4012,
#   'product_id': 10036,
#   'quantity': 4,
#   'unit_price_cents': 5715},
#  {'id': 3325,
#   'order_id': 4012,
#   'product_id': 10037,
#   'quantity': 1,
#   'unit_price_cents': 2460},
#  {'id': 3326,
#   'order_id': 4012,
#   'product_id': 10038,
#   'quantity': 4,
#   'unit_price_cents': 3890},
#  {'id': 3327,
#   'order_id': 4012,
#   'product_id': 10039,
#   'quantity': 1,
#   'unit_price_cents': 3763},
#  {'id': 3328,
#   'order_id': 4012,
#   'product_id': 10040,
#   'quantity': 3,
#   'unit_price_cents': 8250},
#  {'id': 3329,
#   'order_id': 4012,
#   'product_id': 10041,
#   'quantity': 2,
#   'unit_price_cents': 7780},
#  {'id': 3330,
#   'order_id': 4012,
#   'product_id': 10042,
#   'quantity': 4,
#   'unit_price_cents': 8841},
#  {'id': 3331,
#   'order_id': 4012,
#   'product_id': 10043,
#   'quantity': 5,
#   'unit_price_cents': 2772},
#  {'id': 3332,
#   'order_id': 4012,
#   'product_id': 10044,
#   'quantity': 4,
#   'unit_price_cents': 3345},
#  {'id': 3333,
#   'order_id': 4012,
#   'product_id': 10045,
#   'quantity': 3,
#   'unit_price_cents': 1080},
#  {'id': 3334,
#   'order_id': 4012,
#   'product_id': 10046,
#   'quantity': 4,
#   'unit_price_cents': 8125},
#  {'id': 3335,
#   'order_id': 4012,
#   'product_id': 10047,
#   'quantity': 4,
#   'unit_price_cents': 8150},
#  {'id': 3336,
#   'order_id': 4012,
#   'product_id': 10048,
#   'quantity': 5,
#   'unit_price_cents': 8422},
#  {'id': 3337,
#   'order_id': 4012,
#   'product_id': 10049,
#   'quantity': 1,
#   'unit_price_cents': 9192},
#  {'id': 3338,
#   'order_id': 4012,
#   'product_id': 10050,
#   'quantity': 5,
#   'unit_price_cents': 321},
#  {'id': 3339,
#   'order_id': 4012,
#   'product_id': 10051,
#   'quantity': 2,
#   'unit_price_cents': 3652},
#  {'id': 3340,
#   'order_id': 4012,
#   'product_id': 10052,
#   'quantity': 5,
#   'unit_price_cents': 9734},
#  {'id': 3341,
#   'order_id': 4012,
#   'product_id': 10053,
#   'quantity': 2,
#   'unit_price_cents': 2820},
#  {'id': 3342,
#   'order_id': 4012,
#   'product_id': 10054,
#   'quantity': 2,
#   'unit_price_cents': 8876},
#  {'id': 3343,
#   'order_id': 4012,
#   'product_id': 10055,
#   'quantity': 1,
#   'unit_price_cents': 2931},
#  {'id': 3344,
#   'order_id': 4012,
#   'product_id': 10056,
#   'quantity': 4,
#   'unit_price_cents': 4479},
#  {'id': 3345,
#   'order_id': 4012,
#   'product_id': 10057,
#   'quantity': 3,
#   'unit_price_cents': 8433},
#  {'id': 3346,
#   'order_id': 4012,
#   'product_id': 10058,
#   'quantity': 3,
#   'unit_price_cents': 5477},
#  {'id': 3347,
#   'order_id': 4012,
#   'product_id': 10059,
#   'quantity': 1,
#   'unit_price_cents': 764},
#  {'id': 3348,
#   'order_id': 4012,
#   'product_id': 10060,
#   'quantity': 1,
#   'unit_price_cents': 9866},
#  {'id': 3349,
#   'order_id': 4012,
#   'product_id': 10061,
#   'quantity': 1,
#   'unit_price_cents': 7250},
#  {'id': 3350,
#   'order_id': 4012,
#   'product_id': 10062,
#   'quantity': 2,
#   'unit_price_cents': 8056},
#  {'id': 3351,
#   'order_id': 4012,
#   'product_id': 10063,
#   'quantity': 5,
#   'unit_price_cents': 1675},
#  {'id': 3352,
#   'order_id': 4012,
#   'product_id': 10064,
#   'quantity': 3,
#   'unit_price_cents': 4413},
#  {'id': 3353,
#   'order_id': 4012,
#   'product_id': 10065,
#   'quantity': 4,
#   'unit_price_cents': 1528},
#  {'id': 3354,
#   'order_id': 4012,
#   'product_id': 10066,
#   'quantity': 3,
#   'unit_price_cents': 1495},
#  {'id': 3355,
#   'order_id': 4012,
#   'product_id': 10067,
#   'quantity': 3,
#   'unit_price_cents': 9648},
#  {'id': 3356,
#   'order_id': 4012,
#   'product_id': 10068,
#   'quantity': 4,
#   'unit_price_cents': 2360},
#  {'id': 3357,
#   'order_id': 4012,
#   'product_id': 10069,
#   'quantity': 2,
#   'unit_price_cents': 4675},
#  {'id': 3358,
#   'order_id': 4012,
#   'product_id': 10070,
#   'quantity': 5,
#   'unit_price_cents': 3779},
#  {'id': 3359,
#   'order_id': 4012,
#   'product_id': 10071,
#   'quantity': 3,
#   'unit_price_cents': 1149},
#  {'id': 3360,
#   'order_id': 4012,
#   'product_id': 10072,
#   'quantity': 1,
#   'unit_price_cents': 4126},
#  {'id': 3361,
#   'order_id': 4012,
#   'product_id': 10073,
#   'quantity': 1,
#   'unit_price_cents': 3693},
#  {'id': 3362,
#   'order_id': 4012,
#   'product_id': 10074,
#   'quantity': 5,
#   'unit_price_cents': 8275},
#  {'id': 3363,
#   'order_id': 4012,
#   'product_id': 10075,
#   'quantity': 5,
#   'unit_price_cents': 2571},
#  {'id': 3364,
#   'order_id': 4012,
#   'product_id': 10076,
#   'quantity': 3,
#   'unit_price_cents': 9610},
#  {'id': 3365,
#   'order_id': 4012,
#   'product_id': 10077,
#   'quantity': 1,
#   'unit_price_cents': 3120},
#  {'id': 3366,
#   'order_id': 4012,
#   'product_id': 10078,
#   'quantity': 3,
#   'unit_price_cents': 5340},
#  {'id': 3367,
#   'order_id': 4012,
#   'product_id': 10079,
#   'quantity': 3,
#   'unit_price_cents': 6112},
#  {'id': 3368,
#   'order_id': 4012,
#   'product_id': 10080,
#   'quantity': 4,
#   'unit_price_cents': 7618},
#  {'id': 3369,
#   'order_id': 4012,
#   'product_id': 10081,
#   'quantity': 2,
#   'unit_price_cents': 4286},
#  {'id': 3370,
#   'order_id': 4012,
#   'product_id': 10082,
#   'quantity': 1,
#   'unit_price_cents': 954},
#  {'id': 3371,
#   'order_id': 4012,
#   'product_id': 10083,
#   'quantity': 2,
#   'unit_price_cents': 5573},
#  {'id': 3372,
#   'order_id': 4012,
#   'product_id': 10084,
#   'quantity': 2,
#   'unit_price_cents': 5717},
#  {'id': 3373,
#   'order_id': 4012,
#   'product_id': 10085,
#   'quantity': 4,
#   'unit_price_cents': 9082},
#  {'id': 3374,
#   'order_id': 4012,
#   'product_id': 10086,
#   'quantity': 5,
#   'unit_price_cents': 4593},
#  {'id': 3375,
#   'order_id': 4012,
#   'product_id': 10087,
#   'quantity': 2,
#   'unit_price_cents': 7194},
#  {'id': 3376,
#   'order_id': 4012,
#   'product_id': 10088,
#   'quantity': 4,
#   'unit_price_cents': 6849},
#  {'id': 3377,
#   'order_id': 4012,
#   'product_id': 10089,
#   'quantity': 2,
#   'unit_price_cents': 9273},
#  {'id': 3378,
#   'order_id': 4012,
#   'product_id': 10090,
#   'quantity': 5,
#   'unit_price_cents': 4728},
#  {'id': 3379,
#   'order_id': 4012,
#   'product_id': 10091,
#   'quantity': 5,
#   'unit_price_cents': 3885},
#  {'id': 3380,
#   'order_id': 4012,
#   'product_id': 10092,
#   'quantity': 3,
#   'unit_price_cents': 6162},
#  {'id': 3381,
#   'order_id': 4012,
#   'product_id': 10093,
#   'quantity': 3,
#   'unit_price_cents': 9391},
#  {'id': 3382,
#   'order_id': 4012,
#   'product_id': 10094,
#   'quantity': 1,
#   'unit_price_cents': 3475},
#  {'id': 3383,
#   'order_id': 4012,
#   'product_id': 10095,
#   'quantity': 4,
#   'unit_price_cents': 1661},
#  {'id': 3384,
#   'order_id': 4012,
#   'product_id': 10096,
#   'quantity': 3,
#   'unit_price_cents': 7886},
#  {'id': 3385,
#   'order_id': 4012,
#   'product_id': 10097,
#   'quantity': 5,
#   'unit_price_cents': 7622},
#  {'id': 3386,
#   'order_id': 4012,
#   'product_id': 10098,
#   'quantity': 4,
#   'unit_price_cents': 4706},
#  {'id': 3387,
#   'order_id': 4012,
#   'product_id': 10099,
#   'quantity': 3,
#   'unit_price_cents': 2062},
#  {'id': 3388,
#   'order_id': 4012,
#   'product_id': 10100,
#   'quantity': 3,
#   'unit_price_cents': 6617},
#  {'id': 3389,
#   'order_id': 4012,
#   'product_id': 10101,
#   'quantity': 1,
#   'unit_price_cents': 659},
#  {'id': 3390,
#   'order_id': 4012,
#   'product_id': 10102,
#   'quantity': 5,
#   'unit_price_cents': 1205},
#  {'id': 3391,
#   'order_id': 4012,
#   'product_id': 10103,
#   'quantity': 4,
#   'unit_price_cents': 6907},
#  {'id': 3392,
#   'order_id': 4012,
#   'product_id': 10104,
#   'quantity': 1,
#   'unit_price_cents': 7726},
#  {'id': 3393,
#   'order_id': 4012,
#   'product_id': 10105,
#   'quantity': 4,
#   'unit_price_cents': 9512},
#  {'id': 3394,
#   'order_id': 4012,
#   'product_id': 10106,
#   'quantity': 2,
#   'unit_price_cents': 707},
#  {'id': 3395,
#   'order_id': 4012,
#   'product_id': 10107,
#   'quantity': 5,
#   'unit_price_cents': 5991},
#  {'id': 3396,
#   'order_id': 4012,
#   'product_id': 10108,
#   'quantity': 2,
#   'unit_price_cents': 6324},
#  {'id': 3397,
#   'order_id': 4012,
#   'product_id': 10109,
#   'quantity': 2,
#   'unit_price_cents': 3624},
#  {'id': 3398,
#   'order_id': 4012,
#   'product_id': 10110,
#   'quantity': 1,
#   'unit_price_cents': 3172},
#  {'id': 3399,
#   'order_id': 4012,
#   'product_id': 10111,
#   'quantity': 1,
#   'unit_price_cents': 9503},
#  {'id': 3400,
#   'order_id': 4012,
#   'product_id': 10112,
#   'quantity': 4,
#   'unit_price_cents': 1142},
#  {'id': 3401,
#   'order_id': 4012,
#   'product_id': 10113,
#   'quantity': 2,
#   'unit_price_cents': 5684},
#  {'id': 3402,
#   'order_id': 4012,
#   'product_id': 10114,
#   'quantity': 5,
#   'unit_price_cents': 8397},
#  {'id': 3403,
#   'order_id': 4012,
#   'product_id': 10115,
#   'quantity': 5,
#   'unit_price_cents': 3888},
#  {'id': 3404,
#   'order_id': 4012,
#   'product_id': 10116,
#   'quantity': 1,
#   'unit_price_cents': 9431},
#  {'id': 3405,
#   'order_id': 4012,
#   'product_id': 10117,
#   'quantity': 2,
#   'unit_price_cents': 5514},
#  {'id': 3406,
#   'order_id': 4012,
#   'product_id': 10118,
#   'quantity': 2,
#   'unit_price_cents': 7240},
#  {'id': 3407,
#   'order_id': 4012,
#   'product_id': 10119,
#   'quantity': 4,
#   'unit_price_cents': 4873},
#  {'id': 3408,
#   'order_id': 4012,
#   'product_id': 10120,
#   'quantity': 3,
#   'unit_price_cents': 8929},
#  {'id': 3409,
#   'order_id': 4012,
#   'product_id': 10121,
#   'quantity': 3,
#   'unit_price_cents': 6021},
#  {'id': 3410,
#   'order_id': 4012,
#   'product_id': 10122,
#   'quantity': 5,
#   'unit_price_cents': 6907},
#  {'id': 3411,
#   'order_id': 4012,
#   'product_id': 10123,
#   'quantity': 3,
#   'unit_price_cents': 963},
#  {'id': 3412,
#   'order_id': 4012,
#   'product_id': 10124,
#   'quantity': 1,
#   'unit_price_cents': 3353},
#  {'id': 3413,
#   'order_id': 4012,
#   'product_id': 10125,
#   'quantity': 5,
#   'unit_price_cents': 2579},
#  {'id': 3414,
#   'order_id': 4012,
#   'product_id': 10126,
#   'quantity': 1,
#   'unit_price_cents': 491},
#  {'id': 3415,
#   'order_id': 4012,
#   'product_id': 10127,
#   'quantity': 3,
#   'unit_price_cents': 6550},
#  {'id': 3416,
#   'order_id': 4012,
#   'product_id': 10128,
#   'quantity': 2,
#   'unit_price_cents': 2723},
#  {'id': 3417,
#   'order_id': 4012,
#   'product_id': 10129,
#   'quantity': 3,
#   'unit_price_cents': 584},
#  {'id': 3418,
#   'order_id': 4012,
#   'product_id': 10130,
#   'quantity': 2,
#   'unit_price_cents': 1509}]

# %% [markdown]
# ## Step 4 - Read the order back, and its items via `/orders/:id/items`

# %%
resp = requests.get(f"{BASE_URL}/orders/{order['id']}")
assert resp.status_code == 200, resp.text
print("Order:", resp.json())

resp = requests.get(f"{BASE_URL}/orders/{order['id']}/items")
assert resp.status_code == 200, resp.text
items = resp.json()
assert len(items) == PRODUCT_COUNT
print(f"Order has {len(items)} items")
items
# Out:
# Order: {'id': 4012, 'customer_id': 553, 'status': 'pending', 'created_at': '2026-09-03T13:40:02.176Z'}
# Order has 400 items
# [{'id': 3019,
#   'order_id': 4012,
#   'product_id': 9731,
#   'quantity': 2,
#   'unit_price_cents': 4454},
#  {'id': 3020,
#   'order_id': 4012,
#   'product_id': 9732,
#   'quantity': 1,
#   'unit_price_cents': 1475},
#  {'id': 3021,
#   'order_id': 4012,
#   'product_id': 9733,
#   'quantity': 3,
#   'unit_price_cents': 6816},
#  {'id': 3022,
#   'order_id': 4012,
#   'product_id': 9734,
#   'quantity': 1,
#   'unit_price_cents': 6458},
#  {'id': 3023,
#   'order_id': 4012,
#   'product_id': 9735,
#   'quantity': 4,
#   'unit_price_cents': 857},
#  {'id': 3024,
#   'order_id': 4012,
#   'product_id': 9736,
#   'quantity': 4,
#   'unit_price_cents': 8101},
#  {'id': 3025,
#   'order_id': 4012,
#   'product_id': 9737,
#   'quantity': 1,
#   'unit_price_cents': 8983},
#  {'id': 3026,
#   'order_id': 4012,
#   'product_id': 9738,
#   'quantity': 5,
#   'unit_price_cents': 2237},
#  {'id': 3027,
#   'order_id': 4012,
#   'product_id': 9739,
#   'quantity': 4,
#   'unit_price_cents': 8541},
#  {'id': 3028,
#   'order_id': 4012,
#   'product_id': 9740,
#   'quantity': 5,
#   'unit_price_cents': 4214},
#  {'id': 3029,
#   'order_id': 4012,
#   'product_id': 9741,
#   'quantity': 4,
#   'unit_price_cents': 4140},
#  {'id': 3030,
#   'order_id': 4012,
#   'product_id': 9742,
#   'quantity': 3,
#   'unit_price_cents': 5983},
#  {'id': 3031,
#   'order_id': 4012,
#   'product_id': 9743,
#   'quantity': 2,
#   'unit_price_cents': 4117},
#  {'id': 3032,
#   'order_id': 4012,
#   'product_id': 9744,
#   'quantity': 2,
#   'unit_price_cents': 9684},
#  {'id': 3033,
#   'order_id': 4012,
#   'product_id': 9745,
#   'quantity': 2,
#   'unit_price_cents': 1941},
#  {'id': 3034,
#   'order_id': 4012,
#   'product_id': 9746,
#   'quantity': 3,
#   'unit_price_cents': 9141},
#  {'id': 3035,
#   'order_id': 4012,
#   'product_id': 9747,
#   'quantity': 5,
#   'unit_price_cents': 8718},
#  {'id': 3036,
#   'order_id': 4012,
#   'product_id': 9748,
#   'quantity': 2,
#   'unit_price_cents': 9420},
#  {'id': 3037,
#   'order_id': 4012,
#   'product_id': 9749,
#   'quantity': 2,
#   'unit_price_cents': 1814},
#  {'id': 3038,
#   'order_id': 4012,
#   'product_id': 9750,
#   'quantity': 5,
#   'unit_price_cents': 7499},
#  {'id': 3039,
#   'order_id': 4012,
#   'product_id': 9751,
#   'quantity': 2,
#   'unit_price_cents': 1629},
#  {'id': 3040,
#   'order_id': 4012,
#   'product_id': 9752,
#   'quantity': 3,
#   'unit_price_cents': 9632},
#  {'id': 3041,
#   'order_id': 4012,
#   'product_id': 9753,
#   'quantity': 3,
#   'unit_price_cents': 7489},
#  {'id': 3042,
#   'order_id': 4012,
#   'product_id': 9754,
#   'quantity': 5,
#   'unit_price_cents': 955},
#  {'id': 3043,
#   'order_id': 4012,
#   'product_id': 9755,
#   'quantity': 4,
#   'unit_price_cents': 2331},
#  {'id': 3044,
#   'order_id': 4012,
#   'product_id': 9756,
#   'quantity': 4,
#   'unit_price_cents': 7912},
#  {'id': 3045,
#   'order_id': 4012,
#   'product_id': 9757,
#   'quantity': 4,
#   'unit_price_cents': 4229},
#  {'id': 3046,
#   'order_id': 4012,
#   'product_id': 9758,
#   'quantity': 3,
#   'unit_price_cents': 5549},
#  {'id': 3047,
#   'order_id': 4012,
#   'product_id': 9759,
#   'quantity': 4,
#   'unit_price_cents': 4642},
#  {'id': 3048,
#   'order_id': 4012,
#   'product_id': 9760,
#   'quantity': 3,
#   'unit_price_cents': 1112},
#  {'id': 3049,
#   'order_id': 4012,
#   'product_id': 9761,
#   'quantity': 4,
#   'unit_price_cents': 2084},
#  {'id': 3050,
#   'order_id': 4012,
#   'product_id': 9762,
#   'quantity': 4,
#   'unit_price_cents': 9324},
#  {'id': 3051,
#   'order_id': 4012,
#   'product_id': 9763,
#   'quantity': 4,
#   'unit_price_cents': 9303},
#  {'id': 3052,
#   'order_id': 4012,
#   'product_id': 9764,
#   'quantity': 4,
#   'unit_price_cents': 7329},
#  {'id': 3053,
#   'order_id': 4012,
#   'product_id': 9765,
#   'quantity': 1,
#   'unit_price_cents': 3884},
#  {'id': 3054,
#   'order_id': 4012,
#   'product_id': 9766,
#   'quantity': 1,
#   'unit_price_cents': 3542},
#  {'id': 3055,
#   'order_id': 4012,
#   'product_id': 9767,
#   'quantity': 4,
#   'unit_price_cents': 745},
#  {'id': 3056,
#   'order_id': 4012,
#   'product_id': 9768,
#   'quantity': 3,
#   'unit_price_cents': 5950},
#  {'id': 3057,
#   'order_id': 4012,
#   'product_id': 9769,
#   'quantity': 2,
#   'unit_price_cents': 4031},
#  {'id': 3058,
#   'order_id': 4012,
#   'product_id': 9770,
#   'quantity': 4,
#   'unit_price_cents': 518},
#  {'id': 3059,
#   'order_id': 4012,
#   'product_id': 9771,
#   'quantity': 2,
#   'unit_price_cents': 662},
#  {'id': 3060,
#   'order_id': 4012,
#   'product_id': 9772,
#   'quantity': 4,
#   'unit_price_cents': 9499},
#  {'id': 3061,
#   'order_id': 4012,
#   'product_id': 9773,
#   'quantity': 5,
#   'unit_price_cents': 2636},
#  {'id': 3062,
#   'order_id': 4012,
#   'product_id': 9774,
#   'quantity': 2,
#   'unit_price_cents': 2592},
#  {'id': 3063,
#   'order_id': 4012,
#   'product_id': 9775,
#   'quantity': 1,
#   'unit_price_cents': 7913},
#  {'id': 3064,
#   'order_id': 4012,
#   'product_id': 9776,
#   'quantity': 2,
#   'unit_price_cents': 8776},
#  {'id': 3065,
#   'order_id': 4012,
#   'product_id': 9777,
#   'quantity': 4,
#   'unit_price_cents': 4102},
#  {'id': 3066,
#   'order_id': 4012,
#   'product_id': 9778,
#   'quantity': 3,
#   'unit_price_cents': 8989},
#  {'id': 3067,
#   'order_id': 4012,
#   'product_id': 9779,
#   'quantity': 1,
#   'unit_price_cents': 3992},
#  {'id': 3068,
#   'order_id': 4012,
#   'product_id': 9780,
#   'quantity': 5,
#   'unit_price_cents': 3210},
#  {'id': 3069,
#   'order_id': 4012,
#   'product_id': 9781,
#   'quantity': 3,
#   'unit_price_cents': 5458},
#  {'id': 3070,
#   'order_id': 4012,
#   'product_id': 9782,
#   'quantity': 5,
#   'unit_price_cents': 5354},
#  {'id': 3071,
#   'order_id': 4012,
#   'product_id': 9783,
#   'quantity': 3,
#   'unit_price_cents': 1305},
#  {'id': 3072,
#   'order_id': 4012,
#   'product_id': 9784,
#   'quantity': 4,
#   'unit_price_cents': 7911},
#  {'id': 3073,
#   'order_id': 4012,
#   'product_id': 9785,
#   'quantity': 1,
#   'unit_price_cents': 7010},
#  {'id': 3074,
#   'order_id': 4012,
#   'product_id': 9786,
#   'quantity': 1,
#   'unit_price_cents': 1913},
#  {'id': 3075,
#   'order_id': 4012,
#   'product_id': 9787,
#   'quantity': 4,
#   'unit_price_cents': 7554},
#  {'id': 3076,
#   'order_id': 4012,
#   'product_id': 9788,
#   'quantity': 3,
#   'unit_price_cents': 1043},
#  {'id': 3077,
#   'order_id': 4012,
#   'product_id': 9789,
#   'quantity': 1,
#   'unit_price_cents': 471},
#  {'id': 3078,
#   'order_id': 4012,
#   'product_id': 9790,
#   'quantity': 5,
#   'unit_price_cents': 4668},
#  {'id': 3079,
#   'order_id': 4012,
#   'product_id': 9791,
#   'quantity': 4,
#   'unit_price_cents': 7720},
#  {'id': 3080,
#   'order_id': 4012,
#   'product_id': 9792,
#   'quantity': 5,
#   'unit_price_cents': 8230},
#  {'id': 3081,
#   'order_id': 4012,
#   'product_id': 9793,
#   'quantity': 3,
#   'unit_price_cents': 6306},
#  {'id': 3082,
#   'order_id': 4012,
#   'product_id': 9794,
#   'quantity': 5,
#   'unit_price_cents': 5502},
#  {'id': 3083,
#   'order_id': 4012,
#   'product_id': 9795,
#   'quantity': 2,
#   'unit_price_cents': 5443},
#  {'id': 3084,
#   'order_id': 4012,
#   'product_id': 9796,
#   'quantity': 1,
#   'unit_price_cents': 7205},
#  {'id': 3085,
#   'order_id': 4012,
#   'product_id': 9797,
#   'quantity': 1,
#   'unit_price_cents': 4079},
#  {'id': 3086,
#   'order_id': 4012,
#   'product_id': 9798,
#   'quantity': 1,
#   'unit_price_cents': 8656},
#  {'id': 3087,
#   'order_id': 4012,
#   'product_id': 9799,
#   'quantity': 4,
#   'unit_price_cents': 9514},
#  {'id': 3088,
#   'order_id': 4012,
#   'product_id': 9800,
#   'quantity': 5,
#   'unit_price_cents': 9497},
#  {'id': 3089,
#   'order_id': 4012,
#   'product_id': 9801,
#   'quantity': 3,
#   'unit_price_cents': 2836},
#  {'id': 3090,
#   'order_id': 4012,
#   'product_id': 9802,
#   'quantity': 2,
#   'unit_price_cents': 764},
#  {'id': 3091,
#   'order_id': 4012,
#   'product_id': 9803,
#   'quantity': 2,
#   'unit_price_cents': 9594},
#  {'id': 3092,
#   'order_id': 4012,
#   'product_id': 9804,
#   'quantity': 5,
#   'unit_price_cents': 1065},
#  {'id': 3093,
#   'order_id': 4012,
#   'product_id': 9805,
#   'quantity': 4,
#   'unit_price_cents': 9818},
#  {'id': 3094,
#   'order_id': 4012,
#   'product_id': 9806,
#   'quantity': 1,
#   'unit_price_cents': 7867},
#  {'id': 3095,
#   'order_id': 4012,
#   'product_id': 9807,
#   'quantity': 4,
#   'unit_price_cents': 9804},
#  {'id': 3096,
#   'order_id': 4012,
#   'product_id': 9808,
#   'quantity': 2,
#   'unit_price_cents': 8931},
#  {'id': 3097,
#   'order_id': 4012,
#   'product_id': 9809,
#   'quantity': 1,
#   'unit_price_cents': 6614},
#  {'id': 3098,
#   'order_id': 4012,
#   'product_id': 9810,
#   'quantity': 2,
#   'unit_price_cents': 2010},
#  {'id': 3099,
#   'order_id': 4012,
#   'product_id': 9811,
#   'quantity': 2,
#   'unit_price_cents': 5582},
#  {'id': 3100,
#   'order_id': 4012,
#   'product_id': 9812,
#   'quantity': 2,
#   'unit_price_cents': 7020},
#  {'id': 3101,
#   'order_id': 4012,
#   'product_id': 9813,
#   'quantity': 5,
#   'unit_price_cents': 3194},
#  {'id': 3102,
#   'order_id': 4012,
#   'product_id': 9814,
#   'quantity': 4,
#   'unit_price_cents': 2730},
#  {'id': 3103,
#   'order_id': 4012,
#   'product_id': 9815,
#   'quantity': 5,
#   'unit_price_cents': 398},
#  {'id': 3104,
#   'order_id': 4012,
#   'product_id': 9816,
#   'quantity': 1,
#   'unit_price_cents': 2799},
#  {'id': 3105,
#   'order_id': 4012,
#   'product_id': 9817,
#   'quantity': 3,
#   'unit_price_cents': 6815},
#  {'id': 3106,
#   'order_id': 4012,
#   'product_id': 9818,
#   'quantity': 3,
#   'unit_price_cents': 7960},
#  {'id': 3107,
#   'order_id': 4012,
#   'product_id': 9819,
#   'quantity': 5,
#   'unit_price_cents': 9698},
#  {'id': 3108,
#   'order_id': 4012,
#   'product_id': 9820,
#   'quantity': 5,
#   'unit_price_cents': 8215},
#  {'id': 3109,
#   'order_id': 4012,
#   'product_id': 9821,
#   'quantity': 3,
#   'unit_price_cents': 1821},
#  {'id': 3110,
#   'order_id': 4012,
#   'product_id': 9822,
#   'quantity': 5,
#   'unit_price_cents': 9141},
#  {'id': 3111,
#   'order_id': 4012,
#   'product_id': 9823,
#   'quantity': 4,
#   'unit_price_cents': 1845},
#  {'id': 3112,
#   'order_id': 4012,
#   'product_id': 9824,
#   'quantity': 1,
#   'unit_price_cents': 4205},
#  {'id': 3113,
#   'order_id': 4012,
#   'product_id': 9825,
#   'quantity': 3,
#   'unit_price_cents': 8893},
#  {'id': 3114,
#   'order_id': 4012,
#   'product_id': 9826,
#   'quantity': 1,
#   'unit_price_cents': 9553},
#  {'id': 3115,
#   'order_id': 4012,
#   'product_id': 9827,
#   'quantity': 3,
#   'unit_price_cents': 8807},
#  {'id': 3116,
#   'order_id': 4012,
#   'product_id': 9828,
#   'quantity': 1,
#   'unit_price_cents': 563},
#  {'id': 3117,
#   'order_id': 4012,
#   'product_id': 9829,
#   'quantity': 3,
#   'unit_price_cents': 8833},
#  {'id': 3118,
#   'order_id': 4012,
#   'product_id': 9830,
#   'quantity': 2,
#   'unit_price_cents': 7442},
#  {'id': 3119,
#   'order_id': 4012,
#   'product_id': 9831,
#   'quantity': 2,
#   'unit_price_cents': 7781},
#  {'id': 3120,
#   'order_id': 4012,
#   'product_id': 9832,
#   'quantity': 1,
#   'unit_price_cents': 7293},
#  {'id': 3121,
#   'order_id': 4012,
#   'product_id': 9833,
#   'quantity': 3,
#   'unit_price_cents': 3568},
#  {'id': 3122,
#   'order_id': 4012,
#   'product_id': 9834,
#   'quantity': 4,
#   'unit_price_cents': 7787},
#  {'id': 3123,
#   'order_id': 4012,
#   'product_id': 9835,
#   'quantity': 5,
#   'unit_price_cents': 5429},
#  {'id': 3124,
#   'order_id': 4012,
#   'product_id': 9836,
#   'quantity': 4,
#   'unit_price_cents': 9199},
#  {'id': 3125,
#   'order_id': 4012,
#   'product_id': 9837,
#   'quantity': 1,
#   'unit_price_cents': 7359},
#  {'id': 3126,
#   'order_id': 4012,
#   'product_id': 9838,
#   'quantity': 2,
#   'unit_price_cents': 2621},
#  {'id': 3127,
#   'order_id': 4012,
#   'product_id': 9839,
#   'quantity': 2,
#   'unit_price_cents': 3635},
#  {'id': 3128,
#   'order_id': 4012,
#   'product_id': 9840,
#   'quantity': 4,
#   'unit_price_cents': 8809},
#  {'id': 3129,
#   'order_id': 4012,
#   'product_id': 9841,
#   'quantity': 1,
#   'unit_price_cents': 2471},
#  {'id': 3130,
#   'order_id': 4012,
#   'product_id': 9842,
#   'quantity': 3,
#   'unit_price_cents': 7533},
#  {'id': 3131,
#   'order_id': 4012,
#   'product_id': 9843,
#   'quantity': 1,
#   'unit_price_cents': 5837},
#  {'id': 3132,
#   'order_id': 4012,
#   'product_id': 9844,
#   'quantity': 2,
#   'unit_price_cents': 8195},
#  {'id': 3133,
#   'order_id': 4012,
#   'product_id': 9845,
#   'quantity': 1,
#   'unit_price_cents': 5260},
#  {'id': 3134,
#   'order_id': 4012,
#   'product_id': 9846,
#   'quantity': 3,
#   'unit_price_cents': 677},
#  {'id': 3135,
#   'order_id': 4012,
#   'product_id': 9847,
#   'quantity': 1,
#   'unit_price_cents': 7796},
#  {'id': 3136,
#   'order_id': 4012,
#   'product_id': 9848,
#   'quantity': 5,
#   'unit_price_cents': 2013},
#  {'id': 3137,
#   'order_id': 4012,
#   'product_id': 9849,
#   'quantity': 1,
#   'unit_price_cents': 8990},
#  {'id': 3138,
#   'order_id': 4012,
#   'product_id': 9850,
#   'quantity': 2,
#   'unit_price_cents': 5721},
#  {'id': 3139,
#   'order_id': 4012,
#   'product_id': 9851,
#   'quantity': 4,
#   'unit_price_cents': 2845},
#  {'id': 3140,
#   'order_id': 4012,
#   'product_id': 9852,
#   'quantity': 2,
#   'unit_price_cents': 4377},
#  {'id': 3141,
#   'order_id': 4012,
#   'product_id': 9853,
#   'quantity': 1,
#   'unit_price_cents': 5075},
#  {'id': 3142,
#   'order_id': 4012,
#   'product_id': 9854,
#   'quantity': 5,
#   'unit_price_cents': 7101},
#  {'id': 3143,
#   'order_id': 4012,
#   'product_id': 9855,
#   'quantity': 5,
#   'unit_price_cents': 2651},
#  {'id': 3144,
#   'order_id': 4012,
#   'product_id': 9856,
#   'quantity': 3,
#   'unit_price_cents': 7562},
#  {'id': 3145,
#   'order_id': 4012,
#   'product_id': 9857,
#   'quantity': 2,
#   'unit_price_cents': 2454},
#  {'id': 3146,
#   'order_id': 4012,
#   'product_id': 9858,
#   'quantity': 4,
#   'unit_price_cents': 4417},
#  {'id': 3147,
#   'order_id': 4012,
#   'product_id': 9859,
#   'quantity': 3,
#   'unit_price_cents': 6050},
#  {'id': 3148,
#   'order_id': 4012,
#   'product_id': 9860,
#   'quantity': 1,
#   'unit_price_cents': 7122},
#  {'id': 3149,
#   'order_id': 4012,
#   'product_id': 9861,
#   'quantity': 4,
#   'unit_price_cents': 8965},
#  {'id': 3150,
#   'order_id': 4012,
#   'product_id': 9862,
#   'quantity': 5,
#   'unit_price_cents': 1046},
#  {'id': 3151,
#   'order_id': 4012,
#   'product_id': 9863,
#   'quantity': 2,
#   'unit_price_cents': 4123},
#  {'id': 3152,
#   'order_id': 4012,
#   'product_id': 9864,
#   'quantity': 2,
#   'unit_price_cents': 9524},
#  {'id': 3153,
#   'order_id': 4012,
#   'product_id': 9865,
#   'quantity': 3,
#   'unit_price_cents': 2147},
#  {'id': 3154,
#   'order_id': 4012,
#   'product_id': 9866,
#   'quantity': 5,
#   'unit_price_cents': 4257},
#  {'id': 3155,
#   'order_id': 4012,
#   'product_id': 9867,
#   'quantity': 1,
#   'unit_price_cents': 7260},
#  {'id': 3156,
#   'order_id': 4012,
#   'product_id': 9868,
#   'quantity': 4,
#   'unit_price_cents': 8618},
#  {'id': 3157,
#   'order_id': 4012,
#   'product_id': 9869,
#   'quantity': 3,
#   'unit_price_cents': 291},
#  {'id': 3158,
#   'order_id': 4012,
#   'product_id': 9870,
#   'quantity': 2,
#   'unit_price_cents': 900},
#  {'id': 3159,
#   'order_id': 4012,
#   'product_id': 9871,
#   'quantity': 1,
#   'unit_price_cents': 2380},
#  {'id': 3160,
#   'order_id': 4012,
#   'product_id': 9872,
#   'quantity': 3,
#   'unit_price_cents': 2463},
#  {'id': 3161,
#   'order_id': 4012,
#   'product_id': 9873,
#   'quantity': 3,
#   'unit_price_cents': 4629},
#  {'id': 3162,
#   'order_id': 4012,
#   'product_id': 9874,
#   'quantity': 4,
#   'unit_price_cents': 8230},
#  {'id': 3163,
#   'order_id': 4012,
#   'product_id': 9875,
#   'quantity': 4,
#   'unit_price_cents': 9989},
#  {'id': 3164,
#   'order_id': 4012,
#   'product_id': 9876,
#   'quantity': 4,
#   'unit_price_cents': 9103},
#  {'id': 3165,
#   'order_id': 4012,
#   'product_id': 9877,
#   'quantity': 4,
#   'unit_price_cents': 2347},
#  {'id': 3166,
#   'order_id': 4012,
#   'product_id': 9878,
#   'quantity': 2,
#   'unit_price_cents': 8701},
#  {'id': 3167,
#   'order_id': 4012,
#   'product_id': 9879,
#   'quantity': 1,
#   'unit_price_cents': 7651},
#  {'id': 3168,
#   'order_id': 4012,
#   'product_id': 9880,
#   'quantity': 4,
#   'unit_price_cents': 9791},
#  {'id': 3169,
#   'order_id': 4012,
#   'product_id': 9881,
#   'quantity': 3,
#   'unit_price_cents': 4935},
#  {'id': 3170,
#   'order_id': 4012,
#   'product_id': 9882,
#   'quantity': 3,
#   'unit_price_cents': 5970},
#  {'id': 3171,
#   'order_id': 4012,
#   'product_id': 9883,
#   'quantity': 2,
#   'unit_price_cents': 7976},
#  {'id': 3172,
#   'order_id': 4012,
#   'product_id': 9884,
#   'quantity': 3,
#   'unit_price_cents': 838},
#  {'id': 3173,
#   'order_id': 4012,
#   'product_id': 9885,
#   'quantity': 4,
#   'unit_price_cents': 8445},
#  {'id': 3174,
#   'order_id': 4012,
#   'product_id': 9886,
#   'quantity': 5,
#   'unit_price_cents': 9874},
#  {'id': 3175,
#   'order_id': 4012,
#   'product_id': 9887,
#   'quantity': 4,
#   'unit_price_cents': 480},
#  {'id': 3176,
#   'order_id': 4012,
#   'product_id': 9888,
#   'quantity': 5,
#   'unit_price_cents': 6941},
#  {'id': 3177,
#   'order_id': 4012,
#   'product_id': 9889,
#   'quantity': 3,
#   'unit_price_cents': 6139},
#  {'id': 3178,
#   'order_id': 4012,
#   'product_id': 9890,
#   'quantity': 2,
#   'unit_price_cents': 3443},
#  {'id': 3179,
#   'order_id': 4012,
#   'product_id': 9891,
#   'quantity': 4,
#   'unit_price_cents': 4378},
#  {'id': 3180,
#   'order_id': 4012,
#   'product_id': 9892,
#   'quantity': 2,
#   'unit_price_cents': 6522},
#  {'id': 3181,
#   'order_id': 4012,
#   'product_id': 9893,
#   'quantity': 4,
#   'unit_price_cents': 2803},
#  {'id': 3182,
#   'order_id': 4012,
#   'product_id': 9894,
#   'quantity': 3,
#   'unit_price_cents': 3280},
#  {'id': 3183,
#   'order_id': 4012,
#   'product_id': 9895,
#   'quantity': 1,
#   'unit_price_cents': 8683},
#  {'id': 3184,
#   'order_id': 4012,
#   'product_id': 9896,
#   'quantity': 1,
#   'unit_price_cents': 5282},
#  {'id': 3185,
#   'order_id': 4012,
#   'product_id': 9897,
#   'quantity': 1,
#   'unit_price_cents': 2012},
#  {'id': 3186,
#   'order_id': 4012,
#   'product_id': 9898,
#   'quantity': 3,
#   'unit_price_cents': 8045},
#  {'id': 3187,
#   'order_id': 4012,
#   'product_id': 9899,
#   'quantity': 5,
#   'unit_price_cents': 8763},
#  {'id': 3188,
#   'order_id': 4012,
#   'product_id': 9900,
#   'quantity': 5,
#   'unit_price_cents': 6513},
#  {'id': 3189,
#   'order_id': 4012,
#   'product_id': 9901,
#   'quantity': 2,
#   'unit_price_cents': 6112},
#  {'id': 3190,
#   'order_id': 4012,
#   'product_id': 9902,
#   'quantity': 3,
#   'unit_price_cents': 2331},
#  {'id': 3191,
#   'order_id': 4012,
#   'product_id': 9903,
#   'quantity': 5,
#   'unit_price_cents': 2989},
#  {'id': 3192,
#   'order_id': 4012,
#   'product_id': 9904,
#   'quantity': 1,
#   'unit_price_cents': 922},
#  {'id': 3193,
#   'order_id': 4012,
#   'product_id': 9905,
#   'quantity': 5,
#   'unit_price_cents': 6119},
#  {'id': 3194,
#   'order_id': 4012,
#   'product_id': 9906,
#   'quantity': 5,
#   'unit_price_cents': 2818},
#  {'id': 3195,
#   'order_id': 4012,
#   'product_id': 9907,
#   'quantity': 5,
#   'unit_price_cents': 2357},
#  {'id': 3196,
#   'order_id': 4012,
#   'product_id': 9908,
#   'quantity': 1,
#   'unit_price_cents': 1792},
#  {'id': 3197,
#   'order_id': 4012,
#   'product_id': 9909,
#   'quantity': 4,
#   'unit_price_cents': 6014},
#  {'id': 3198,
#   'order_id': 4012,
#   'product_id': 9910,
#   'quantity': 5,
#   'unit_price_cents': 3863},
#  {'id': 3199,
#   'order_id': 4012,
#   'product_id': 9911,
#   'quantity': 4,
#   'unit_price_cents': 9138},
#  {'id': 3200,
#   'order_id': 4012,
#   'product_id': 9912,
#   'quantity': 1,
#   'unit_price_cents': 4256},
#  {'id': 3201,
#   'order_id': 4012,
#   'product_id': 9913,
#   'quantity': 1,
#   'unit_price_cents': 8479},
#  {'id': 3202,
#   'order_id': 4012,
#   'product_id': 9914,
#   'quantity': 2,
#   'unit_price_cents': 8953},
#  {'id': 3203,
#   'order_id': 4012,
#   'product_id': 9915,
#   'quantity': 5,
#   'unit_price_cents': 7502},
#  {'id': 3204,
#   'order_id': 4012,
#   'product_id': 9916,
#   'quantity': 2,
#   'unit_price_cents': 7264},
#  {'id': 3205,
#   'order_id': 4012,
#   'product_id': 9917,
#   'quantity': 3,
#   'unit_price_cents': 9967},
#  {'id': 3206,
#   'order_id': 4012,
#   'product_id': 9918,
#   'quantity': 3,
#   'unit_price_cents': 2151},
#  {'id': 3207,
#   'order_id': 4012,
#   'product_id': 9919,
#   'quantity': 2,
#   'unit_price_cents': 1946},
#  {'id': 3208,
#   'order_id': 4012,
#   'product_id': 9920,
#   'quantity': 3,
#   'unit_price_cents': 4502},
#  {'id': 3209,
#   'order_id': 4012,
#   'product_id': 9921,
#   'quantity': 3,
#   'unit_price_cents': 9454},
#  {'id': 3210,
#   'order_id': 4012,
#   'product_id': 9922,
#   'quantity': 4,
#   'unit_price_cents': 4164},
#  {'id': 3211,
#   'order_id': 4012,
#   'product_id': 9923,
#   'quantity': 5,
#   'unit_price_cents': 7157},
#  {'id': 3212,
#   'order_id': 4012,
#   'product_id': 9924,
#   'quantity': 3,
#   'unit_price_cents': 2876},
#  {'id': 3213,
#   'order_id': 4012,
#   'product_id': 9925,
#   'quantity': 5,
#   'unit_price_cents': 7404},
#  {'id': 3214,
#   'order_id': 4012,
#   'product_id': 9926,
#   'quantity': 3,
#   'unit_price_cents': 545},
#  {'id': 3215,
#   'order_id': 4012,
#   'product_id': 9927,
#   'quantity': 5,
#   'unit_price_cents': 9020},
#  {'id': 3216,
#   'order_id': 4012,
#   'product_id': 9928,
#   'quantity': 1,
#   'unit_price_cents': 9612},
#  {'id': 3217,
#   'order_id': 4012,
#   'product_id': 9929,
#   'quantity': 5,
#   'unit_price_cents': 7258},
#  {'id': 3218,
#   'order_id': 4012,
#   'product_id': 9930,
#   'quantity': 3,
#   'unit_price_cents': 7537},
#  {'id': 3219,
#   'order_id': 4012,
#   'product_id': 9931,
#   'quantity': 2,
#   'unit_price_cents': 4908},
#  {'id': 3220,
#   'order_id': 4012,
#   'product_id': 9932,
#   'quantity': 3,
#   'unit_price_cents': 3865},
#  {'id': 3221,
#   'order_id': 4012,
#   'product_id': 9933,
#   'quantity': 1,
#   'unit_price_cents': 1712},
#  {'id': 3222,
#   'order_id': 4012,
#   'product_id': 9934,
#   'quantity': 4,
#   'unit_price_cents': 5896},
#  {'id': 3223,
#   'order_id': 4012,
#   'product_id': 9935,
#   'quantity': 3,
#   'unit_price_cents': 4896},
#  {'id': 3224,
#   'order_id': 4012,
#   'product_id': 9936,
#   'quantity': 3,
#   'unit_price_cents': 3336},
#  {'id': 3225,
#   'order_id': 4012,
#   'product_id': 9937,
#   'quantity': 5,
#   'unit_price_cents': 6220},
#  {'id': 3226,
#   'order_id': 4012,
#   'product_id': 9938,
#   'quantity': 2,
#   'unit_price_cents': 1325},
#  {'id': 3227,
#   'order_id': 4012,
#   'product_id': 9939,
#   'quantity': 5,
#   'unit_price_cents': 5010},
#  {'id': 3228,
#   'order_id': 4012,
#   'product_id': 9940,
#   'quantity': 4,
#   'unit_price_cents': 9433},
#  {'id': 3229,
#   'order_id': 4012,
#   'product_id': 9941,
#   'quantity': 2,
#   'unit_price_cents': 9548},
#  {'id': 3230,
#   'order_id': 4012,
#   'product_id': 9942,
#   'quantity': 1,
#   'unit_price_cents': 5034},
#  {'id': 3231,
#   'order_id': 4012,
#   'product_id': 9943,
#   'quantity': 3,
#   'unit_price_cents': 6292},
#  {'id': 3232,
#   'order_id': 4012,
#   'product_id': 9944,
#   'quantity': 4,
#   'unit_price_cents': 3912},
#  {'id': 3233,
#   'order_id': 4012,
#   'product_id': 9945,
#   'quantity': 3,
#   'unit_price_cents': 5353},
#  {'id': 3234,
#   'order_id': 4012,
#   'product_id': 9946,
#   'quantity': 4,
#   'unit_price_cents': 2808},
#  {'id': 3235,
#   'order_id': 4012,
#   'product_id': 9947,
#   'quantity': 5,
#   'unit_price_cents': 1557},
#  {'id': 3236,
#   'order_id': 4012,
#   'product_id': 9948,
#   'quantity': 1,
#   'unit_price_cents': 4985},
#  {'id': 3237,
#   'order_id': 4012,
#   'product_id': 9949,
#   'quantity': 2,
#   'unit_price_cents': 7572},
#  {'id': 3238,
#   'order_id': 4012,
#   'product_id': 9950,
#   'quantity': 2,
#   'unit_price_cents': 3281},
#  {'id': 3239,
#   'order_id': 4012,
#   'product_id': 9951,
#   'quantity': 3,
#   'unit_price_cents': 1077},
#  {'id': 3240,
#   'order_id': 4012,
#   'product_id': 9952,
#   'quantity': 1,
#   'unit_price_cents': 1552},
#  {'id': 3241,
#   'order_id': 4012,
#   'product_id': 9953,
#   'quantity': 5,
#   'unit_price_cents': 3800},
#  {'id': 3242,
#   'order_id': 4012,
#   'product_id': 9954,
#   'quantity': 2,
#   'unit_price_cents': 6074},
#  {'id': 3243,
#   'order_id': 4012,
#   'product_id': 9955,
#   'quantity': 5,
#   'unit_price_cents': 5548},
#  {'id': 3244,
#   'order_id': 4012,
#   'product_id': 9956,
#   'quantity': 1,
#   'unit_price_cents': 7180},
#  {'id': 3245,
#   'order_id': 4012,
#   'product_id': 9957,
#   'quantity': 4,
#   'unit_price_cents': 3954},
#  {'id': 3246,
#   'order_id': 4012,
#   'product_id': 9958,
#   'quantity': 4,
#   'unit_price_cents': 6919},
#  {'id': 3247,
#   'order_id': 4012,
#   'product_id': 9959,
#   'quantity': 3,
#   'unit_price_cents': 4404},
#  {'id': 3248,
#   'order_id': 4012,
#   'product_id': 9960,
#   'quantity': 2,
#   'unit_price_cents': 6279},
#  {'id': 3249,
#   'order_id': 4012,
#   'product_id': 9961,
#   'quantity': 5,
#   'unit_price_cents': 7470},
#  {'id': 3250,
#   'order_id': 4012,
#   'product_id': 9962,
#   'quantity': 5,
#   'unit_price_cents': 5568},
#  {'id': 3251,
#   'order_id': 4012,
#   'product_id': 9963,
#   'quantity': 1,
#   'unit_price_cents': 5855},
#  {'id': 3252,
#   'order_id': 4012,
#   'product_id': 9964,
#   'quantity': 3,
#   'unit_price_cents': 3548},
#  {'id': 3253,
#   'order_id': 4012,
#   'product_id': 9965,
#   'quantity': 4,
#   'unit_price_cents': 9888},
#  {'id': 3254,
#   'order_id': 4012,
#   'product_id': 9966,
#   'quantity': 4,
#   'unit_price_cents': 5218},
#  {'id': 3255,
#   'order_id': 4012,
#   'product_id': 9967,
#   'quantity': 1,
#   'unit_price_cents': 1636},
#  {'id': 3256,
#   'order_id': 4012,
#   'product_id': 9968,
#   'quantity': 4,
#   'unit_price_cents': 6416},
#  {'id': 3257,
#   'order_id': 4012,
#   'product_id': 9969,
#   'quantity': 1,
#   'unit_price_cents': 9028},
#  {'id': 3258,
#   'order_id': 4012,
#   'product_id': 9970,
#   'quantity': 3,
#   'unit_price_cents': 5268},
#  {'id': 3259,
#   'order_id': 4012,
#   'product_id': 9971,
#   'quantity': 5,
#   'unit_price_cents': 2347},
#  {'id': 3260,
#   'order_id': 4012,
#   'product_id': 9972,
#   'quantity': 5,
#   'unit_price_cents': 4896},
#  {'id': 3261,
#   'order_id': 4012,
#   'product_id': 9973,
#   'quantity': 4,
#   'unit_price_cents': 6944},
#  {'id': 3262,
#   'order_id': 4012,
#   'product_id': 9974,
#   'quantity': 1,
#   'unit_price_cents': 6531},
#  {'id': 3263,
#   'order_id': 4012,
#   'product_id': 9975,
#   'quantity': 4,
#   'unit_price_cents': 6941},
#  {'id': 3264,
#   'order_id': 4012,
#   'product_id': 9976,
#   'quantity': 5,
#   'unit_price_cents': 6543},
#  {'id': 3265,
#   'order_id': 4012,
#   'product_id': 9977,
#   'quantity': 1,
#   'unit_price_cents': 7957},
#  {'id': 3266,
#   'order_id': 4012,
#   'product_id': 9978,
#   'quantity': 2,
#   'unit_price_cents': 6892},
#  {'id': 3267,
#   'order_id': 4012,
#   'product_id': 9979,
#   'quantity': 1,
#   'unit_price_cents': 1220},
#  {'id': 3268,
#   'order_id': 4012,
#   'product_id': 9980,
#   'quantity': 1,
#   'unit_price_cents': 8117},
#  {'id': 3269,
#   'order_id': 4012,
#   'product_id': 9981,
#   'quantity': 4,
#   'unit_price_cents': 3636},
#  {'id': 3270,
#   'order_id': 4012,
#   'product_id': 9982,
#   'quantity': 4,
#   'unit_price_cents': 7804},
#  {'id': 3271,
#   'order_id': 4012,
#   'product_id': 9983,
#   'quantity': 3,
#   'unit_price_cents': 3634},
#  {'id': 3272,
#   'order_id': 4012,
#   'product_id': 9984,
#   'quantity': 3,
#   'unit_price_cents': 8975},
#  {'id': 3273,
#   'order_id': 4012,
#   'product_id': 9985,
#   'quantity': 2,
#   'unit_price_cents': 4383},
#  {'id': 3274,
#   'order_id': 4012,
#   'product_id': 9986,
#   'quantity': 5,
#   'unit_price_cents': 1495},
#  {'id': 3275,
#   'order_id': 4012,
#   'product_id': 9987,
#   'quantity': 3,
#   'unit_price_cents': 1921},
#  {'id': 3276,
#   'order_id': 4012,
#   'product_id': 9988,
#   'quantity': 1,
#   'unit_price_cents': 8726},
#  {'id': 3277,
#   'order_id': 4012,
#   'product_id': 9989,
#   'quantity': 4,
#   'unit_price_cents': 655},
#  {'id': 3278,
#   'order_id': 4012,
#   'product_id': 9990,
#   'quantity': 1,
#   'unit_price_cents': 6332},
#  {'id': 3279,
#   'order_id': 4012,
#   'product_id': 9991,
#   'quantity': 5,
#   'unit_price_cents': 9597},
#  {'id': 3280,
#   'order_id': 4012,
#   'product_id': 9992,
#   'quantity': 1,
#   'unit_price_cents': 1085},
#  {'id': 3281,
#   'order_id': 4012,
#   'product_id': 9993,
#   'quantity': 2,
#   'unit_price_cents': 5896},
#  {'id': 3282,
#   'order_id': 4012,
#   'product_id': 9994,
#   'quantity': 1,
#   'unit_price_cents': 1424},
#  {'id': 3283,
#   'order_id': 4012,
#   'product_id': 9995,
#   'quantity': 5,
#   'unit_price_cents': 5601},
#  {'id': 3284,
#   'order_id': 4012,
#   'product_id': 9996,
#   'quantity': 2,
#   'unit_price_cents': 2974},
#  {'id': 3285,
#   'order_id': 4012,
#   'product_id': 9997,
#   'quantity': 2,
#   'unit_price_cents': 4967},
#  {'id': 3286,
#   'order_id': 4012,
#   'product_id': 9998,
#   'quantity': 4,
#   'unit_price_cents': 6817},
#  {'id': 3287,
#   'order_id': 4012,
#   'product_id': 9999,
#   'quantity': 3,
#   'unit_price_cents': 546},
#  {'id': 3288,
#   'order_id': 4012,
#   'product_id': 10000,
#   'quantity': 1,
#   'unit_price_cents': 7123},
#  {'id': 3289,
#   'order_id': 4012,
#   'product_id': 10001,
#   'quantity': 1,
#   'unit_price_cents': 4297},
#  {'id': 3290,
#   'order_id': 4012,
#   'product_id': 10002,
#   'quantity': 4,
#   'unit_price_cents': 3680},
#  {'id': 3291,
#   'order_id': 4012,
#   'product_id': 10003,
#   'quantity': 5,
#   'unit_price_cents': 4856},
#  {'id': 3292,
#   'order_id': 4012,
#   'product_id': 10004,
#   'quantity': 1,
#   'unit_price_cents': 9708},
#  {'id': 3293,
#   'order_id': 4012,
#   'product_id': 10005,
#   'quantity': 3,
#   'unit_price_cents': 6193},
#  {'id': 3294,
#   'order_id': 4012,
#   'product_id': 10006,
#   'quantity': 2,
#   'unit_price_cents': 7221},
#  {'id': 3295,
#   'order_id': 4012,
#   'product_id': 10007,
#   'quantity': 3,
#   'unit_price_cents': 9949},
#  {'id': 3296,
#   'order_id': 4012,
#   'product_id': 10008,
#   'quantity': 3,
#   'unit_price_cents': 1205},
#  {'id': 3297,
#   'order_id': 4012,
#   'product_id': 10009,
#   'quantity': 5,
#   'unit_price_cents': 7507},
#  {'id': 3298,
#   'order_id': 4012,
#   'product_id': 10010,
#   'quantity': 5,
#   'unit_price_cents': 7311},
#  {'id': 3299,
#   'order_id': 4012,
#   'product_id': 10011,
#   'quantity': 2,
#   'unit_price_cents': 1919},
#  {'id': 3300,
#   'order_id': 4012,
#   'product_id': 10012,
#   'quantity': 2,
#   'unit_price_cents': 7721},
#  {'id': 3301,
#   'order_id': 4012,
#   'product_id': 10013,
#   'quantity': 4,
#   'unit_price_cents': 4830},
#  {'id': 3302,
#   'order_id': 4012,
#   'product_id': 10014,
#   'quantity': 4,
#   'unit_price_cents': 6636},
#  {'id': 3303,
#   'order_id': 4012,
#   'product_id': 10015,
#   'quantity': 4,
#   'unit_price_cents': 1406},
#  {'id': 3304,
#   'order_id': 4012,
#   'product_id': 10016,
#   'quantity': 4,
#   'unit_price_cents': 7490},
#  {'id': 3305,
#   'order_id': 4012,
#   'product_id': 10017,
#   'quantity': 1,
#   'unit_price_cents': 1668},
#  {'id': 3306,
#   'order_id': 4012,
#   'product_id': 10018,
#   'quantity': 4,
#   'unit_price_cents': 5541},
#  {'id': 3307,
#   'order_id': 4012,
#   'product_id': 10019,
#   'quantity': 3,
#   'unit_price_cents': 2805},
#  {'id': 3308,
#   'order_id': 4012,
#   'product_id': 10020,
#   'quantity': 4,
#   'unit_price_cents': 9702},
#  {'id': 3309,
#   'order_id': 4012,
#   'product_id': 10021,
#   'quantity': 3,
#   'unit_price_cents': 8498},
#  {'id': 3310,
#   'order_id': 4012,
#   'product_id': 10022,
#   'quantity': 5,
#   'unit_price_cents': 4381},
#  {'id': 3311,
#   'order_id': 4012,
#   'product_id': 10023,
#   'quantity': 1,
#   'unit_price_cents': 5280},
#  {'id': 3312,
#   'order_id': 4012,
#   'product_id': 10024,
#   'quantity': 5,
#   'unit_price_cents': 787},
#  {'id': 3313,
#   'order_id': 4012,
#   'product_id': 10025,
#   'quantity': 1,
#   'unit_price_cents': 7978},
#  {'id': 3314,
#   'order_id': 4012,
#   'product_id': 10026,
#   'quantity': 1,
#   'unit_price_cents': 3451},
#  {'id': 3315,
#   'order_id': 4012,
#   'product_id': 10027,
#   'quantity': 2,
#   'unit_price_cents': 5629},
#  {'id': 3316,
#   'order_id': 4012,
#   'product_id': 10028,
#   'quantity': 5,
#   'unit_price_cents': 7404},
#  {'id': 3317,
#   'order_id': 4012,
#   'product_id': 10029,
#   'quantity': 5,
#   'unit_price_cents': 2997},
#  {'id': 3318,
#   'order_id': 4012,
#   'product_id': 10030,
#   'quantity': 2,
#   'unit_price_cents': 3185},
#  {'id': 3319,
#   'order_id': 4012,
#   'product_id': 10031,
#   'quantity': 5,
#   'unit_price_cents': 1854},
#  {'id': 3320,
#   'order_id': 4012,
#   'product_id': 10032,
#   'quantity': 5,
#   'unit_price_cents': 8676},
#  {'id': 3321,
#   'order_id': 4012,
#   'product_id': 10033,
#   'quantity': 1,
#   'unit_price_cents': 6336},
#  {'id': 3322,
#   'order_id': 4012,
#   'product_id': 10034,
#   'quantity': 4,
#   'unit_price_cents': 3615},
#  {'id': 3323,
#   'order_id': 4012,
#   'product_id': 10035,
#   'quantity': 1,
#   'unit_price_cents': 9549},
#  {'id': 3324,
#   'order_id': 4012,
#   'product_id': 10036,
#   'quantity': 4,
#   'unit_price_cents': 5715},
#  {'id': 3325,
#   'order_id': 4012,
#   'product_id': 10037,
#   'quantity': 1,
#   'unit_price_cents': 2460},
#  {'id': 3326,
#   'order_id': 4012,
#   'product_id': 10038,
#   'quantity': 4,
#   'unit_price_cents': 3890},
#  {'id': 3327,
#   'order_id': 4012,
#   'product_id': 10039,
#   'quantity': 1,
#   'unit_price_cents': 3763},
#  {'id': 3328,
#   'order_id': 4012,
#   'product_id': 10040,
#   'quantity': 3,
#   'unit_price_cents': 8250},
#  {'id': 3329,
#   'order_id': 4012,
#   'product_id': 10041,
#   'quantity': 2,
#   'unit_price_cents': 7780},
#  {'id': 3330,
#   'order_id': 4012,
#   'product_id': 10042,
#   'quantity': 4,
#   'unit_price_cents': 8841},
#  {'id': 3331,
#   'order_id': 4012,
#   'product_id': 10043,
#   'quantity': 5,
#   'unit_price_cents': 2772},
#  {'id': 3332,
#   'order_id': 4012,
#   'product_id': 10044,
#   'quantity': 4,
#   'unit_price_cents': 3345},
#  {'id': 3333,
#   'order_id': 4012,
#   'product_id': 10045,
#   'quantity': 3,
#   'unit_price_cents': 1080},
#  {'id': 3334,
#   'order_id': 4012,
#   'product_id': 10046,
#   'quantity': 4,
#   'unit_price_cents': 8125},
#  {'id': 3335,
#   'order_id': 4012,
#   'product_id': 10047,
#   'quantity': 4,
#   'unit_price_cents': 8150},
#  {'id': 3336,
#   'order_id': 4012,
#   'product_id': 10048,
#   'quantity': 5,
#   'unit_price_cents': 8422},
#  {'id': 3337,
#   'order_id': 4012,
#   'product_id': 10049,
#   'quantity': 1,
#   'unit_price_cents': 9192},
#  {'id': 3338,
#   'order_id': 4012,
#   'product_id': 10050,
#   'quantity': 5,
#   'unit_price_cents': 321},
#  {'id': 3339,
#   'order_id': 4012,
#   'product_id': 10051,
#   'quantity': 2,
#   'unit_price_cents': 3652},
#  {'id': 3340,
#   'order_id': 4012,
#   'product_id': 10052,
#   'quantity': 5,
#   'unit_price_cents': 9734},
#  {'id': 3341,
#   'order_id': 4012,
#   'product_id': 10053,
#   'quantity': 2,
#   'unit_price_cents': 2820},
#  {'id': 3342,
#   'order_id': 4012,
#   'product_id': 10054,
#   'quantity': 2,
#   'unit_price_cents': 8876},
#  {'id': 3343,
#   'order_id': 4012,
#   'product_id': 10055,
#   'quantity': 1,
#   'unit_price_cents': 2931},
#  {'id': 3344,
#   'order_id': 4012,
#   'product_id': 10056,
#   'quantity': 4,
#   'unit_price_cents': 4479},
#  {'id': 3345,
#   'order_id': 4012,
#   'product_id': 10057,
#   'quantity': 3,
#   'unit_price_cents': 8433},
#  {'id': 3346,
#   'order_id': 4012,
#   'product_id': 10058,
#   'quantity': 3,
#   'unit_price_cents': 5477},
#  {'id': 3347,
#   'order_id': 4012,
#   'product_id': 10059,
#   'quantity': 1,
#   'unit_price_cents': 764},
#  {'id': 3348,
#   'order_id': 4012,
#   'product_id': 10060,
#   'quantity': 1,
#   'unit_price_cents': 9866},
#  {'id': 3349,
#   'order_id': 4012,
#   'product_id': 10061,
#   'quantity': 1,
#   'unit_price_cents': 7250},
#  {'id': 3350,
#   'order_id': 4012,
#   'product_id': 10062,
#   'quantity': 2,
#   'unit_price_cents': 8056},
#  {'id': 3351,
#   'order_id': 4012,
#   'product_id': 10063,
#   'quantity': 5,
#   'unit_price_cents': 1675},
#  {'id': 3352,
#   'order_id': 4012,
#   'product_id': 10064,
#   'quantity': 3,
#   'unit_price_cents': 4413},
#  {'id': 3353,
#   'order_id': 4012,
#   'product_id': 10065,
#   'quantity': 4,
#   'unit_price_cents': 1528},
#  {'id': 3354,
#   'order_id': 4012,
#   'product_id': 10066,
#   'quantity': 3,
#   'unit_price_cents': 1495},
#  {'id': 3355,
#   'order_id': 4012,
#   'product_id': 10067,
#   'quantity': 3,
#   'unit_price_cents': 9648},
#  {'id': 3356,
#   'order_id': 4012,
#   'product_id': 10068,
#   'quantity': 4,
#   'unit_price_cents': 2360},
#  {'id': 3357,
#   'order_id': 4012,
#   'product_id': 10069,
#   'quantity': 2,
#   'unit_price_cents': 4675},
#  {'id': 3358,
#   'order_id': 4012,
#   'product_id': 10070,
#   'quantity': 5,
#   'unit_price_cents': 3779},
#  {'id': 3359,
#   'order_id': 4012,
#   'product_id': 10071,
#   'quantity': 3,
#   'unit_price_cents': 1149},
#  {'id': 3360,
#   'order_id': 4012,
#   'product_id': 10072,
#   'quantity': 1,
#   'unit_price_cents': 4126},
#  {'id': 3361,
#   'order_id': 4012,
#   'product_id': 10073,
#   'quantity': 1,
#   'unit_price_cents': 3693},
#  {'id': 3362,
#   'order_id': 4012,
#   'product_id': 10074,
#   'quantity': 5,
#   'unit_price_cents': 8275},
#  {'id': 3363,
#   'order_id': 4012,
#   'product_id': 10075,
#   'quantity': 5,
#   'unit_price_cents': 2571},
#  {'id': 3364,
#   'order_id': 4012,
#   'product_id': 10076,
#   'quantity': 3,
#   'unit_price_cents': 9610},
#  {'id': 3365,
#   'order_id': 4012,
#   'product_id': 10077,
#   'quantity': 1,
#   'unit_price_cents': 3120},
#  {'id': 3366,
#   'order_id': 4012,
#   'product_id': 10078,
#   'quantity': 3,
#   'unit_price_cents': 5340},
#  {'id': 3367,
#   'order_id': 4012,
#   'product_id': 10079,
#   'quantity': 3,
#   'unit_price_cents': 6112},
#  {'id': 3368,
#   'order_id': 4012,
#   'product_id': 10080,
#   'quantity': 4,
#   'unit_price_cents': 7618},
#  {'id': 3369,
#   'order_id': 4012,
#   'product_id': 10081,
#   'quantity': 2,
#   'unit_price_cents': 4286},
#  {'id': 3370,
#   'order_id': 4012,
#   'product_id': 10082,
#   'quantity': 1,
#   'unit_price_cents': 954},
#  {'id': 3371,
#   'order_id': 4012,
#   'product_id': 10083,
#   'quantity': 2,
#   'unit_price_cents': 5573},
#  {'id': 3372,
#   'order_id': 4012,
#   'product_id': 10084,
#   'quantity': 2,
#   'unit_price_cents': 5717},
#  {'id': 3373,
#   'order_id': 4012,
#   'product_id': 10085,
#   'quantity': 4,
#   'unit_price_cents': 9082},
#  {'id': 3374,
#   'order_id': 4012,
#   'product_id': 10086,
#   'quantity': 5,
#   'unit_price_cents': 4593},
#  {'id': 3375,
#   'order_id': 4012,
#   'product_id': 10087,
#   'quantity': 2,
#   'unit_price_cents': 7194},
#  {'id': 3376,
#   'order_id': 4012,
#   'product_id': 10088,
#   'quantity': 4,
#   'unit_price_cents': 6849},
#  {'id': 3377,
#   'order_id': 4012,
#   'product_id': 10089,
#   'quantity': 2,
#   'unit_price_cents': 9273},
#  {'id': 3378,
#   'order_id': 4012,
#   'product_id': 10090,
#   'quantity': 5,
#   'unit_price_cents': 4728},
#  {'id': 3379,
#   'order_id': 4012,
#   'product_id': 10091,
#   'quantity': 5,
#   'unit_price_cents': 3885},
#  {'id': 3380,
#   'order_id': 4012,
#   'product_id': 10092,
#   'quantity': 3,
#   'unit_price_cents': 6162},
#  {'id': 3381,
#   'order_id': 4012,
#   'product_id': 10093,
#   'quantity': 3,
#   'unit_price_cents': 9391},
#  {'id': 3382,
#   'order_id': 4012,
#   'product_id': 10094,
#   'quantity': 1,
#   'unit_price_cents': 3475},
#  {'id': 3383,
#   'order_id': 4012,
#   'product_id': 10095,
#   'quantity': 4,
#   'unit_price_cents': 1661},
#  {'id': 3384,
#   'order_id': 4012,
#   'product_id': 10096,
#   'quantity': 3,
#   'unit_price_cents': 7886},
#  {'id': 3385,
#   'order_id': 4012,
#   'product_id': 10097,
#   'quantity': 5,
#   'unit_price_cents': 7622},
#  {'id': 3386,
#   'order_id': 4012,
#   'product_id': 10098,
#   'quantity': 4,
#   'unit_price_cents': 4706},
#  {'id': 3387,
#   'order_id': 4012,
#   'product_id': 10099,
#   'quantity': 3,
#   'unit_price_cents': 2062},
#  {'id': 3388,
#   'order_id': 4012,
#   'product_id': 10100,
#   'quantity': 3,
#   'unit_price_cents': 6617},
#  {'id': 3389,
#   'order_id': 4012,
#   'product_id': 10101,
#   'quantity': 1,
#   'unit_price_cents': 659},
#  {'id': 3390,
#   'order_id': 4012,
#   'product_id': 10102,
#   'quantity': 5,
#   'unit_price_cents': 1205},
#  {'id': 3391,
#   'order_id': 4012,
#   'product_id': 10103,
#   'quantity': 4,
#   'unit_price_cents': 6907},
#  {'id': 3392,
#   'order_id': 4012,
#   'product_id': 10104,
#   'quantity': 1,
#   'unit_price_cents': 7726},
#  {'id': 3393,
#   'order_id': 4012,
#   'product_id': 10105,
#   'quantity': 4,
#   'unit_price_cents': 9512},
#  {'id': 3394,
#   'order_id': 4012,
#   'product_id': 10106,
#   'quantity': 2,
#   'unit_price_cents': 707},
#  {'id': 3395,
#   'order_id': 4012,
#   'product_id': 10107,
#   'quantity': 5,
#   'unit_price_cents': 5991},
#  {'id': 3396,
#   'order_id': 4012,
#   'product_id': 10108,
#   'quantity': 2,
#   'unit_price_cents': 6324},
#  {'id': 3397,
#   'order_id': 4012,
#   'product_id': 10109,
#   'quantity': 2,
#   'unit_price_cents': 3624},
#  {'id': 3398,
#   'order_id': 4012,
#   'product_id': 10110,
#   'quantity': 1,
#   'unit_price_cents': 3172},
#  {'id': 3399,
#   'order_id': 4012,
#   'product_id': 10111,
#   'quantity': 1,
#   'unit_price_cents': 9503},
#  {'id': 3400,
#   'order_id': 4012,
#   'product_id': 10112,
#   'quantity': 4,
#   'unit_price_cents': 1142},
#  {'id': 3401,
#   'order_id': 4012,
#   'product_id': 10113,
#   'quantity': 2,
#   'unit_price_cents': 5684},
#  {'id': 3402,
#   'order_id': 4012,
#   'product_id': 10114,
#   'quantity': 5,
#   'unit_price_cents': 8397},
#  {'id': 3403,
#   'order_id': 4012,
#   'product_id': 10115,
#   'quantity': 5,
#   'unit_price_cents': 3888},
#  {'id': 3404,
#   'order_id': 4012,
#   'product_id': 10116,
#   'quantity': 1,
#   'unit_price_cents': 9431},
#  {'id': 3405,
#   'order_id': 4012,
#   'product_id': 10117,
#   'quantity': 2,
#   'unit_price_cents': 5514},
#  {'id': 3406,
#   'order_id': 4012,
#   'product_id': 10118,
#   'quantity': 2,
#   'unit_price_cents': 7240},
#  {'id': 3407,
#   'order_id': 4012,
#   'product_id': 10119,
#   'quantity': 4,
#   'unit_price_cents': 4873},
#  {'id': 3408,
#   'order_id': 4012,
#   'product_id': 10120,
#   'quantity': 3,
#   'unit_price_cents': 8929},
#  {'id': 3409,
#   'order_id': 4012,
#   'product_id': 10121,
#   'quantity': 3,
#   'unit_price_cents': 6021},
#  {'id': 3410,
#   'order_id': 4012,
#   'product_id': 10122,
#   'quantity': 5,
#   'unit_price_cents': 6907},
#  {'id': 3411,
#   'order_id': 4012,
#   'product_id': 10123,
#   'quantity': 3,
#   'unit_price_cents': 963},
#  {'id': 3412,
#   'order_id': 4012,
#   'product_id': 10124,
#   'quantity': 1,
#   'unit_price_cents': 3353},
#  {'id': 3413,
#   'order_id': 4012,
#   'product_id': 10125,
#   'quantity': 5,
#   'unit_price_cents': 2579},
#  {'id': 3414,
#   'order_id': 4012,
#   'product_id': 10126,
#   'quantity': 1,
#   'unit_price_cents': 491},
#  {'id': 3415,
#   'order_id': 4012,
#   'product_id': 10127,
#   'quantity': 3,
#   'unit_price_cents': 6550},
#  {'id': 3416,
#   'order_id': 4012,
#   'product_id': 10128,
#   'quantity': 2,
#   'unit_price_cents': 2723},
#  {'id': 3417,
#   'order_id': 4012,
#   'product_id': 10129,
#   'quantity': 3,
#   'unit_price_cents': 584},
#  {'id': 3418,
#   'order_id': 4012,
#   'product_id': 10130,
#   'quantity': 2,
#   'unit_price_cents': 1509}]

# %% [markdown]
# ## Step 5 - Check `/orders/pending-totals` includes this order with the right total

# %%
resp = requests.get(f"{BASE_URL}/orders/pending-totals")
assert resp.status_code == 200, resp.text
pending_totals = resp.json()
mine = next((row for row in pending_totals if row["order_id"] == order["id"]), None)
assert mine is not None, "order missing from pending-totals"
assert int(mine["total_cents"]) == expected_total_cents, (
    f"total mismatch: expected {expected_total_cents}, got {mine['total_cents']}"
)
print("Pending total row for this order:", mine)
# Out:
# Pending total row for this order: {'order_id': 4012, 'email': 'fleonard@example.com', 'status': 'pending', 'total_cents': '6474583'}

# %% [markdown]
# ## Step 6 - Customer's order list shows this order

# %%
resp = requests.get(f"{BASE_URL}/customers/{customer['id']}/orders")
assert resp.status_code == 200, resp.text
customer_orders = resp.json()
assert any(o["id"] == order["id"] for o in customer_orders)
print("Customer orders:", customer_orders)
# Out:
# Customer orders: [{'id': 4012, 'customer_id': 553, 'status': 'pending', 'created_at': '2026-09-03T13:40:02.176Z'}]

# %% [markdown]
# ## Step 7 - Warehouse ships the order (`pending -> shipped`)

# %%
resp = requests.patch(f"{BASE_URL}/orders/{order['id']}", json={"status": "shipped"})
assert resp.status_code == 200, resp.text
order = resp.json()
assert order["status"] == "shipped"
print("Order after shipping:", order)
# Out:
# Order after shipping: {'id': 4012, 'customer_id': 553, 'status': 'shipped', 'created_at': '2026-09-03T13:40:02.176Z'}

# %% [markdown]
# ## Step 8 - Order is delivered (`shipped -> delivered`)

# %%
resp = requests.patch(f"{BASE_URL}/orders/{order['id']}", json={"status": "delivered"})
assert resp.status_code == 200, resp.text
order = resp.json()
assert order["status"] == "delivered"
print("Order after delivery:", order)
# Out:
# Order after delivery: {'id': 4012, 'customer_id': 553, 'status': 'delivered', 'created_at': '2026-09-03T13:40:02.176Z'}

# %% [markdown]
# ## Step 9 - `/orders/pending-totals` no longer includes this order

# %%
resp = requests.get(f"{BASE_URL}/orders/pending-totals")
assert resp.status_code == 200, resp.text
pending_totals = resp.json()
assert all(row["order_id"] != order["id"] for row in pending_totals), (
    "delivered order should not appear in pending-totals"
)
print("Confirmed delivered order is excluded from pending-totals")
print(f"Checkout flow complete for customer {customer['id']}, order {order['id']}")
# Out:
# Confirmed delivered order is excluded from pending-totals
# Checkout flow complete for customer 553, order 4012
