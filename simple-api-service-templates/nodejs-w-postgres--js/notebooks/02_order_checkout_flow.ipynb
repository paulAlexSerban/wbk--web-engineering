# %% [markdown]
# # Path 2: Order checkout flow (happy path)
#
# Simulates a single customer's end-to-end shopping journey:
#
# `signup -> create order -> add catalog products as line items -> read order/items -> check pending totals -> ship -> deliver -> re-check totals`
#
# Covers `POST /customers`, `POST /products`, `POST/GET /orders`, `GET /orders/pending-totals`,
# `GET /orders/:id/items`, `PATCH /orders/:id`, `POST/GET /order-items`,
# `GET /customers/:id/orders`.
#
# Run top-to-bottom (e.g. `jupyter nbconvert --to notebook --execute 02_order_checkout_flow.ipynb`).

# %%
import os

import requests
from faker import Faker

BASE_URL = os.environ.get("API_BASE_URL", "http://localhost:3002/api")
fake = Faker()


def fake_product():
    return {
        "sku": f"SKU-{fake.unique.bothify(text='???-####').upper()}",
        "name": fake.unique.catch_phrase(),
        "unit_price_cents": fake.random_int(min=199, max=9999),
    }


def create_product():
    resp = requests.post(f"{BASE_URL}/products", json=fake_product())
    assert resp.status_code == 201, resp.text
    return resp.json()


def fake_order_item(order_id, product):
    return {
        "order_id": order_id,
        "product_id": product["id"],
        "quantity": fake.random_int(min=1, max=5),
        "unit_price_cents": product["unit_price_cents"],
    }


print(f"BASE_URL={BASE_URL}")
# Out:
# BASE_URL=http://api-service:5000/api

# %% [markdown]
# ## Step 1 - A new customer signs up

# %%
resp = requests.post(
    f"{BASE_URL}/customers",
    json={"email": fake.unique.email(), "password": fake.password(length=14)},
)
assert resp.status_code == 201, resp.text
customer = resp.json()
print("Customer:", customer)
# Out:
# Customer: {'id': 107, 'email': 'hmurphy@example.org', 'created_at': '2026-09-24T09:21:52.787Z'}

# %% [markdown]
# ## Step 2 - Customer places a new order (defaults to `pending`)

# %%
resp = requests.post(f"{BASE_URL}/orders", json={"customer_id": customer["id"]})
assert resp.status_code == 201, resp.text
order = resp.json()
assert order["status"] == "pending"
print("Order:", order)
# Out:
# Order: {'id': 8, 'customer_id': 107, 'status': 'pending', 'created_at': '2026-09-24T09:21:52.798Z'}

# %% [markdown]
# ## Step 3 - Create catalog products, then add them as order line items

# %%
PRODUCT_COUNT = int(os.environ.get("PRODUCT_COUNT", "400"))

products = []
order_items = []
for _ in range(PRODUCT_COUNT):
    product = create_product()
    products.append(product)
    resp = requests.post(f"{BASE_URL}/order-items", json=fake_order_item(order["id"], product))
    assert resp.status_code == 201, resp.text
    order_items.append(resp.json())

expected_total_cents = sum(i["quantity"] * i["unit_price_cents"] for i in order_items)
print(f"Added {len(order_items)} line items from {len(products)} catalog products, expected total = {expected_total_cents} cents")
order_items
# Out:
# Added 400 line items from 400 catalog products, expected total = 6220457 cents
# [{'id': 12,
#   'order_id': 8,
#   'product_id': 185,
#   'quantity': 5,
#   'unit_price_cents': 9182},
#  {'id': 13,
#   'order_id': 8,
#   'product_id': 186,
#   'quantity': 4,
#   'unit_price_cents': 2226},
#  {'id': 14,
#   'order_id': 8,
#   'product_id': 187,
#   'quantity': 1,
#   'unit_price_cents': 6577},
#  {'id': 15,
#   'order_id': 8,
#   'product_id': 188,
#   'quantity': 5,
#   'unit_price_cents': 9208},
#  {'id': 16,
#   'order_id': 8,
#   'product_id': 189,
#   'quantity': 2,
#   'unit_price_cents': 1347},
#  {'id': 17,
#   'order_id': 8,
#   'product_id': 190,
#   'quantity': 3,
#   'unit_price_cents': 1931},
#  {'id': 18,
#   'order_id': 8,
#   'product_id': 191,
#   'quantity': 3,
#   'unit_price_cents': 1683},
#  {'id': 19,
#   'order_id': 8,
#   'product_id': 192,
#   'quantity': 3,
#   'unit_price_cents': 7513},
#  {'id': 20,
#   'order_id': 8,
#   'product_id': 193,
#   'quantity': 4,
#   'unit_price_cents': 6653},
#  {'id': 21,
#   'order_id': 8,
#   'product_id': 194,
#   'quantity': 4,
#   'unit_price_cents': 8921},
#  {'id': 22,
#   'order_id': 8,
#   'product_id': 195,
#   'quantity': 1,
#   'unit_price_cents': 5247},
#  {'id': 23,
#   'order_id': 8,
#   'product_id': 196,
#   'quantity': 4,
#   'unit_price_cents': 9442},
#  {'id': 24,
#   'order_id': 8,
#   'product_id': 197,
#   'quantity': 3,
#   'unit_price_cents': 5995},
#  {'id': 25,
#   'order_id': 8,
#   'product_id': 198,
#   'quantity': 3,
#   'unit_price_cents': 5252},
#  {'id': 26,
#   'order_id': 8,
#   'product_id': 199,
#   'quantity': 4,
#   'unit_price_cents': 2349},
#  {'id': 27,
#   'order_id': 8,
#   'product_id': 200,
#   'quantity': 5,
#   'unit_price_cents': 8490},
#  {'id': 28,
#   'order_id': 8,
#   'product_id': 201,
#   'quantity': 4,
#   'unit_price_cents': 8880},
#  {'id': 29,
#   'order_id': 8,
#   'product_id': 202,
#   'quantity': 3,
#   'unit_price_cents': 9323},
#  {'id': 30,
#   'order_id': 8,
#   'product_id': 203,
#   'quantity': 3,
#   'unit_price_cents': 8982},
#  {'id': 31,
#   'order_id': 8,
#   'product_id': 204,
#   'quantity': 1,
#   'unit_price_cents': 3129},
#  {'id': 32,
#   'order_id': 8,
#   'product_id': 205,
#   'quantity': 5,
#   'unit_price_cents': 4384},
#  {'id': 33,
#   'order_id': 8,
#   'product_id': 206,
#   'quantity': 3,
#   'unit_price_cents': 486},
#  {'id': 34,
#   'order_id': 8,
#   'product_id': 207,
#   'quantity': 5,
#   'unit_price_cents': 9706},
#  {'id': 35,
#   'order_id': 8,
#   'product_id': 208,
#   'quantity': 2,
#   'unit_price_cents': 9267},
#  {'id': 36,
#   'order_id': 8,
#   'product_id': 209,
#   'quantity': 1,
#   'unit_price_cents': 5338},
#  {'id': 37,
#   'order_id': 8,
#   'product_id': 210,
#   'quantity': 2,
#   'unit_price_cents': 4993},
#  {'id': 38,
#   'order_id': 8,
#   'product_id': 211,
#   'quantity': 5,
#   'unit_price_cents': 2515},
#  {'id': 39,
#   'order_id': 8,
#   'product_id': 212,
#   'quantity': 2,
#   'unit_price_cents': 9087},
#  {'id': 40,
#   'order_id': 8,
#   'product_id': 213,
#   'quantity': 2,
#   'unit_price_cents': 6886},
#  {'id': 41,
#   'order_id': 8,
#   'product_id': 214,
#   'quantity': 1,
#   'unit_price_cents': 4934},
#  {'id': 42,
#   'order_id': 8,
#   'product_id': 215,
#   'quantity': 3,
#   'unit_price_cents': 2942},
#  {'id': 43,
#   'order_id': 8,
#   'product_id': 216,
#   'quantity': 4,
#   'unit_price_cents': 1790},
#  {'id': 44,
#   'order_id': 8,
#   'product_id': 217,
#   'quantity': 2,
#   'unit_price_cents': 7111},
#  {'id': 45,
#   'order_id': 8,
#   'product_id': 218,
#   'quantity': 1,
#   'unit_price_cents': 2394},
#  {'id': 46,
#   'order_id': 8,
#   'product_id': 219,
#   'quantity': 3,
#   'unit_price_cents': 2697},
#  {'id': 47,
#   'order_id': 8,
#   'product_id': 220,
#   'quantity': 2,
#   'unit_price_cents': 4784},
#  {'id': 48,
#   'order_id': 8,
#   'product_id': 221,
#   'quantity': 4,
#   'unit_price_cents': 6413},
#  {'id': 49,
#   'order_id': 8,
#   'product_id': 222,
#   'quantity': 4,
#   'unit_price_cents': 577},
#  {'id': 50,
#   'order_id': 8,
#   'product_id': 223,
#   'quantity': 2,
#   'unit_price_cents': 4189},
#  {'id': 51,
#   'order_id': 8,
#   'product_id': 224,
#   'quantity': 4,
#   'unit_price_cents': 9994},
#  {'id': 52,
#   'order_id': 8,
#   'product_id': 225,
#   'quantity': 2,
#   'unit_price_cents': 8767},
#  {'id': 53,
#   'order_id': 8,
#   'product_id': 226,
#   'quantity': 4,
#   'unit_price_cents': 7920},
#  {'id': 54,
#   'order_id': 8,
#   'product_id': 227,
#   'quantity': 1,
#   'unit_price_cents': 1229},
#  {'id': 55,
#   'order_id': 8,
#   'product_id': 228,
#   'quantity': 1,
#   'unit_price_cents': 2407},
#  {'id': 56,
#   'order_id': 8,
#   'product_id': 229,
#   'quantity': 2,
#   'unit_price_cents': 455},
#  {'id': 57,
#   'order_id': 8,
#   'product_id': 230,
#   'quantity': 1,
#   'unit_price_cents': 6269},
#  {'id': 58,
#   'order_id': 8,
#   'product_id': 231,
#   'quantity': 2,
#   'unit_price_cents': 8772},
#  {'id': 59,
#   'order_id': 8,
#   'product_id': 232,
#   'quantity': 2,
#   'unit_price_cents': 2899},
#  {'id': 60,
#   'order_id': 8,
#   'product_id': 233,
#   'quantity': 2,
#   'unit_price_cents': 8420},
#  {'id': 61,
#   'order_id': 8,
#   'product_id': 234,
#   'quantity': 3,
#   'unit_price_cents': 3893},
#  {'id': 62,
#   'order_id': 8,
#   'product_id': 235,
#   'quantity': 4,
#   'unit_price_cents': 7385},
#  {'id': 63,
#   'order_id': 8,
#   'product_id': 236,
#   'quantity': 3,
#   'unit_price_cents': 8608},
#  {'id': 64,
#   'order_id': 8,
#   'product_id': 237,
#   'quantity': 4,
#   'unit_price_cents': 617},
#  {'id': 65,
#   'order_id': 8,
#   'product_id': 238,
#   'quantity': 1,
#   'unit_price_cents': 2582},
#  {'id': 66,
#   'order_id': 8,
#   'product_id': 239,
#   'quantity': 3,
#   'unit_price_cents': 3911},
#  {'id': 67,
#   'order_id': 8,
#   'product_id': 240,
#   'quantity': 5,
#   'unit_price_cents': 3403},
#  {'id': 68,
#   'order_id': 8,
#   'product_id': 241,
#   'quantity': 2,
#   'unit_price_cents': 2831},
#  {'id': 69,
#   'order_id': 8,
#   'product_id': 242,
#   'quantity': 2,
#   'unit_price_cents': 8965},
#  {'id': 70,
#   'order_id': 8,
#   'product_id': 243,
#   'quantity': 2,
#   'unit_price_cents': 8251},
#  {'id': 71,
#   'order_id': 8,
#   'product_id': 244,
#   'quantity': 4,
#   'unit_price_cents': 5211},
#  {'id': 72,
#   'order_id': 8,
#   'product_id': 245,
#   'quantity': 5,
#   'unit_price_cents': 2744},
#  {'id': 73,
#   'order_id': 8,
#   'product_id': 246,
#   'quantity': 4,
#   'unit_price_cents': 2704},
#  {'id': 74,
#   'order_id': 8,
#   'product_id': 247,
#   'quantity': 1,
#   'unit_price_cents': 1444},
#  {'id': 75,
#   'order_id': 8,
#   'product_id': 248,
#   'quantity': 4,
#   'unit_price_cents': 1306},
#  {'id': 76,
#   'order_id': 8,
#   'product_id': 249,
#   'quantity': 4,
#   'unit_price_cents': 1428},
#  {'id': 77,
#   'order_id': 8,
#   'product_id': 250,
#   'quantity': 5,
#   'unit_price_cents': 4983},
#  {'id': 78,
#   'order_id': 8,
#   'product_id': 251,
#   'quantity': 4,
#   'unit_price_cents': 4416},
#  {'id': 79,
#   'order_id': 8,
#   'product_id': 252,
#   'quantity': 1,
#   'unit_price_cents': 7789},
#  {'id': 80,
#   'order_id': 8,
#   'product_id': 253,
#   'quantity': 2,
#   'unit_price_cents': 309},
#  {'id': 81,
#   'order_id': 8,
#   'product_id': 254,
#   'quantity': 5,
#   'unit_price_cents': 1344},
#  {'id': 82,
#   'order_id': 8,
#   'product_id': 255,
#   'quantity': 4,
#   'unit_price_cents': 6621},
#  {'id': 83,
#   'order_id': 8,
#   'product_id': 256,
#   'quantity': 5,
#   'unit_price_cents': 9792},
#  {'id': 84,
#   'order_id': 8,
#   'product_id': 257,
#   'quantity': 1,
#   'unit_price_cents': 865},
#  {'id': 85,
#   'order_id': 8,
#   'product_id': 258,
#   'quantity': 1,
#   'unit_price_cents': 4018},
#  {'id': 86,
#   'order_id': 8,
#   'product_id': 259,
#   'quantity': 1,
#   'unit_price_cents': 9177},
#  {'id': 87,
#   'order_id': 8,
#   'product_id': 260,
#   'quantity': 4,
#   'unit_price_cents': 4958},
#  {'id': 88,
#   'order_id': 8,
#   'product_id': 261,
#   'quantity': 4,
#   'unit_price_cents': 7177},
#  {'id': 89,
#   'order_id': 8,
#   'product_id': 262,
#   'quantity': 3,
#   'unit_price_cents': 3937},
#  {'id': 90,
#   'order_id': 8,
#   'product_id': 263,
#   'quantity': 3,
#   'unit_price_cents': 2353},
#  {'id': 91,
#   'order_id': 8,
#   'product_id': 264,
#   'quantity': 3,
#   'unit_price_cents': 614},
#  {'id': 92,
#   'order_id': 8,
#   'product_id': 265,
#   'quantity': 3,
#   'unit_price_cents': 6166},
#  {'id': 93,
#   'order_id': 8,
#   'product_id': 266,
#   'quantity': 4,
#   'unit_price_cents': 7844},
#  {'id': 94,
#   'order_id': 8,
#   'product_id': 267,
#   'quantity': 1,
#   'unit_price_cents': 2916},
#  {'id': 95,
#   'order_id': 8,
#   'product_id': 268,
#   'quantity': 3,
#   'unit_price_cents': 8728},
#  {'id': 96,
#   'order_id': 8,
#   'product_id': 269,
#   'quantity': 5,
#   'unit_price_cents': 4003},
#  {'id': 97,
#   'order_id': 8,
#   'product_id': 270,
#   'quantity': 5,
#   'unit_price_cents': 4846},
#  {'id': 98,
#   'order_id': 8,
#   'product_id': 271,
#   'quantity': 3,
#   'unit_price_cents': 5329},
#  {'id': 99,
#   'order_id': 8,
#   'product_id': 272,
#   'quantity': 4,
#   'unit_price_cents': 4699},
#  {'id': 100,
#   'order_id': 8,
#   'product_id': 273,
#   'quantity': 1,
#   'unit_price_cents': 4094},
#  {'id': 101,
#   'order_id': 8,
#   'product_id': 274,
#   'quantity': 2,
#   'unit_price_cents': 4686},
#  {'id': 102,
#   'order_id': 8,
#   'product_id': 275,
#   'quantity': 4,
#   'unit_price_cents': 8823},
#  {'id': 103,
#   'order_id': 8,
#   'product_id': 276,
#   'quantity': 5,
#   'unit_price_cents': 586},
#  {'id': 104,
#   'order_id': 8,
#   'product_id': 277,
#   'quantity': 1,
#   'unit_price_cents': 3692},
#  {'id': 105,
#   'order_id': 8,
#   'product_id': 278,
#   'quantity': 4,
#   'unit_price_cents': 6094},
#  {'id': 106,
#   'order_id': 8,
#   'product_id': 279,
#   'quantity': 3,
#   'unit_price_cents': 8004},
#  {'id': 107,
#   'order_id': 8,
#   'product_id': 280,
#   'quantity': 3,
#   'unit_price_cents': 7531},
#  {'id': 108,
#   'order_id': 8,
#   'product_id': 281,
#   'quantity': 5,
#   'unit_price_cents': 788},
#  {'id': 109,
#   'order_id': 8,
#   'product_id': 282,
#   'quantity': 4,
#   'unit_price_cents': 5977},
#  {'id': 110,
#   'order_id': 8,
#   'product_id': 283,
#   'quantity': 1,
#   'unit_price_cents': 6815},
#  {'id': 111,
#   'order_id': 8,
#   'product_id': 284,
#   'quantity': 2,
#   'unit_price_cents': 7387},
#  {'id': 112,
#   'order_id': 8,
#   'product_id': 285,
#   'quantity': 2,
#   'unit_price_cents': 6634},
#  {'id': 113,
#   'order_id': 8,
#   'product_id': 286,
#   'quantity': 5,
#   'unit_price_cents': 4719},
#  {'id': 114,
#   'order_id': 8,
#   'product_id': 287,
#   'quantity': 2,
#   'unit_price_cents': 3933},
#  {'id': 115,
#   'order_id': 8,
#   'product_id': 288,
#   'quantity': 5,
#   'unit_price_cents': 327},
#  {'id': 116,
#   'order_id': 8,
#   'product_id': 289,
#   'quantity': 5,
#   'unit_price_cents': 454},
#  {'id': 117,
#   'order_id': 8,
#   'product_id': 290,
#   'quantity': 1,
#   'unit_price_cents': 776},
#  {'id': 118,
#   'order_id': 8,
#   'product_id': 291,
#   'quantity': 2,
#   'unit_price_cents': 5496},
#  {'id': 119,
#   'order_id': 8,
#   'product_id': 292,
#   'quantity': 5,
#   'unit_price_cents': 8620},
#  {'id': 120,
#   'order_id': 8,
#   'product_id': 293,
#   'quantity': 5,
#   'unit_price_cents': 1167},
#  {'id': 121,
#   'order_id': 8,
#   'product_id': 294,
#   'quantity': 1,
#   'unit_price_cents': 1097},
#  {'id': 122,
#   'order_id': 8,
#   'product_id': 295,
#   'quantity': 3,
#   'unit_price_cents': 1299},
#  {'id': 123,
#   'order_id': 8,
#   'product_id': 296,
#   'quantity': 3,
#   'unit_price_cents': 4084},
#  {'id': 124,
#   'order_id': 8,
#   'product_id': 297,
#   'quantity': 1,
#   'unit_price_cents': 8746},
#  {'id': 125,
#   'order_id': 8,
#   'product_id': 298,
#   'quantity': 1,
#   'unit_price_cents': 3774},
#  {'id': 126,
#   'order_id': 8,
#   'product_id': 299,
#   'quantity': 3,
#   'unit_price_cents': 6894},
#  {'id': 127,
#   'order_id': 8,
#   'product_id': 300,
#   'quantity': 3,
#   'unit_price_cents': 7325},
#  {'id': 128,
#   'order_id': 8,
#   'product_id': 301,
#   'quantity': 2,
#   'unit_price_cents': 2692},
#  {'id': 129,
#   'order_id': 8,
#   'product_id': 302,
#   'quantity': 5,
#   'unit_price_cents': 1456},
#  {'id': 130,
#   'order_id': 8,
#   'product_id': 303,
#   'quantity': 2,
#   'unit_price_cents': 5313},
#  {'id': 131,
#   'order_id': 8,
#   'product_id': 304,
#   'quantity': 5,
#   'unit_price_cents': 9424},
#  {'id': 132,
#   'order_id': 8,
#   'product_id': 305,
#   'quantity': 1,
#   'unit_price_cents': 3987},
#  {'id': 133,
#   'order_id': 8,
#   'product_id': 306,
#   'quantity': 2,
#   'unit_price_cents': 5258},
#  {'id': 134,
#   'order_id': 8,
#   'product_id': 307,
#   'quantity': 4,
#   'unit_price_cents': 301},
#  {'id': 135,
#   'order_id': 8,
#   'product_id': 308,
#   'quantity': 5,
#   'unit_price_cents': 7520},
#  {'id': 136,
#   'order_id': 8,
#   'product_id': 309,
#   'quantity': 1,
#   'unit_price_cents': 2387},
#  {'id': 137,
#   'order_id': 8,
#   'product_id': 310,
#   'quantity': 5,
#   'unit_price_cents': 7097},
#  {'id': 138,
#   'order_id': 8,
#   'product_id': 311,
#   'quantity': 2,
#   'unit_price_cents': 8163},
#  {'id': 139,
#   'order_id': 8,
#   'product_id': 312,
#   'quantity': 3,
#   'unit_price_cents': 1989},
#  {'id': 140,
#   'order_id': 8,
#   'product_id': 313,
#   'quantity': 3,
#   'unit_price_cents': 6999},
#  {'id': 141,
#   'order_id': 8,
#   'product_id': 314,
#   'quantity': 2,
#   'unit_price_cents': 853},
#  {'id': 142,
#   'order_id': 8,
#   'product_id': 315,
#   'quantity': 3,
#   'unit_price_cents': 3248},
#  {'id': 143,
#   'order_id': 8,
#   'product_id': 316,
#   'quantity': 5,
#   'unit_price_cents': 3206},
#  {'id': 144,
#   'order_id': 8,
#   'product_id': 317,
#   'quantity': 2,
#   'unit_price_cents': 3414},
#  {'id': 145,
#   'order_id': 8,
#   'product_id': 318,
#   'quantity': 2,
#   'unit_price_cents': 8530},
#  {'id': 146,
#   'order_id': 8,
#   'product_id': 319,
#   'quantity': 1,
#   'unit_price_cents': 3396},
#  {'id': 147,
#   'order_id': 8,
#   'product_id': 320,
#   'quantity': 1,
#   'unit_price_cents': 8255},
#  {'id': 148,
#   'order_id': 8,
#   'product_id': 321,
#   'quantity': 3,
#   'unit_price_cents': 6150},
#  {'id': 149,
#   'order_id': 8,
#   'product_id': 322,
#   'quantity': 2,
#   'unit_price_cents': 2779},
#  {'id': 150,
#   'order_id': 8,
#   'product_id': 323,
#   'quantity': 2,
#   'unit_price_cents': 4754},
#  {'id': 151,
#   'order_id': 8,
#   'product_id': 324,
#   'quantity': 3,
#   'unit_price_cents': 9341},
#  {'id': 152,
#   'order_id': 8,
#   'product_id': 325,
#   'quantity': 5,
#   'unit_price_cents': 3755},
#  {'id': 153,
#   'order_id': 8,
#   'product_id': 326,
#   'quantity': 3,
#   'unit_price_cents': 2774},
#  {'id': 154,
#   'order_id': 8,
#   'product_id': 327,
#   'quantity': 2,
#   'unit_price_cents': 8916},
#  {'id': 155,
#   'order_id': 8,
#   'product_id': 328,
#   'quantity': 5,
#   'unit_price_cents': 3815},
#  {'id': 156,
#   'order_id': 8,
#   'product_id': 329,
#   'quantity': 1,
#   'unit_price_cents': 1220},
#  {'id': 157,
#   'order_id': 8,
#   'product_id': 330,
#   'quantity': 4,
#   'unit_price_cents': 6237},
#  {'id': 158,
#   'order_id': 8,
#   'product_id': 331,
#   'quantity': 2,
#   'unit_price_cents': 1832},
#  {'id': 159,
#   'order_id': 8,
#   'product_id': 332,
#   'quantity': 5,
#   'unit_price_cents': 9564},
#  {'id': 160,
#   'order_id': 8,
#   'product_id': 333,
#   'quantity': 1,
#   'unit_price_cents': 2381},
#  {'id': 161,
#   'order_id': 8,
#   'product_id': 334,
#   'quantity': 4,
#   'unit_price_cents': 8143},
#  {'id': 162,
#   'order_id': 8,
#   'product_id': 335,
#   'quantity': 4,
#   'unit_price_cents': 7453},
#  {'id': 163,
#   'order_id': 8,
#   'product_id': 336,
#   'quantity': 5,
#   'unit_price_cents': 8772},
#  {'id': 164,
#   'order_id': 8,
#   'product_id': 337,
#   'quantity': 2,
#   'unit_price_cents': 6892},
#  {'id': 165,
#   'order_id': 8,
#   'product_id': 338,
#   'quantity': 2,
#   'unit_price_cents': 7961},
#  {'id': 166,
#   'order_id': 8,
#   'product_id': 339,
#   'quantity': 4,
#   'unit_price_cents': 827},
#  {'id': 167,
#   'order_id': 8,
#   'product_id': 340,
#   'quantity': 1,
#   'unit_price_cents': 3130},
#  {'id': 168,
#   'order_id': 8,
#   'product_id': 341,
#   'quantity': 2,
#   'unit_price_cents': 8287},
#  {'id': 169,
#   'order_id': 8,
#   'product_id': 342,
#   'quantity': 4,
#   'unit_price_cents': 9835},
#  {'id': 170,
#   'order_id': 8,
#   'product_id': 343,
#   'quantity': 3,
#   'unit_price_cents': 8004},
#  {'id': 171,
#   'order_id': 8,
#   'product_id': 344,
#   'quantity': 5,
#   'unit_price_cents': 1784},
#  {'id': 172,
#   'order_id': 8,
#   'product_id': 345,
#   'quantity': 2,
#   'unit_price_cents': 3107},
#  {'id': 173,
#   'order_id': 8,
#   'product_id': 346,
#   'quantity': 4,
#   'unit_price_cents': 5473},
#  {'id': 174,
#   'order_id': 8,
#   'product_id': 347,
#   'quantity': 1,
#   'unit_price_cents': 6257},
#  {'id': 175,
#   'order_id': 8,
#   'product_id': 348,
#   'quantity': 5,
#   'unit_price_cents': 7931},
#  {'id': 176,
#   'order_id': 8,
#   'product_id': 349,
#   'quantity': 2,
#   'unit_price_cents': 322},
#  {'id': 177,
#   'order_id': 8,
#   'product_id': 350,
#   'quantity': 1,
#   'unit_price_cents': 8910},
#  {'id': 178,
#   'order_id': 8,
#   'product_id': 351,
#   'quantity': 1,
#   'unit_price_cents': 718},
#  {'id': 179,
#   'order_id': 8,
#   'product_id': 352,
#   'quantity': 4,
#   'unit_price_cents': 8800},
#  {'id': 180,
#   'order_id': 8,
#   'product_id': 353,
#   'quantity': 3,
#   'unit_price_cents': 8361},
#  {'id': 181,
#   'order_id': 8,
#   'product_id': 354,
#   'quantity': 4,
#   'unit_price_cents': 5627},
#  {'id': 182,
#   'order_id': 8,
#   'product_id': 355,
#   'quantity': 4,
#   'unit_price_cents': 9979},
#  {'id': 183,
#   'order_id': 8,
#   'product_id': 356,
#   'quantity': 4,
#   'unit_price_cents': 7796},
#  {'id': 184,
#   'order_id': 8,
#   'product_id': 357,
#   'quantity': 3,
#   'unit_price_cents': 3609},
#  {'id': 185,
#   'order_id': 8,
#   'product_id': 358,
#   'quantity': 1,
#   'unit_price_cents': 3567},
#  {'id': 186,
#   'order_id': 8,
#   'product_id': 359,
#   'quantity': 3,
#   'unit_price_cents': 2570},
#  {'id': 187,
#   'order_id': 8,
#   'product_id': 360,
#   'quantity': 4,
#   'unit_price_cents': 1063},
#  {'id': 188,
#   'order_id': 8,
#   'product_id': 361,
#   'quantity': 2,
#   'unit_price_cents': 8328},
#  {'id': 189,
#   'order_id': 8,
#   'product_id': 362,
#   'quantity': 3,
#   'unit_price_cents': 6470},
#  {'id': 190,
#   'order_id': 8,
#   'product_id': 363,
#   'quantity': 5,
#   'unit_price_cents': 1584},
#  {'id': 191,
#   'order_id': 8,
#   'product_id': 364,
#   'quantity': 3,
#   'unit_price_cents': 9599},
#  {'id': 192,
#   'order_id': 8,
#   'product_id': 365,
#   'quantity': 5,
#   'unit_price_cents': 4635},
#  {'id': 193,
#   'order_id': 8,
#   'product_id': 366,
#   'quantity': 3,
#   'unit_price_cents': 1659},
#  {'id': 194,
#   'order_id': 8,
#   'product_id': 367,
#   'quantity': 2,
#   'unit_price_cents': 8485},
#  {'id': 195,
#   'order_id': 8,
#   'product_id': 368,
#   'quantity': 4,
#   'unit_price_cents': 1934},
#  {'id': 196,
#   'order_id': 8,
#   'product_id': 369,
#   'quantity': 5,
#   'unit_price_cents': 2061},
#  {'id': 197,
#   'order_id': 8,
#   'product_id': 370,
#   'quantity': 1,
#   'unit_price_cents': 3776},
#  {'id': 198,
#   'order_id': 8,
#   'product_id': 371,
#   'quantity': 3,
#   'unit_price_cents': 2244},
#  {'id': 199,
#   'order_id': 8,
#   'product_id': 372,
#   'quantity': 2,
#   'unit_price_cents': 1991},
#  {'id': 200,
#   'order_id': 8,
#   'product_id': 373,
#   'quantity': 5,
#   'unit_price_cents': 9513},
#  {'id': 201,
#   'order_id': 8,
#   'product_id': 374,
#   'quantity': 4,
#   'unit_price_cents': 835},
#  {'id': 202,
#   'order_id': 8,
#   'product_id': 375,
#   'quantity': 2,
#   'unit_price_cents': 7415},
#  {'id': 203,
#   'order_id': 8,
#   'product_id': 376,
#   'quantity': 4,
#   'unit_price_cents': 5838},
#  {'id': 204,
#   'order_id': 8,
#   'product_id': 377,
#   'quantity': 1,
#   'unit_price_cents': 4654},
#  {'id': 205,
#   'order_id': 8,
#   'product_id': 378,
#   'quantity': 1,
#   'unit_price_cents': 9945},
#  {'id': 206,
#   'order_id': 8,
#   'product_id': 379,
#   'quantity': 2,
#   'unit_price_cents': 5162},
#  {'id': 207,
#   'order_id': 8,
#   'product_id': 380,
#   'quantity': 2,
#   'unit_price_cents': 1163},
#  {'id': 208,
#   'order_id': 8,
#   'product_id': 381,
#   'quantity': 4,
#   'unit_price_cents': 3753},
#  {'id': 209,
#   'order_id': 8,
#   'product_id': 382,
#   'quantity': 1,
#   'unit_price_cents': 7419},
#  {'id': 210,
#   'order_id': 8,
#   'product_id': 383,
#   'quantity': 4,
#   'unit_price_cents': 379},
#  {'id': 211,
#   'order_id': 8,
#   'product_id': 384,
#   'quantity': 5,
#   'unit_price_cents': 5361},
#  {'id': 212,
#   'order_id': 8,
#   'product_id': 385,
#   'quantity': 4,
#   'unit_price_cents': 3912},
#  {'id': 213,
#   'order_id': 8,
#   'product_id': 386,
#   'quantity': 5,
#   'unit_price_cents': 8483},
#  {'id': 214,
#   'order_id': 8,
#   'product_id': 387,
#   'quantity': 1,
#   'unit_price_cents': 4699},
#  {'id': 215,
#   'order_id': 8,
#   'product_id': 388,
#   'quantity': 5,
#   'unit_price_cents': 8239},
#  {'id': 216,
#   'order_id': 8,
#   'product_id': 389,
#   'quantity': 2,
#   'unit_price_cents': 4499},
#  {'id': 217,
#   'order_id': 8,
#   'product_id': 390,
#   'quantity': 5,
#   'unit_price_cents': 5514},
#  {'id': 218,
#   'order_id': 8,
#   'product_id': 391,
#   'quantity': 1,
#   'unit_price_cents': 1707},
#  {'id': 219,
#   'order_id': 8,
#   'product_id': 392,
#   'quantity': 3,
#   'unit_price_cents': 3002},
#  {'id': 220,
#   'order_id': 8,
#   'product_id': 393,
#   'quantity': 5,
#   'unit_price_cents': 8742},
#  {'id': 221,
#   'order_id': 8,
#   'product_id': 394,
#   'quantity': 2,
#   'unit_price_cents': 6090},
#  {'id': 222,
#   'order_id': 8,
#   'product_id': 395,
#   'quantity': 1,
#   'unit_price_cents': 6294},
#  {'id': 223,
#   'order_id': 8,
#   'product_id': 396,
#   'quantity': 2,
#   'unit_price_cents': 2407},
#  {'id': 224,
#   'order_id': 8,
#   'product_id': 397,
#   'quantity': 4,
#   'unit_price_cents': 2433},
#  {'id': 225,
#   'order_id': 8,
#   'product_id': 398,
#   'quantity': 2,
#   'unit_price_cents': 7698},
#  {'id': 226,
#   'order_id': 8,
#   'product_id': 399,
#   'quantity': 1,
#   'unit_price_cents': 4316},
#  {'id': 227,
#   'order_id': 8,
#   'product_id': 400,
#   'quantity': 2,
#   'unit_price_cents': 7197},
#  {'id': 228,
#   'order_id': 8,
#   'product_id': 401,
#   'quantity': 3,
#   'unit_price_cents': 6038},
#  {'id': 229,
#   'order_id': 8,
#   'product_id': 402,
#   'quantity': 3,
#   'unit_price_cents': 6387},
#  {'id': 230,
#   'order_id': 8,
#   'product_id': 403,
#   'quantity': 4,
#   'unit_price_cents': 6753},
#  {'id': 231,
#   'order_id': 8,
#   'product_id': 404,
#   'quantity': 3,
#   'unit_price_cents': 9027},
#  {'id': 232,
#   'order_id': 8,
#   'product_id': 405,
#   'quantity': 1,
#   'unit_price_cents': 8192},
#  {'id': 233,
#   'order_id': 8,
#   'product_id': 406,
#   'quantity': 3,
#   'unit_price_cents': 9780},
#  {'id': 234,
#   'order_id': 8,
#   'product_id': 407,
#   'quantity': 2,
#   'unit_price_cents': 3985},
#  {'id': 235,
#   'order_id': 8,
#   'product_id': 408,
#   'quantity': 5,
#   'unit_price_cents': 5476},
#  {'id': 236,
#   'order_id': 8,
#   'product_id': 409,
#   'quantity': 5,
#   'unit_price_cents': 3583},
#  {'id': 237,
#   'order_id': 8,
#   'product_id': 410,
#   'quantity': 4,
#   'unit_price_cents': 1275},
#  {'id': 238,
#   'order_id': 8,
#   'product_id': 411,
#   'quantity': 5,
#   'unit_price_cents': 8496},
#  {'id': 239,
#   'order_id': 8,
#   'product_id': 412,
#   'quantity': 1,
#   'unit_price_cents': 9574},
#  {'id': 240,
#   'order_id': 8,
#   'product_id': 413,
#   'quantity': 1,
#   'unit_price_cents': 2958},
#  {'id': 241,
#   'order_id': 8,
#   'product_id': 414,
#   'quantity': 3,
#   'unit_price_cents': 2498},
#  {'id': 242,
#   'order_id': 8,
#   'product_id': 415,
#   'quantity': 2,
#   'unit_price_cents': 9165},
#  {'id': 243,
#   'order_id': 8,
#   'product_id': 416,
#   'quantity': 1,
#   'unit_price_cents': 6067},
#  {'id': 244,
#   'order_id': 8,
#   'product_id': 417,
#   'quantity': 1,
#   'unit_price_cents': 8402},
#  {'id': 245,
#   'order_id': 8,
#   'product_id': 418,
#   'quantity': 4,
#   'unit_price_cents': 5690},
#  {'id': 246,
#   'order_id': 8,
#   'product_id': 419,
#   'quantity': 2,
#   'unit_price_cents': 8043},
#  {'id': 247,
#   'order_id': 8,
#   'product_id': 420,
#   'quantity': 2,
#   'unit_price_cents': 1798},
#  {'id': 248,
#   'order_id': 8,
#   'product_id': 421,
#   'quantity': 2,
#   'unit_price_cents': 5288},
#  {'id': 249,
#   'order_id': 8,
#   'product_id': 422,
#   'quantity': 5,
#   'unit_price_cents': 784},
#  {'id': 250,
#   'order_id': 8,
#   'product_id': 423,
#   'quantity': 1,
#   'unit_price_cents': 9298},
#  {'id': 251,
#   'order_id': 8,
#   'product_id': 424,
#   'quantity': 1,
#   'unit_price_cents': 9842},
#  {'id': 252,
#   'order_id': 8,
#   'product_id': 425,
#   'quantity': 2,
#   'unit_price_cents': 7430},
#  {'id': 253,
#   'order_id': 8,
#   'product_id': 426,
#   'quantity': 5,
#   'unit_price_cents': 9607},
#  {'id': 254,
#   'order_id': 8,
#   'product_id': 427,
#   'quantity': 3,
#   'unit_price_cents': 3521},
#  {'id': 255,
#   'order_id': 8,
#   'product_id': 428,
#   'quantity': 2,
#   'unit_price_cents': 6461},
#  {'id': 256,
#   'order_id': 8,
#   'product_id': 429,
#   'quantity': 5,
#   'unit_price_cents': 2364},
#  {'id': 257,
#   'order_id': 8,
#   'product_id': 430,
#   'quantity': 1,
#   'unit_price_cents': 6789},
#  {'id': 258,
#   'order_id': 8,
#   'product_id': 431,
#   'quantity': 3,
#   'unit_price_cents': 5536},
#  {'id': 259,
#   'order_id': 8,
#   'product_id': 432,
#   'quantity': 5,
#   'unit_price_cents': 7664},
#  {'id': 260,
#   'order_id': 8,
#   'product_id': 433,
#   'quantity': 3,
#   'unit_price_cents': 292},
#  {'id': 261,
#   'order_id': 8,
#   'product_id': 434,
#   'quantity': 4,
#   'unit_price_cents': 2181},
#  {'id': 262,
#   'order_id': 8,
#   'product_id': 435,
#   'quantity': 5,
#   'unit_price_cents': 2260},
#  {'id': 263,
#   'order_id': 8,
#   'product_id': 436,
#   'quantity': 3,
#   'unit_price_cents': 619},
#  {'id': 264,
#   'order_id': 8,
#   'product_id': 437,
#   'quantity': 4,
#   'unit_price_cents': 3243},
#  {'id': 265,
#   'order_id': 8,
#   'product_id': 438,
#   'quantity': 5,
#   'unit_price_cents': 9948},
#  {'id': 266,
#   'order_id': 8,
#   'product_id': 439,
#   'quantity': 4,
#   'unit_price_cents': 666},
#  {'id': 267,
#   'order_id': 8,
#   'product_id': 440,
#   'quantity': 2,
#   'unit_price_cents': 5079},
#  {'id': 268,
#   'order_id': 8,
#   'product_id': 441,
#   'quantity': 3,
#   'unit_price_cents': 1595},
#  {'id': 269,
#   'order_id': 8,
#   'product_id': 442,
#   'quantity': 5,
#   'unit_price_cents': 7056},
#  {'id': 270,
#   'order_id': 8,
#   'product_id': 443,
#   'quantity': 2,
#   'unit_price_cents': 2526},
#  {'id': 271,
#   'order_id': 8,
#   'product_id': 444,
#   'quantity': 5,
#   'unit_price_cents': 5536},
#  {'id': 272,
#   'order_id': 8,
#   'product_id': 445,
#   'quantity': 5,
#   'unit_price_cents': 6314},
#  {'id': 273,
#   'order_id': 8,
#   'product_id': 446,
#   'quantity': 1,
#   'unit_price_cents': 9628},
#  {'id': 274,
#   'order_id': 8,
#   'product_id': 447,
#   'quantity': 5,
#   'unit_price_cents': 5605},
#  {'id': 275,
#   'order_id': 8,
#   'product_id': 448,
#   'quantity': 1,
#   'unit_price_cents': 4542},
#  {'id': 276,
#   'order_id': 8,
#   'product_id': 449,
#   'quantity': 5,
#   'unit_price_cents': 4711},
#  {'id': 277,
#   'order_id': 8,
#   'product_id': 450,
#   'quantity': 5,
#   'unit_price_cents': 7378},
#  {'id': 278,
#   'order_id': 8,
#   'product_id': 451,
#   'quantity': 4,
#   'unit_price_cents': 3530},
#  {'id': 279,
#   'order_id': 8,
#   'product_id': 452,
#   'quantity': 4,
#   'unit_price_cents': 1583},
#  {'id': 280,
#   'order_id': 8,
#   'product_id': 453,
#   'quantity': 4,
#   'unit_price_cents': 3724},
#  {'id': 281,
#   'order_id': 8,
#   'product_id': 454,
#   'quantity': 2,
#   'unit_price_cents': 4915},
#  {'id': 282,
#   'order_id': 8,
#   'product_id': 455,
#   'quantity': 2,
#   'unit_price_cents': 8294},
#  {'id': 283,
#   'order_id': 8,
#   'product_id': 456,
#   'quantity': 2,
#   'unit_price_cents': 9473},
#  {'id': 284,
#   'order_id': 8,
#   'product_id': 457,
#   'quantity': 3,
#   'unit_price_cents': 6296},
#  {'id': 285,
#   'order_id': 8,
#   'product_id': 458,
#   'quantity': 5,
#   'unit_price_cents': 314},
#  {'id': 286,
#   'order_id': 8,
#   'product_id': 459,
#   'quantity': 1,
#   'unit_price_cents': 8193},
#  {'id': 287,
#   'order_id': 8,
#   'product_id': 460,
#   'quantity': 5,
#   'unit_price_cents': 9858},
#  {'id': 288,
#   'order_id': 8,
#   'product_id': 461,
#   'quantity': 4,
#   'unit_price_cents': 4154},
#  {'id': 289,
#   'order_id': 8,
#   'product_id': 462,
#   'quantity': 1,
#   'unit_price_cents': 5248},
#  {'id': 290,
#   'order_id': 8,
#   'product_id': 463,
#   'quantity': 1,
#   'unit_price_cents': 9541},
#  {'id': 291,
#   'order_id': 8,
#   'product_id': 464,
#   'quantity': 4,
#   'unit_price_cents': 2621},
#  {'id': 292,
#   'order_id': 8,
#   'product_id': 465,
#   'quantity': 2,
#   'unit_price_cents': 3798},
#  {'id': 293,
#   'order_id': 8,
#   'product_id': 466,
#   'quantity': 3,
#   'unit_price_cents': 8704},
#  {'id': 294,
#   'order_id': 8,
#   'product_id': 467,
#   'quantity': 1,
#   'unit_price_cents': 1985},
#  {'id': 295,
#   'order_id': 8,
#   'product_id': 468,
#   'quantity': 3,
#   'unit_price_cents': 4316},
#  {'id': 296,
#   'order_id': 8,
#   'product_id': 469,
#   'quantity': 5,
#   'unit_price_cents': 4587},
#  {'id': 297,
#   'order_id': 8,
#   'product_id': 470,
#   'quantity': 4,
#   'unit_price_cents': 4651},
#  {'id': 298,
#   'order_id': 8,
#   'product_id': 471,
#   'quantity': 5,
#   'unit_price_cents': 6489},
#  {'id': 299,
#   'order_id': 8,
#   'product_id': 472,
#   'quantity': 1,
#   'unit_price_cents': 3804},
#  {'id': 300,
#   'order_id': 8,
#   'product_id': 473,
#   'quantity': 3,
#   'unit_price_cents': 2497},
#  {'id': 301,
#   'order_id': 8,
#   'product_id': 474,
#   'quantity': 5,
#   'unit_price_cents': 7082},
#  {'id': 302,
#   'order_id': 8,
#   'product_id': 475,
#   'quantity': 2,
#   'unit_price_cents': 2411},
#  {'id': 303,
#   'order_id': 8,
#   'product_id': 476,
#   'quantity': 4,
#   'unit_price_cents': 1488},
#  {'id': 304,
#   'order_id': 8,
#   'product_id': 477,
#   'quantity': 2,
#   'unit_price_cents': 2991},
#  {'id': 305,
#   'order_id': 8,
#   'product_id': 478,
#   'quantity': 4,
#   'unit_price_cents': 7686},
#  {'id': 306,
#   'order_id': 8,
#   'product_id': 479,
#   'quantity': 3,
#   'unit_price_cents': 9505},
#  {'id': 307,
#   'order_id': 8,
#   'product_id': 480,
#   'quantity': 3,
#   'unit_price_cents': 9722},
#  {'id': 308,
#   'order_id': 8,
#   'product_id': 481,
#   'quantity': 3,
#   'unit_price_cents': 5017},
#  {'id': 309,
#   'order_id': 8,
#   'product_id': 482,
#   'quantity': 4,
#   'unit_price_cents': 4815},
#  {'id': 310,
#   'order_id': 8,
#   'product_id': 483,
#   'quantity': 3,
#   'unit_price_cents': 1512},
#  {'id': 311,
#   'order_id': 8,
#   'product_id': 484,
#   'quantity': 5,
#   'unit_price_cents': 7242},
#  {'id': 312,
#   'order_id': 8,
#   'product_id': 485,
#   'quantity': 2,
#   'unit_price_cents': 8498},
#  {'id': 313,
#   'order_id': 8,
#   'product_id': 486,
#   'quantity': 5,
#   'unit_price_cents': 2083},
#  {'id': 314,
#   'order_id': 8,
#   'product_id': 487,
#   'quantity': 2,
#   'unit_price_cents': 4624},
#  {'id': 315,
#   'order_id': 8,
#   'product_id': 488,
#   'quantity': 3,
#   'unit_price_cents': 6055},
#  {'id': 316,
#   'order_id': 8,
#   'product_id': 489,
#   'quantity': 4,
#   'unit_price_cents': 4643},
#  {'id': 317,
#   'order_id': 8,
#   'product_id': 490,
#   'quantity': 3,
#   'unit_price_cents': 1437},
#  {'id': 318,
#   'order_id': 8,
#   'product_id': 491,
#   'quantity': 2,
#   'unit_price_cents': 1478},
#  {'id': 319,
#   'order_id': 8,
#   'product_id': 492,
#   'quantity': 4,
#   'unit_price_cents': 1389},
#  {'id': 320,
#   'order_id': 8,
#   'product_id': 493,
#   'quantity': 3,
#   'unit_price_cents': 9451},
#  {'id': 321,
#   'order_id': 8,
#   'product_id': 494,
#   'quantity': 3,
#   'unit_price_cents': 3908},
#  {'id': 322,
#   'order_id': 8,
#   'product_id': 495,
#   'quantity': 4,
#   'unit_price_cents': 9666},
#  {'id': 323,
#   'order_id': 8,
#   'product_id': 496,
#   'quantity': 2,
#   'unit_price_cents': 1223},
#  {'id': 324,
#   'order_id': 8,
#   'product_id': 497,
#   'quantity': 5,
#   'unit_price_cents': 6207},
#  {'id': 325,
#   'order_id': 8,
#   'product_id': 498,
#   'quantity': 3,
#   'unit_price_cents': 2290},
#  {'id': 326,
#   'order_id': 8,
#   'product_id': 499,
#   'quantity': 4,
#   'unit_price_cents': 3158},
#  {'id': 327,
#   'order_id': 8,
#   'product_id': 500,
#   'quantity': 2,
#   'unit_price_cents': 6961},
#  {'id': 328,
#   'order_id': 8,
#   'product_id': 501,
#   'quantity': 3,
#   'unit_price_cents': 7641},
#  {'id': 329,
#   'order_id': 8,
#   'product_id': 502,
#   'quantity': 4,
#   'unit_price_cents': 2773},
#  {'id': 330,
#   'order_id': 8,
#   'product_id': 503,
#   'quantity': 2,
#   'unit_price_cents': 5908},
#  {'id': 331,
#   'order_id': 8,
#   'product_id': 504,
#   'quantity': 2,
#   'unit_price_cents': 9536},
#  {'id': 332,
#   'order_id': 8,
#   'product_id': 505,
#   'quantity': 4,
#   'unit_price_cents': 8433},
#  {'id': 333,
#   'order_id': 8,
#   'product_id': 506,
#   'quantity': 3,
#   'unit_price_cents': 7211},
#  {'id': 334,
#   'order_id': 8,
#   'product_id': 507,
#   'quantity': 1,
#   'unit_price_cents': 5410},
#  {'id': 335,
#   'order_id': 8,
#   'product_id': 508,
#   'quantity': 3,
#   'unit_price_cents': 219},
#  {'id': 336,
#   'order_id': 8,
#   'product_id': 509,
#   'quantity': 2,
#   'unit_price_cents': 4960},
#  {'id': 337,
#   'order_id': 8,
#   'product_id': 510,
#   'quantity': 1,
#   'unit_price_cents': 1948},
#  {'id': 338,
#   'order_id': 8,
#   'product_id': 511,
#   'quantity': 2,
#   'unit_price_cents': 6821},
#  {'id': 339,
#   'order_id': 8,
#   'product_id': 512,
#   'quantity': 5,
#   'unit_price_cents': 6216},
#  {'id': 340,
#   'order_id': 8,
#   'product_id': 513,
#   'quantity': 3,
#   'unit_price_cents': 9720},
#  {'id': 341,
#   'order_id': 8,
#   'product_id': 514,
#   'quantity': 1,
#   'unit_price_cents': 8332},
#  {'id': 342,
#   'order_id': 8,
#   'product_id': 515,
#   'quantity': 1,
#   'unit_price_cents': 6485},
#  {'id': 343,
#   'order_id': 8,
#   'product_id': 516,
#   'quantity': 2,
#   'unit_price_cents': 7005},
#  {'id': 344,
#   'order_id': 8,
#   'product_id': 517,
#   'quantity': 3,
#   'unit_price_cents': 9169},
#  {'id': 345,
#   'order_id': 8,
#   'product_id': 518,
#   'quantity': 4,
#   'unit_price_cents': 1845},
#  {'id': 346,
#   'order_id': 8,
#   'product_id': 519,
#   'quantity': 1,
#   'unit_price_cents': 504},
#  {'id': 347,
#   'order_id': 8,
#   'product_id': 520,
#   'quantity': 1,
#   'unit_price_cents': 5346},
#  {'id': 348,
#   'order_id': 8,
#   'product_id': 521,
#   'quantity': 1,
#   'unit_price_cents': 941},
#  {'id': 349,
#   'order_id': 8,
#   'product_id': 522,
#   'quantity': 5,
#   'unit_price_cents': 568},
#  {'id': 350,
#   'order_id': 8,
#   'product_id': 523,
#   'quantity': 3,
#   'unit_price_cents': 8235},
#  {'id': 351,
#   'order_id': 8,
#   'product_id': 524,
#   'quantity': 2,
#   'unit_price_cents': 3922},
#  {'id': 352,
#   'order_id': 8,
#   'product_id': 525,
#   'quantity': 1,
#   'unit_price_cents': 3522},
#  {'id': 353,
#   'order_id': 8,
#   'product_id': 526,
#   'quantity': 2,
#   'unit_price_cents': 9819},
#  {'id': 354,
#   'order_id': 8,
#   'product_id': 527,
#   'quantity': 2,
#   'unit_price_cents': 7015},
#  {'id': 355,
#   'order_id': 8,
#   'product_id': 528,
#   'quantity': 2,
#   'unit_price_cents': 7679},
#  {'id': 356,
#   'order_id': 8,
#   'product_id': 529,
#   'quantity': 4,
#   'unit_price_cents': 7893},
#  {'id': 357,
#   'order_id': 8,
#   'product_id': 530,
#   'quantity': 3,
#   'unit_price_cents': 4581},
#  {'id': 358,
#   'order_id': 8,
#   'product_id': 531,
#   'quantity': 1,
#   'unit_price_cents': 7328},
#  {'id': 359,
#   'order_id': 8,
#   'product_id': 532,
#   'quantity': 5,
#   'unit_price_cents': 5687},
#  {'id': 360,
#   'order_id': 8,
#   'product_id': 533,
#   'quantity': 2,
#   'unit_price_cents': 1956},
#  {'id': 361,
#   'order_id': 8,
#   'product_id': 534,
#   'quantity': 4,
#   'unit_price_cents': 4901},
#  {'id': 362,
#   'order_id': 8,
#   'product_id': 535,
#   'quantity': 3,
#   'unit_price_cents': 7428},
#  {'id': 363,
#   'order_id': 8,
#   'product_id': 536,
#   'quantity': 1,
#   'unit_price_cents': 3670},
#  {'id': 364,
#   'order_id': 8,
#   'product_id': 537,
#   'quantity': 2,
#   'unit_price_cents': 7368},
#  {'id': 365,
#   'order_id': 8,
#   'product_id': 538,
#   'quantity': 4,
#   'unit_price_cents': 5575},
#  {'id': 366,
#   'order_id': 8,
#   'product_id': 539,
#   'quantity': 2,
#   'unit_price_cents': 2948},
#  {'id': 367,
#   'order_id': 8,
#   'product_id': 540,
#   'quantity': 2,
#   'unit_price_cents': 8072},
#  {'id': 368,
#   'order_id': 8,
#   'product_id': 541,
#   'quantity': 4,
#   'unit_price_cents': 4570},
#  {'id': 369,
#   'order_id': 8,
#   'product_id': 542,
#   'quantity': 5,
#   'unit_price_cents': 7213},
#  {'id': 370,
#   'order_id': 8,
#   'product_id': 543,
#   'quantity': 3,
#   'unit_price_cents': 4403},
#  {'id': 371,
#   'order_id': 8,
#   'product_id': 544,
#   'quantity': 4,
#   'unit_price_cents': 7480},
#  {'id': 372,
#   'order_id': 8,
#   'product_id': 545,
#   'quantity': 4,
#   'unit_price_cents': 8795},
#  {'id': 373,
#   'order_id': 8,
#   'product_id': 546,
#   'quantity': 2,
#   'unit_price_cents': 5619},
#  {'id': 374,
#   'order_id': 8,
#   'product_id': 547,
#   'quantity': 1,
#   'unit_price_cents': 7987},
#  {'id': 375,
#   'order_id': 8,
#   'product_id': 548,
#   'quantity': 2,
#   'unit_price_cents': 357},
#  {'id': 376,
#   'order_id': 8,
#   'product_id': 549,
#   'quantity': 5,
#   'unit_price_cents': 4460},
#  {'id': 377,
#   'order_id': 8,
#   'product_id': 550,
#   'quantity': 4,
#   'unit_price_cents': 9361},
#  {'id': 378,
#   'order_id': 8,
#   'product_id': 551,
#   'quantity': 2,
#   'unit_price_cents': 9152},
#  {'id': 379,
#   'order_id': 8,
#   'product_id': 552,
#   'quantity': 1,
#   'unit_price_cents': 6722},
#  {'id': 380,
#   'order_id': 8,
#   'product_id': 553,
#   'quantity': 2,
#   'unit_price_cents': 8273},
#  {'id': 381,
#   'order_id': 8,
#   'product_id': 554,
#   'quantity': 3,
#   'unit_price_cents': 7499},
#  {'id': 382,
#   'order_id': 8,
#   'product_id': 555,
#   'quantity': 3,
#   'unit_price_cents': 9606},
#  {'id': 383,
#   'order_id': 8,
#   'product_id': 556,
#   'quantity': 3,
#   'unit_price_cents': 4456},
#  {'id': 384,
#   'order_id': 8,
#   'product_id': 557,
#   'quantity': 1,
#   'unit_price_cents': 2937},
#  {'id': 385,
#   'order_id': 8,
#   'product_id': 558,
#   'quantity': 3,
#   'unit_price_cents': 3879},
#  {'id': 386,
#   'order_id': 8,
#   'product_id': 559,
#   'quantity': 3,
#   'unit_price_cents': 5427},
#  {'id': 387,
#   'order_id': 8,
#   'product_id': 560,
#   'quantity': 3,
#   'unit_price_cents': 4074},
#  {'id': 388,
#   'order_id': 8,
#   'product_id': 561,
#   'quantity': 4,
#   'unit_price_cents': 4266},
#  {'id': 389,
#   'order_id': 8,
#   'product_id': 562,
#   'quantity': 5,
#   'unit_price_cents': 6334},
#  {'id': 390,
#   'order_id': 8,
#   'product_id': 563,
#   'quantity': 5,
#   'unit_price_cents': 4069},
#  {'id': 391,
#   'order_id': 8,
#   'product_id': 564,
#   'quantity': 1,
#   'unit_price_cents': 6934},
#  {'id': 392,
#   'order_id': 8,
#   'product_id': 565,
#   'quantity': 3,
#   'unit_price_cents': 9165},
#  {'id': 393,
#   'order_id': 8,
#   'product_id': 566,
#   'quantity': 2,
#   'unit_price_cents': 6648},
#  {'id': 394,
#   'order_id': 8,
#   'product_id': 567,
#   'quantity': 1,
#   'unit_price_cents': 7586},
#  {'id': 395,
#   'order_id': 8,
#   'product_id': 568,
#   'quantity': 4,
#   'unit_price_cents': 4717},
#  {'id': 396,
#   'order_id': 8,
#   'product_id': 569,
#   'quantity': 1,
#   'unit_price_cents': 2671},
#  {'id': 397,
#   'order_id': 8,
#   'product_id': 570,
#   'quantity': 2,
#   'unit_price_cents': 6177},
#  {'id': 398,
#   'order_id': 8,
#   'product_id': 571,
#   'quantity': 5,
#   'unit_price_cents': 7404},
#  {'id': 399,
#   'order_id': 8,
#   'product_id': 572,
#   'quantity': 4,
#   'unit_price_cents': 4013},
#  {'id': 400,
#   'order_id': 8,
#   'product_id': 573,
#   'quantity': 2,
#   'unit_price_cents': 1259},
#  {'id': 401,
#   'order_id': 8,
#   'product_id': 574,
#   'quantity': 2,
#   'unit_price_cents': 743},
#  {'id': 402,
#   'order_id': 8,
#   'product_id': 575,
#   'quantity': 5,
#   'unit_price_cents': 6762},
#  {'id': 403,
#   'order_id': 8,
#   'product_id': 576,
#   'quantity': 2,
#   'unit_price_cents': 5434},
#  {'id': 404,
#   'order_id': 8,
#   'product_id': 577,
#   'quantity': 2,
#   'unit_price_cents': 3518},
#  {'id': 405,
#   'order_id': 8,
#   'product_id': 578,
#   'quantity': 2,
#   'unit_price_cents': 6954},
#  {'id': 406,
#   'order_id': 8,
#   'product_id': 579,
#   'quantity': 1,
#   'unit_price_cents': 3539},
#  {'id': 407,
#   'order_id': 8,
#   'product_id': 580,
#   'quantity': 5,
#   'unit_price_cents': 5452},
#  {'id': 408,
#   'order_id': 8,
#   'product_id': 581,
#   'quantity': 5,
#   'unit_price_cents': 8218},
#  {'id': 409,
#   'order_id': 8,
#   'product_id': 582,
#   'quantity': 2,
#   'unit_price_cents': 9415},
#  {'id': 410,
#   'order_id': 8,
#   'product_id': 583,
#   'quantity': 3,
#   'unit_price_cents': 9594},
#  {'id': 411,
#   'order_id': 8,
#   'product_id': 584,
#   'quantity': 2,
#   'unit_price_cents': 1391}]

# %% [markdown]
# ## Step 4 - Read the order back, and its items via `/orders/:id/items`

# %%
resp = requests.get(f"{BASE_URL}/orders/{order['id']}")
assert resp.status_code == 200, resp.text
print("Order:", resp.json())

resp = requests.get(f"{BASE_URL}/orders/{order['id']}/items")
assert resp.status_code == 200, resp.text
items = resp.json()
assert len(items) == PRODUCT_COUNT
print(f"Order has {len(items)} items")
items
# Out:
# Order: {'id': 8, 'customer_id': 107, 'status': 'pending', 'created_at': '2026-09-24T09:21:52.798Z'}
# Order has 400 items
# [{'id': 12,
#   'order_id': 8,
#   'product_id': 185,
#   'quantity': 5,
#   'unit_price_cents': 9182},
#  {'id': 13,
#   'order_id': 8,
#   'product_id': 186,
#   'quantity': 4,
#   'unit_price_cents': 2226},
#  {'id': 14,
#   'order_id': 8,
#   'product_id': 187,
#   'quantity': 1,
#   'unit_price_cents': 6577},
#  {'id': 15,
#   'order_id': 8,
#   'product_id': 188,
#   'quantity': 5,
#   'unit_price_cents': 9208},
#  {'id': 16,
#   'order_id': 8,
#   'product_id': 189,
#   'quantity': 2,
#   'unit_price_cents': 1347},
#  {'id': 17,
#   'order_id': 8,
#   'product_id': 190,
#   'quantity': 3,
#   'unit_price_cents': 1931},
#  {'id': 18,
#   'order_id': 8,
#   'product_id': 191,
#   'quantity': 3,
#   'unit_price_cents': 1683},
#  {'id': 19,
#   'order_id': 8,
#   'product_id': 192,
#   'quantity': 3,
#   'unit_price_cents': 7513},
#  {'id': 20,
#   'order_id': 8,
#   'product_id': 193,
#   'quantity': 4,
#   'unit_price_cents': 6653},
#  {'id': 21,
#   'order_id': 8,
#   'product_id': 194,
#   'quantity': 4,
#   'unit_price_cents': 8921},
#  {'id': 22,
#   'order_id': 8,
#   'product_id': 195,
#   'quantity': 1,
#   'unit_price_cents': 5247},
#  {'id': 23,
#   'order_id': 8,
#   'product_id': 196,
#   'quantity': 4,
#   'unit_price_cents': 9442},
#  {'id': 24,
#   'order_id': 8,
#   'product_id': 197,
#   'quantity': 3,
#   'unit_price_cents': 5995},
#  {'id': 25,
#   'order_id': 8,
#   'product_id': 198,
#   'quantity': 3,
#   'unit_price_cents': 5252},
#  {'id': 26,
#   'order_id': 8,
#   'product_id': 199,
#   'quantity': 4,
#   'unit_price_cents': 2349},
#  {'id': 27,
#   'order_id': 8,
#   'product_id': 200,
#   'quantity': 5,
#   'unit_price_cents': 8490},
#  {'id': 28,
#   'order_id': 8,
#   'product_id': 201,
#   'quantity': 4,
#   'unit_price_cents': 8880},
#  {'id': 29,
#   'order_id': 8,
#   'product_id': 202,
#   'quantity': 3,
#   'unit_price_cents': 9323},
#  {'id': 30,
#   'order_id': 8,
#   'product_id': 203,
#   'quantity': 3,
#   'unit_price_cents': 8982},
#  {'id': 31,
#   'order_id': 8,
#   'product_id': 204,
#   'quantity': 1,
#   'unit_price_cents': 3129},
#  {'id': 32,
#   'order_id': 8,
#   'product_id': 205,
#   'quantity': 5,
#   'unit_price_cents': 4384},
#  {'id': 33,
#   'order_id': 8,
#   'product_id': 206,
#   'quantity': 3,
#   'unit_price_cents': 486},
#  {'id': 34,
#   'order_id': 8,
#   'product_id': 207,
#   'quantity': 5,
#   'unit_price_cents': 9706},
#  {'id': 35,
#   'order_id': 8,
#   'product_id': 208,
#   'quantity': 2,
#   'unit_price_cents': 9267},
#  {'id': 36,
#   'order_id': 8,
#   'product_id': 209,
#   'quantity': 1,
#   'unit_price_cents': 5338},
#  {'id': 37,
#   'order_id': 8,
#   'product_id': 210,
#   'quantity': 2,
#   'unit_price_cents': 4993},
#  {'id': 38,
#   'order_id': 8,
#   'product_id': 211,
#   'quantity': 5,
#   'unit_price_cents': 2515},
#  {'id': 39,
#   'order_id': 8,
#   'product_id': 212,
#   'quantity': 2,
#   'unit_price_cents': 9087},
#  {'id': 40,
#   'order_id': 8,
#   'product_id': 213,
#   'quantity': 2,
#   'unit_price_cents': 6886},
#  {'id': 41,
#   'order_id': 8,
#   'product_id': 214,
#   'quantity': 1,
#   'unit_price_cents': 4934},
#  {'id': 42,
#   'order_id': 8,
#   'product_id': 215,
#   'quantity': 3,
#   'unit_price_cents': 2942},
#  {'id': 43,
#   'order_id': 8,
#   'product_id': 216,
#   'quantity': 4,
#   'unit_price_cents': 1790},
#  {'id': 44,
#   'order_id': 8,
#   'product_id': 217,
#   'quantity': 2,
#   'unit_price_cents': 7111},
#  {'id': 45,
#   'order_id': 8,
#   'product_id': 218,
#   'quantity': 1,
#   'unit_price_cents': 2394},
#  {'id': 46,
#   'order_id': 8,
#   'product_id': 219,
#   'quantity': 3,
#   'unit_price_cents': 2697},
#  {'id': 47,
#   'order_id': 8,
#   'product_id': 220,
#   'quantity': 2,
#   'unit_price_cents': 4784},
#  {'id': 48,
#   'order_id': 8,
#   'product_id': 221,
#   'quantity': 4,
#   'unit_price_cents': 6413},
#  {'id': 49,
#   'order_id': 8,
#   'product_id': 222,
#   'quantity': 4,
#   'unit_price_cents': 577},
#  {'id': 50,
#   'order_id': 8,
#   'product_id': 223,
#   'quantity': 2,
#   'unit_price_cents': 4189},
#  {'id': 51,
#   'order_id': 8,
#   'product_id': 224,
#   'quantity': 4,
#   'unit_price_cents': 9994},
#  {'id': 52,
#   'order_id': 8,
#   'product_id': 225,
#   'quantity': 2,
#   'unit_price_cents': 8767},
#  {'id': 53,
#   'order_id': 8,
#   'product_id': 226,
#   'quantity': 4,
#   'unit_price_cents': 7920},
#  {'id': 54,
#   'order_id': 8,
#   'product_id': 227,
#   'quantity': 1,
#   'unit_price_cents': 1229},
#  {'id': 55,
#   'order_id': 8,
#   'product_id': 228,
#   'quantity': 1,
#   'unit_price_cents': 2407},
#  {'id': 56,
#   'order_id': 8,
#   'product_id': 229,
#   'quantity': 2,
#   'unit_price_cents': 455},
#  {'id': 57,
#   'order_id': 8,
#   'product_id': 230,
#   'quantity': 1,
#   'unit_price_cents': 6269},
#  {'id': 58,
#   'order_id': 8,
#   'product_id': 231,
#   'quantity': 2,
#   'unit_price_cents': 8772},
#  {'id': 59,
#   'order_id': 8,
#   'product_id': 232,
#   'quantity': 2,
#   'unit_price_cents': 2899},
#  {'id': 60,
#   'order_id': 8,
#   'product_id': 233,
#   'quantity': 2,
#   'unit_price_cents': 8420},
#  {'id': 61,
#   'order_id': 8,
#   'product_id': 234,
#   'quantity': 3,
#   'unit_price_cents': 3893},
#  {'id': 62,
#   'order_id': 8,
#   'product_id': 235,
#   'quantity': 4,
#   'unit_price_cents': 7385},
#  {'id': 63,
#   'order_id': 8,
#   'product_id': 236,
#   'quantity': 3,
#   'unit_price_cents': 8608},
#  {'id': 64,
#   'order_id': 8,
#   'product_id': 237,
#   'quantity': 4,
#   'unit_price_cents': 617},
#  {'id': 65,
#   'order_id': 8,
#   'product_id': 238,
#   'quantity': 1,
#   'unit_price_cents': 2582},
#  {'id': 66,
#   'order_id': 8,
#   'product_id': 239,
#   'quantity': 3,
#   'unit_price_cents': 3911},
#  {'id': 67,
#   'order_id': 8,
#   'product_id': 240,
#   'quantity': 5,
#   'unit_price_cents': 3403},
#  {'id': 68,
#   'order_id': 8,
#   'product_id': 241,
#   'quantity': 2,
#   'unit_price_cents': 2831},
#  {'id': 69,
#   'order_id': 8,
#   'product_id': 242,
#   'quantity': 2,
#   'unit_price_cents': 8965},
#  {'id': 70,
#   'order_id': 8,
#   'product_id': 243,
#   'quantity': 2,
#   'unit_price_cents': 8251},
#  {'id': 71,
#   'order_id': 8,
#   'product_id': 244,
#   'quantity': 4,
#   'unit_price_cents': 5211},
#  {'id': 72,
#   'order_id': 8,
#   'product_id': 245,
#   'quantity': 5,
#   'unit_price_cents': 2744},
#  {'id': 73,
#   'order_id': 8,
#   'product_id': 246,
#   'quantity': 4,
#   'unit_price_cents': 2704},
#  {'id': 74,
#   'order_id': 8,
#   'product_id': 247,
#   'quantity': 1,
#   'unit_price_cents': 1444},
#  {'id': 75,
#   'order_id': 8,
#   'product_id': 248,
#   'quantity': 4,
#   'unit_price_cents': 1306},
#  {'id': 76,
#   'order_id': 8,
#   'product_id': 249,
#   'quantity': 4,
#   'unit_price_cents': 1428},
#  {'id': 77,
#   'order_id': 8,
#   'product_id': 250,
#   'quantity': 5,
#   'unit_price_cents': 4983},
#  {'id': 78,
#   'order_id': 8,
#   'product_id': 251,
#   'quantity': 4,
#   'unit_price_cents': 4416},
#  {'id': 79,
#   'order_id': 8,
#   'product_id': 252,
#   'quantity': 1,
#   'unit_price_cents': 7789},
#  {'id': 80,
#   'order_id': 8,
#   'product_id': 253,
#   'quantity': 2,
#   'unit_price_cents': 309},
#  {'id': 81,
#   'order_id': 8,
#   'product_id': 254,
#   'quantity': 5,
#   'unit_price_cents': 1344},
#  {'id': 82,
#   'order_id': 8,
#   'product_id': 255,
#   'quantity': 4,
#   'unit_price_cents': 6621},
#  {'id': 83,
#   'order_id': 8,
#   'product_id': 256,
#   'quantity': 5,
#   'unit_price_cents': 9792},
#  {'id': 84,
#   'order_id': 8,
#   'product_id': 257,
#   'quantity': 1,
#   'unit_price_cents': 865},
#  {'id': 85,
#   'order_id': 8,
#   'product_id': 258,
#   'quantity': 1,
#   'unit_price_cents': 4018},
#  {'id': 86,
#   'order_id': 8,
#   'product_id': 259,
#   'quantity': 1,
#   'unit_price_cents': 9177},
#  {'id': 87,
#   'order_id': 8,
#   'product_id': 260,
#   'quantity': 4,
#   'unit_price_cents': 4958},
#  {'id': 88,
#   'order_id': 8,
#   'product_id': 261,
#   'quantity': 4,
#   'unit_price_cents': 7177},
#  {'id': 89,
#   'order_id': 8,
#   'product_id': 262,
#   'quantity': 3,
#   'unit_price_cents': 3937},
#  {'id': 90,
#   'order_id': 8,
#   'product_id': 263,
#   'quantity': 3,
#   'unit_price_cents': 2353},
#  {'id': 91,
#   'order_id': 8,
#   'product_id': 264,
#   'quantity': 3,
#   'unit_price_cents': 614},
#  {'id': 92,
#   'order_id': 8,
#   'product_id': 265,
#   'quantity': 3,
#   'unit_price_cents': 6166},
#  {'id': 93,
#   'order_id': 8,
#   'product_id': 266,
#   'quantity': 4,
#   'unit_price_cents': 7844},
#  {'id': 94,
#   'order_id': 8,
#   'product_id': 267,
#   'quantity': 1,
#   'unit_price_cents': 2916},
#  {'id': 95,
#   'order_id': 8,
#   'product_id': 268,
#   'quantity': 3,
#   'unit_price_cents': 8728},
#  {'id': 96,
#   'order_id': 8,
#   'product_id': 269,
#   'quantity': 5,
#   'unit_price_cents': 4003},
#  {'id': 97,
#   'order_id': 8,
#   'product_id': 270,
#   'quantity': 5,
#   'unit_price_cents': 4846},
#  {'id': 98,
#   'order_id': 8,
#   'product_id': 271,
#   'quantity': 3,
#   'unit_price_cents': 5329},
#  {'id': 99,
#   'order_id': 8,
#   'product_id': 272,
#   'quantity': 4,
#   'unit_price_cents': 4699},
#  {'id': 100,
#   'order_id': 8,
#   'product_id': 273,
#   'quantity': 1,
#   'unit_price_cents': 4094},
#  {'id': 101,
#   'order_id': 8,
#   'product_id': 274,
#   'quantity': 2,
#   'unit_price_cents': 4686},
#  {'id': 102,
#   'order_id': 8,
#   'product_id': 275,
#   'quantity': 4,
#   'unit_price_cents': 8823},
#  {'id': 103,
#   'order_id': 8,
#   'product_id': 276,
#   'quantity': 5,
#   'unit_price_cents': 586},
#  {'id': 104,
#   'order_id': 8,
#   'product_id': 277,
#   'quantity': 1,
#   'unit_price_cents': 3692},
#  {'id': 105,
#   'order_id': 8,
#   'product_id': 278,
#   'quantity': 4,
#   'unit_price_cents': 6094},
#  {'id': 106,
#   'order_id': 8,
#   'product_id': 279,
#   'quantity': 3,
#   'unit_price_cents': 8004},
#  {'id': 107,
#   'order_id': 8,
#   'product_id': 280,
#   'quantity': 3,
#   'unit_price_cents': 7531},
#  {'id': 108,
#   'order_id': 8,
#   'product_id': 281,
#   'quantity': 5,
#   'unit_price_cents': 788},
#  {'id': 109,
#   'order_id': 8,
#   'product_id': 282,
#   'quantity': 4,
#   'unit_price_cents': 5977},
#  {'id': 110,
#   'order_id': 8,
#   'product_id': 283,
#   'quantity': 1,
#   'unit_price_cents': 6815},
#  {'id': 111,
#   'order_id': 8,
#   'product_id': 284,
#   'quantity': 2,
#   'unit_price_cents': 7387},
#  {'id': 112,
#   'order_id': 8,
#   'product_id': 285,
#   'quantity': 2,
#   'unit_price_cents': 6634},
#  {'id': 113,
#   'order_id': 8,
#   'product_id': 286,
#   'quantity': 5,
#   'unit_price_cents': 4719},
#  {'id': 114,
#   'order_id': 8,
#   'product_id': 287,
#   'quantity': 2,
#   'unit_price_cents': 3933},
#  {'id': 115,
#   'order_id': 8,
#   'product_id': 288,
#   'quantity': 5,
#   'unit_price_cents': 327},
#  {'id': 116,
#   'order_id': 8,
#   'product_id': 289,
#   'quantity': 5,
#   'unit_price_cents': 454},
#  {'id': 117,
#   'order_id': 8,
#   'product_id': 290,
#   'quantity': 1,
#   'unit_price_cents': 776},
#  {'id': 118,
#   'order_id': 8,
#   'product_id': 291,
#   'quantity': 2,
#   'unit_price_cents': 5496},
#  {'id': 119,
#   'order_id': 8,
#   'product_id': 292,
#   'quantity': 5,
#   'unit_price_cents': 8620},
#  {'id': 120,
#   'order_id': 8,
#   'product_id': 293,
#   'quantity': 5,
#   'unit_price_cents': 1167},
#  {'id': 121,
#   'order_id': 8,
#   'product_id': 294,
#   'quantity': 1,
#   'unit_price_cents': 1097},
#  {'id': 122,
#   'order_id': 8,
#   'product_id': 295,
#   'quantity': 3,
#   'unit_price_cents': 1299},
#  {'id': 123,
#   'order_id': 8,
#   'product_id': 296,
#   'quantity': 3,
#   'unit_price_cents': 4084},
#  {'id': 124,
#   'order_id': 8,
#   'product_id': 297,
#   'quantity': 1,
#   'unit_price_cents': 8746},
#  {'id': 125,
#   'order_id': 8,
#   'product_id': 298,
#   'quantity': 1,
#   'unit_price_cents': 3774},
#  {'id': 126,
#   'order_id': 8,
#   'product_id': 299,
#   'quantity': 3,
#   'unit_price_cents': 6894},
#  {'id': 127,
#   'order_id': 8,
#   'product_id': 300,
#   'quantity': 3,
#   'unit_price_cents': 7325},
#  {'id': 128,
#   'order_id': 8,
#   'product_id': 301,
#   'quantity': 2,
#   'unit_price_cents': 2692},
#  {'id': 129,
#   'order_id': 8,
#   'product_id': 302,
#   'quantity': 5,
#   'unit_price_cents': 1456},
#  {'id': 130,
#   'order_id': 8,
#   'product_id': 303,
#   'quantity': 2,
#   'unit_price_cents': 5313},
#  {'id': 131,
#   'order_id': 8,
#   'product_id': 304,
#   'quantity': 5,
#   'unit_price_cents': 9424},
#  {'id': 132,
#   'order_id': 8,
#   'product_id': 305,
#   'quantity': 1,
#   'unit_price_cents': 3987},
#  {'id': 133,
#   'order_id': 8,
#   'product_id': 306,
#   'quantity': 2,
#   'unit_price_cents': 5258},
#  {'id': 134,
#   'order_id': 8,
#   'product_id': 307,
#   'quantity': 4,
#   'unit_price_cents': 301},
#  {'id': 135,
#   'order_id': 8,
#   'product_id': 308,
#   'quantity': 5,
#   'unit_price_cents': 7520},
#  {'id': 136,
#   'order_id': 8,
#   'product_id': 309,
#   'quantity': 1,
#   'unit_price_cents': 2387},
#  {'id': 137,
#   'order_id': 8,
#   'product_id': 310,
#   'quantity': 5,
#   'unit_price_cents': 7097},
#  {'id': 138,
#   'order_id': 8,
#   'product_id': 311,
#   'quantity': 2,
#   'unit_price_cents': 8163},
#  {'id': 139,
#   'order_id': 8,
#   'product_id': 312,
#   'quantity': 3,
#   'unit_price_cents': 1989},
#  {'id': 140,
#   'order_id': 8,
#   'product_id': 313,
#   'quantity': 3,
#   'unit_price_cents': 6999},
#  {'id': 141,
#   'order_id': 8,
#   'product_id': 314,
#   'quantity': 2,
#   'unit_price_cents': 853},
#  {'id': 142,
#   'order_id': 8,
#   'product_id': 315,
#   'quantity': 3,
#   'unit_price_cents': 3248},
#  {'id': 143,
#   'order_id': 8,
#   'product_id': 316,
#   'quantity': 5,
#   'unit_price_cents': 3206},
#  {'id': 144,
#   'order_id': 8,
#   'product_id': 317,
#   'quantity': 2,
#   'unit_price_cents': 3414},
#  {'id': 145,
#   'order_id': 8,
#   'product_id': 318,
#   'quantity': 2,
#   'unit_price_cents': 8530},
#  {'id': 146,
#   'order_id': 8,
#   'product_id': 319,
#   'quantity': 1,
#   'unit_price_cents': 3396},
#  {'id': 147,
#   'order_id': 8,
#   'product_id': 320,
#   'quantity': 1,
#   'unit_price_cents': 8255},
#  {'id': 148,
#   'order_id': 8,
#   'product_id': 321,
#   'quantity': 3,
#   'unit_price_cents': 6150},
#  {'id': 149,
#   'order_id': 8,
#   'product_id': 322,
#   'quantity': 2,
#   'unit_price_cents': 2779},
#  {'id': 150,
#   'order_id': 8,
#   'product_id': 323,
#   'quantity': 2,
#   'unit_price_cents': 4754},
#  {'id': 151,
#   'order_id': 8,
#   'product_id': 324,
#   'quantity': 3,
#   'unit_price_cents': 9341},
#  {'id': 152,
#   'order_id': 8,
#   'product_id': 325,
#   'quantity': 5,
#   'unit_price_cents': 3755},
#  {'id': 153,
#   'order_id': 8,
#   'product_id': 326,
#   'quantity': 3,
#   'unit_price_cents': 2774},
#  {'id': 154,
#   'order_id': 8,
#   'product_id': 327,
#   'quantity': 2,
#   'unit_price_cents': 8916},
#  {'id': 155,
#   'order_id': 8,
#   'product_id': 328,
#   'quantity': 5,
#   'unit_price_cents': 3815},
#  {'id': 156,
#   'order_id': 8,
#   'product_id': 329,
#   'quantity': 1,
#   'unit_price_cents': 1220},
#  {'id': 157,
#   'order_id': 8,
#   'product_id': 330,
#   'quantity': 4,
#   'unit_price_cents': 6237},
#  {'id': 158,
#   'order_id': 8,
#   'product_id': 331,
#   'quantity': 2,
#   'unit_price_cents': 1832},
#  {'id': 159,
#   'order_id': 8,
#   'product_id': 332,
#   'quantity': 5,
#   'unit_price_cents': 9564},
#  {'id': 160,
#   'order_id': 8,
#   'product_id': 333,
#   'quantity': 1,
#   'unit_price_cents': 2381},
#  {'id': 161,
#   'order_id': 8,
#   'product_id': 334,
#   'quantity': 4,
#   'unit_price_cents': 8143},
#  {'id': 162,
#   'order_id': 8,
#   'product_id': 335,
#   'quantity': 4,
#   'unit_price_cents': 7453},
#  {'id': 163,
#   'order_id': 8,
#   'product_id': 336,
#   'quantity': 5,
#   'unit_price_cents': 8772},
#  {'id': 164,
#   'order_id': 8,
#   'product_id': 337,
#   'quantity': 2,
#   'unit_price_cents': 6892},
#  {'id': 165,
#   'order_id': 8,
#   'product_id': 338,
#   'quantity': 2,
#   'unit_price_cents': 7961},
#  {'id': 166,
#   'order_id': 8,
#   'product_id': 339,
#   'quantity': 4,
#   'unit_price_cents': 827},
#  {'id': 167,
#   'order_id': 8,
#   'product_id': 340,
#   'quantity': 1,
#   'unit_price_cents': 3130},
#  {'id': 168,
#   'order_id': 8,
#   'product_id': 341,
#   'quantity': 2,
#   'unit_price_cents': 8287},
#  {'id': 169,
#   'order_id': 8,
#   'product_id': 342,
#   'quantity': 4,
#   'unit_price_cents': 9835},
#  {'id': 170,
#   'order_id': 8,
#   'product_id': 343,
#   'quantity': 3,
#   'unit_price_cents': 8004},
#  {'id': 171,
#   'order_id': 8,
#   'product_id': 344,
#   'quantity': 5,
#   'unit_price_cents': 1784},
#  {'id': 172,
#   'order_id': 8,
#   'product_id': 345,
#   'quantity': 2,
#   'unit_price_cents': 3107},
#  {'id': 173,
#   'order_id': 8,
#   'product_id': 346,
#   'quantity': 4,
#   'unit_price_cents': 5473},
#  {'id': 174,
#   'order_id': 8,
#   'product_id': 347,
#   'quantity': 1,
#   'unit_price_cents': 6257},
#  {'id': 175,
#   'order_id': 8,
#   'product_id': 348,
#   'quantity': 5,
#   'unit_price_cents': 7931},
#  {'id': 176,
#   'order_id': 8,
#   'product_id': 349,
#   'quantity': 2,
#   'unit_price_cents': 322},
#  {'id': 177,
#   'order_id': 8,
#   'product_id': 350,
#   'quantity': 1,
#   'unit_price_cents': 8910},
#  {'id': 178,
#   'order_id': 8,
#   'product_id': 351,
#   'quantity': 1,
#   'unit_price_cents': 718},
#  {'id': 179,
#   'order_id': 8,
#   'product_id': 352,
#   'quantity': 4,
#   'unit_price_cents': 8800},
#  {'id': 180,
#   'order_id': 8,
#   'product_id': 353,
#   'quantity': 3,
#   'unit_price_cents': 8361},
#  {'id': 181,
#   'order_id': 8,
#   'product_id': 354,
#   'quantity': 4,
#   'unit_price_cents': 5627},
#  {'id': 182,
#   'order_id': 8,
#   'product_id': 355,
#   'quantity': 4,
#   'unit_price_cents': 9979},
#  {'id': 183,
#   'order_id': 8,
#   'product_id': 356,
#   'quantity': 4,
#   'unit_price_cents': 7796},
#  {'id': 184,
#   'order_id': 8,
#   'product_id': 357,
#   'quantity': 3,
#   'unit_price_cents': 3609},
#  {'id': 185,
#   'order_id': 8,
#   'product_id': 358,
#   'quantity': 1,
#   'unit_price_cents': 3567},
#  {'id': 186,
#   'order_id': 8,
#   'product_id': 359,
#   'quantity': 3,
#   'unit_price_cents': 2570},
#  {'id': 187,
#   'order_id': 8,
#   'product_id': 360,
#   'quantity': 4,
#   'unit_price_cents': 1063},
#  {'id': 188,
#   'order_id': 8,
#   'product_id': 361,
#   'quantity': 2,
#   'unit_price_cents': 8328},
#  {'id': 189,
#   'order_id': 8,
#   'product_id': 362,
#   'quantity': 3,
#   'unit_price_cents': 6470},
#  {'id': 190,
#   'order_id': 8,
#   'product_id': 363,
#   'quantity': 5,
#   'unit_price_cents': 1584},
#  {'id': 191,
#   'order_id': 8,
#   'product_id': 364,
#   'quantity': 3,
#   'unit_price_cents': 9599},
#  {'id': 192,
#   'order_id': 8,
#   'product_id': 365,
#   'quantity': 5,
#   'unit_price_cents': 4635},
#  {'id': 193,
#   'order_id': 8,
#   'product_id': 366,
#   'quantity': 3,
#   'unit_price_cents': 1659},
#  {'id': 194,
#   'order_id': 8,
#   'product_id': 367,
#   'quantity': 2,
#   'unit_price_cents': 8485},
#  {'id': 195,
#   'order_id': 8,
#   'product_id': 368,
#   'quantity': 4,
#   'unit_price_cents': 1934},
#  {'id': 196,
#   'order_id': 8,
#   'product_id': 369,
#   'quantity': 5,
#   'unit_price_cents': 2061},
#  {'id': 197,
#   'order_id': 8,
#   'product_id': 370,
#   'quantity': 1,
#   'unit_price_cents': 3776},
#  {'id': 198,
#   'order_id': 8,
#   'product_id': 371,
#   'quantity': 3,
#   'unit_price_cents': 2244},
#  {'id': 199,
#   'order_id': 8,
#   'product_id': 372,
#   'quantity': 2,
#   'unit_price_cents': 1991},
#  {'id': 200,
#   'order_id': 8,
#   'product_id': 373,
#   'quantity': 5,
#   'unit_price_cents': 9513},
#  {'id': 201,
#   'order_id': 8,
#   'product_id': 374,
#   'quantity': 4,
#   'unit_price_cents': 835},
#  {'id': 202,
#   'order_id': 8,
#   'product_id': 375,
#   'quantity': 2,
#   'unit_price_cents': 7415},
#  {'id': 203,
#   'order_id': 8,
#   'product_id': 376,
#   'quantity': 4,
#   'unit_price_cents': 5838},
#  {'id': 204,
#   'order_id': 8,
#   'product_id': 377,
#   'quantity': 1,
#   'unit_price_cents': 4654},
#  {'id': 205,
#   'order_id': 8,
#   'product_id': 378,
#   'quantity': 1,
#   'unit_price_cents': 9945},
#  {'id': 206,
#   'order_id': 8,
#   'product_id': 379,
#   'quantity': 2,
#   'unit_price_cents': 5162},
#  {'id': 207,
#   'order_id': 8,
#   'product_id': 380,
#   'quantity': 2,
#   'unit_price_cents': 1163},
#  {'id': 208,
#   'order_id': 8,
#   'product_id': 381,
#   'quantity': 4,
#   'unit_price_cents': 3753},
#  {'id': 209,
#   'order_id': 8,
#   'product_id': 382,
#   'quantity': 1,
#   'unit_price_cents': 7419},
#  {'id': 210,
#   'order_id': 8,
#   'product_id': 383,
#   'quantity': 4,
#   'unit_price_cents': 379},
#  {'id': 211,
#   'order_id': 8,
#   'product_id': 384,
#   'quantity': 5,
#   'unit_price_cents': 5361},
#  {'id': 212,
#   'order_id': 8,
#   'product_id': 385,
#   'quantity': 4,
#   'unit_price_cents': 3912},
#  {'id': 213,
#   'order_id': 8,
#   'product_id': 386,
#   'quantity': 5,
#   'unit_price_cents': 8483},
#  {'id': 214,
#   'order_id': 8,
#   'product_id': 387,
#   'quantity': 1,
#   'unit_price_cents': 4699},
#  {'id': 215,
#   'order_id': 8,
#   'product_id': 388,
#   'quantity': 5,
#   'unit_price_cents': 8239},
#  {'id': 216,
#   'order_id': 8,
#   'product_id': 389,
#   'quantity': 2,
#   'unit_price_cents': 4499},
#  {'id': 217,
#   'order_id': 8,
#   'product_id': 390,
#   'quantity': 5,
#   'unit_price_cents': 5514},
#  {'id': 218,
#   'order_id': 8,
#   'product_id': 391,
#   'quantity': 1,
#   'unit_price_cents': 1707},
#  {'id': 219,
#   'order_id': 8,
#   'product_id': 392,
#   'quantity': 3,
#   'unit_price_cents': 3002},
#  {'id': 220,
#   'order_id': 8,
#   'product_id': 393,
#   'quantity': 5,
#   'unit_price_cents': 8742},
#  {'id': 221,
#   'order_id': 8,
#   'product_id': 394,
#   'quantity': 2,
#   'unit_price_cents': 6090},
#  {'id': 222,
#   'order_id': 8,
#   'product_id': 395,
#   'quantity': 1,
#   'unit_price_cents': 6294},
#  {'id': 223,
#   'order_id': 8,
#   'product_id': 396,
#   'quantity': 2,
#   'unit_price_cents': 2407},
#  {'id': 224,
#   'order_id': 8,
#   'product_id': 397,
#   'quantity': 4,
#   'unit_price_cents': 2433},
#  {'id': 225,
#   'order_id': 8,
#   'product_id': 398,
#   'quantity': 2,
#   'unit_price_cents': 7698},
#  {'id': 226,
#   'order_id': 8,
#   'product_id': 399,
#   'quantity': 1,
#   'unit_price_cents': 4316},
#  {'id': 227,
#   'order_id': 8,
#   'product_id': 400,
#   'quantity': 2,
#   'unit_price_cents': 7197},
#  {'id': 228,
#   'order_id': 8,
#   'product_id': 401,
#   'quantity': 3,
#   'unit_price_cents': 6038},
#  {'id': 229,
#   'order_id': 8,
#   'product_id': 402,
#   'quantity': 3,
#   'unit_price_cents': 6387},
#  {'id': 230,
#   'order_id': 8,
#   'product_id': 403,
#   'quantity': 4,
#   'unit_price_cents': 6753},
#  {'id': 231,
#   'order_id': 8,
#   'product_id': 404,
#   'quantity': 3,
#   'unit_price_cents': 9027},
#  {'id': 232,
#   'order_id': 8,
#   'product_id': 405,
#   'quantity': 1,
#   'unit_price_cents': 8192},
#  {'id': 233,
#   'order_id': 8,
#   'product_id': 406,
#   'quantity': 3,
#   'unit_price_cents': 9780},
#  {'id': 234,
#   'order_id': 8,
#   'product_id': 407,
#   'quantity': 2,
#   'unit_price_cents': 3985},
#  {'id': 235,
#   'order_id': 8,
#   'product_id': 408,
#   'quantity': 5,
#   'unit_price_cents': 5476},
#  {'id': 236,
#   'order_id': 8,
#   'product_id': 409,
#   'quantity': 5,
#   'unit_price_cents': 3583},
#  {'id': 237,
#   'order_id': 8,
#   'product_id': 410,
#   'quantity': 4,
#   'unit_price_cents': 1275},
#  {'id': 238,
#   'order_id': 8,
#   'product_id': 411,
#   'quantity': 5,
#   'unit_price_cents': 8496},
#  {'id': 239,
#   'order_id': 8,
#   'product_id': 412,
#   'quantity': 1,
#   'unit_price_cents': 9574},
#  {'id': 240,
#   'order_id': 8,
#   'product_id': 413,
#   'quantity': 1,
#   'unit_price_cents': 2958},
#  {'id': 241,
#   'order_id': 8,
#   'product_id': 414,
#   'quantity': 3,
#   'unit_price_cents': 2498},
#  {'id': 242,
#   'order_id': 8,
#   'product_id': 415,
#   'quantity': 2,
#   'unit_price_cents': 9165},
#  {'id': 243,
#   'order_id': 8,
#   'product_id': 416,
#   'quantity': 1,
#   'unit_price_cents': 6067},
#  {'id': 244,
#   'order_id': 8,
#   'product_id': 417,
#   'quantity': 1,
#   'unit_price_cents': 8402},
#  {'id': 245,
#   'order_id': 8,
#   'product_id': 418,
#   'quantity': 4,
#   'unit_price_cents': 5690},
#  {'id': 246,
#   'order_id': 8,
#   'product_id': 419,
#   'quantity': 2,
#   'unit_price_cents': 8043},
#  {'id': 247,
#   'order_id': 8,
#   'product_id': 420,
#   'quantity': 2,
#   'unit_price_cents': 1798},
#  {'id': 248,
#   'order_id': 8,
#   'product_id': 421,
#   'quantity': 2,
#   'unit_price_cents': 5288},
#  {'id': 249,
#   'order_id': 8,
#   'product_id': 422,
#   'quantity': 5,
#   'unit_price_cents': 784},
#  {'id': 250,
#   'order_id': 8,
#   'product_id': 423,
#   'quantity': 1,
#   'unit_price_cents': 9298},
#  {'id': 251,
#   'order_id': 8,
#   'product_id': 424,
#   'quantity': 1,
#   'unit_price_cents': 9842},
#  {'id': 252,
#   'order_id': 8,
#   'product_id': 425,
#   'quantity': 2,
#   'unit_price_cents': 7430},
#  {'id': 253,
#   'order_id': 8,
#   'product_id': 426,
#   'quantity': 5,
#   'unit_price_cents': 9607},
#  {'id': 254,
#   'order_id': 8,
#   'product_id': 427,
#   'quantity': 3,
#   'unit_price_cents': 3521},
#  {'id': 255,
#   'order_id': 8,
#   'product_id': 428,
#   'quantity': 2,
#   'unit_price_cents': 6461},
#  {'id': 256,
#   'order_id': 8,
#   'product_id': 429,
#   'quantity': 5,
#   'unit_price_cents': 2364},
#  {'id': 257,
#   'order_id': 8,
#   'product_id': 430,
#   'quantity': 1,
#   'unit_price_cents': 6789},
#  {'id': 258,
#   'order_id': 8,
#   'product_id': 431,
#   'quantity': 3,
#   'unit_price_cents': 5536},
#  {'id': 259,
#   'order_id': 8,
#   'product_id': 432,
#   'quantity': 5,
#   'unit_price_cents': 7664},
#  {'id': 260,
#   'order_id': 8,
#   'product_id': 433,
#   'quantity': 3,
#   'unit_price_cents': 292},
#  {'id': 261,
#   'order_id': 8,
#   'product_id': 434,
#   'quantity': 4,
#   'unit_price_cents': 2181},
#  {'id': 262,
#   'order_id': 8,
#   'product_id': 435,
#   'quantity': 5,
#   'unit_price_cents': 2260},
#  {'id': 263,
#   'order_id': 8,
#   'product_id': 436,
#   'quantity': 3,
#   'unit_price_cents': 619},
#  {'id': 264,
#   'order_id': 8,
#   'product_id': 437,
#   'quantity': 4,
#   'unit_price_cents': 3243},
#  {'id': 265,
#   'order_id': 8,
#   'product_id': 438,
#   'quantity': 5,
#   'unit_price_cents': 9948},
#  {'id': 266,
#   'order_id': 8,
#   'product_id': 439,
#   'quantity': 4,
#   'unit_price_cents': 666},
#  {'id': 267,
#   'order_id': 8,
#   'product_id': 440,
#   'quantity': 2,
#   'unit_price_cents': 5079},
#  {'id': 268,
#   'order_id': 8,
#   'product_id': 441,
#   'quantity': 3,
#   'unit_price_cents': 1595},
#  {'id': 269,
#   'order_id': 8,
#   'product_id': 442,
#   'quantity': 5,
#   'unit_price_cents': 7056},
#  {'id': 270,
#   'order_id': 8,
#   'product_id': 443,
#   'quantity': 2,
#   'unit_price_cents': 2526},
#  {'id': 271,
#   'order_id': 8,
#   'product_id': 444,
#   'quantity': 5,
#   'unit_price_cents': 5536},
#  {'id': 272,
#   'order_id': 8,
#   'product_id': 445,
#   'quantity': 5,
#   'unit_price_cents': 6314},
#  {'id': 273,
#   'order_id': 8,
#   'product_id': 446,
#   'quantity': 1,
#   'unit_price_cents': 9628},
#  {'id': 274,
#   'order_id': 8,
#   'product_id': 447,
#   'quantity': 5,
#   'unit_price_cents': 5605},
#  {'id': 275,
#   'order_id': 8,
#   'product_id': 448,
#   'quantity': 1,
#   'unit_price_cents': 4542},
#  {'id': 276,
#   'order_id': 8,
#   'product_id': 449,
#   'quantity': 5,
#   'unit_price_cents': 4711},
#  {'id': 277,
#   'order_id': 8,
#   'product_id': 450,
#   'quantity': 5,
#   'unit_price_cents': 7378},
#  {'id': 278,
#   'order_id': 8,
#   'product_id': 451,
#   'quantity': 4,
#   'unit_price_cents': 3530},
#  {'id': 279,
#   'order_id': 8,
#   'product_id': 452,
#   'quantity': 4,
#   'unit_price_cents': 1583},
#  {'id': 280,
#   'order_id': 8,
#   'product_id': 453,
#   'quantity': 4,
#   'unit_price_cents': 3724},
#  {'id': 281,
#   'order_id': 8,
#   'product_id': 454,
#   'quantity': 2,
#   'unit_price_cents': 4915},
#  {'id': 282,
#   'order_id': 8,
#   'product_id': 455,
#   'quantity': 2,
#   'unit_price_cents': 8294},
#  {'id': 283,
#   'order_id': 8,
#   'product_id': 456,
#   'quantity': 2,
#   'unit_price_cents': 9473},
#  {'id': 284,
#   'order_id': 8,
#   'product_id': 457,
#   'quantity': 3,
#   'unit_price_cents': 6296},
#  {'id': 285,
#   'order_id': 8,
#   'product_id': 458,
#   'quantity': 5,
#   'unit_price_cents': 314},
#  {'id': 286,
#   'order_id': 8,
#   'product_id': 459,
#   'quantity': 1,
#   'unit_price_cents': 8193},
#  {'id': 287,
#   'order_id': 8,
#   'product_id': 460,
#   'quantity': 5,
#   'unit_price_cents': 9858},
#  {'id': 288,
#   'order_id': 8,
#   'product_id': 461,
#   'quantity': 4,
#   'unit_price_cents': 4154},
#  {'id': 289,
#   'order_id': 8,
#   'product_id': 462,
#   'quantity': 1,
#   'unit_price_cents': 5248},
#  {'id': 290,
#   'order_id': 8,
#   'product_id': 463,
#   'quantity': 1,
#   'unit_price_cents': 9541},
#  {'id': 291,
#   'order_id': 8,
#   'product_id': 464,
#   'quantity': 4,
#   'unit_price_cents': 2621},
#  {'id': 292,
#   'order_id': 8,
#   'product_id': 465,
#   'quantity': 2,
#   'unit_price_cents': 3798},
#  {'id': 293,
#   'order_id': 8,
#   'product_id': 466,
#   'quantity': 3,
#   'unit_price_cents': 8704},
#  {'id': 294,
#   'order_id': 8,
#   'product_id': 467,
#   'quantity': 1,
#   'unit_price_cents': 1985},
#  {'id': 295,
#   'order_id': 8,
#   'product_id': 468,
#   'quantity': 3,
#   'unit_price_cents': 4316},
#  {'id': 296,
#   'order_id': 8,
#   'product_id': 469,
#   'quantity': 5,
#   'unit_price_cents': 4587},
#  {'id': 297,
#   'order_id': 8,
#   'product_id': 470,
#   'quantity': 4,
#   'unit_price_cents': 4651},
#  {'id': 298,
#   'order_id': 8,
#   'product_id': 471,
#   'quantity': 5,
#   'unit_price_cents': 6489},
#  {'id': 299,
#   'order_id': 8,
#   'product_id': 472,
#   'quantity': 1,
#   'unit_price_cents': 3804},
#  {'id': 300,
#   'order_id': 8,
#   'product_id': 473,
#   'quantity': 3,
#   'unit_price_cents': 2497},
#  {'id': 301,
#   'order_id': 8,
#   'product_id': 474,
#   'quantity': 5,
#   'unit_price_cents': 7082},
#  {'id': 302,
#   'order_id': 8,
#   'product_id': 475,
#   'quantity': 2,
#   'unit_price_cents': 2411},
#  {'id': 303,
#   'order_id': 8,
#   'product_id': 476,
#   'quantity': 4,
#   'unit_price_cents': 1488},
#  {'id': 304,
#   'order_id': 8,
#   'product_id': 477,
#   'quantity': 2,
#   'unit_price_cents': 2991},
#  {'id': 305,
#   'order_id': 8,
#   'product_id': 478,
#   'quantity': 4,
#   'unit_price_cents': 7686},
#  {'id': 306,
#   'order_id': 8,
#   'product_id': 479,
#   'quantity': 3,
#   'unit_price_cents': 9505},
#  {'id': 307,
#   'order_id': 8,
#   'product_id': 480,
#   'quantity': 3,
#   'unit_price_cents': 9722},
#  {'id': 308,
#   'order_id': 8,
#   'product_id': 481,
#   'quantity': 3,
#   'unit_price_cents': 5017},
#  {'id': 309,
#   'order_id': 8,
#   'product_id': 482,
#   'quantity': 4,
#   'unit_price_cents': 4815},
#  {'id': 310,
#   'order_id': 8,
#   'product_id': 483,
#   'quantity': 3,
#   'unit_price_cents': 1512},
#  {'id': 311,
#   'order_id': 8,
#   'product_id': 484,
#   'quantity': 5,
#   'unit_price_cents': 7242},
#  {'id': 312,
#   'order_id': 8,
#   'product_id': 485,
#   'quantity': 2,
#   'unit_price_cents': 8498},
#  {'id': 313,
#   'order_id': 8,
#   'product_id': 486,
#   'quantity': 5,
#   'unit_price_cents': 2083},
#  {'id': 314,
#   'order_id': 8,
#   'product_id': 487,
#   'quantity': 2,
#   'unit_price_cents': 4624},
#  {'id': 315,
#   'order_id': 8,
#   'product_id': 488,
#   'quantity': 3,
#   'unit_price_cents': 6055},
#  {'id': 316,
#   'order_id': 8,
#   'product_id': 489,
#   'quantity': 4,
#   'unit_price_cents': 4643},
#  {'id': 317,
#   'order_id': 8,
#   'product_id': 490,
#   'quantity': 3,
#   'unit_price_cents': 1437},
#  {'id': 318,
#   'order_id': 8,
#   'product_id': 491,
#   'quantity': 2,
#   'unit_price_cents': 1478},
#  {'id': 319,
#   'order_id': 8,
#   'product_id': 492,
#   'quantity': 4,
#   'unit_price_cents': 1389},
#  {'id': 320,
#   'order_id': 8,
#   'product_id': 493,
#   'quantity': 3,
#   'unit_price_cents': 9451},
#  {'id': 321,
#   'order_id': 8,
#   'product_id': 494,
#   'quantity': 3,
#   'unit_price_cents': 3908},
#  {'id': 322,
#   'order_id': 8,
#   'product_id': 495,
#   'quantity': 4,
#   'unit_price_cents': 9666},
#  {'id': 323,
#   'order_id': 8,
#   'product_id': 496,
#   'quantity': 2,
#   'unit_price_cents': 1223},
#  {'id': 324,
#   'order_id': 8,
#   'product_id': 497,
#   'quantity': 5,
#   'unit_price_cents': 6207},
#  {'id': 325,
#   'order_id': 8,
#   'product_id': 498,
#   'quantity': 3,
#   'unit_price_cents': 2290},
#  {'id': 326,
#   'order_id': 8,
#   'product_id': 499,
#   'quantity': 4,
#   'unit_price_cents': 3158},
#  {'id': 327,
#   'order_id': 8,
#   'product_id': 500,
#   'quantity': 2,
#   'unit_price_cents': 6961},
#  {'id': 328,
#   'order_id': 8,
#   'product_id': 501,
#   'quantity': 3,
#   'unit_price_cents': 7641},
#  {'id': 329,
#   'order_id': 8,
#   'product_id': 502,
#   'quantity': 4,
#   'unit_price_cents': 2773},
#  {'id': 330,
#   'order_id': 8,
#   'product_id': 503,
#   'quantity': 2,
#   'unit_price_cents': 5908},
#  {'id': 331,
#   'order_id': 8,
#   'product_id': 504,
#   'quantity': 2,
#   'unit_price_cents': 9536},
#  {'id': 332,
#   'order_id': 8,
#   'product_id': 505,
#   'quantity': 4,
#   'unit_price_cents': 8433},
#  {'id': 333,
#   'order_id': 8,
#   'product_id': 506,
#   'quantity': 3,
#   'unit_price_cents': 7211},
#  {'id': 334,
#   'order_id': 8,
#   'product_id': 507,
#   'quantity': 1,
#   'unit_price_cents': 5410},
#  {'id': 335,
#   'order_id': 8,
#   'product_id': 508,
#   'quantity': 3,
#   'unit_price_cents': 219},
#  {'id': 336,
#   'order_id': 8,
#   'product_id': 509,
#   'quantity': 2,
#   'unit_price_cents': 4960},
#  {'id': 337,
#   'order_id': 8,
#   'product_id': 510,
#   'quantity': 1,
#   'unit_price_cents': 1948},
#  {'id': 338,
#   'order_id': 8,
#   'product_id': 511,
#   'quantity': 2,
#   'unit_price_cents': 6821},
#  {'id': 339,
#   'order_id': 8,
#   'product_id': 512,
#   'quantity': 5,
#   'unit_price_cents': 6216},
#  {'id': 340,
#   'order_id': 8,
#   'product_id': 513,
#   'quantity': 3,
#   'unit_price_cents': 9720},
#  {'id': 341,
#   'order_id': 8,
#   'product_id': 514,
#   'quantity': 1,
#   'unit_price_cents': 8332},
#  {'id': 342,
#   'order_id': 8,
#   'product_id': 515,
#   'quantity': 1,
#   'unit_price_cents': 6485},
#  {'id': 343,
#   'order_id': 8,
#   'product_id': 516,
#   'quantity': 2,
#   'unit_price_cents': 7005},
#  {'id': 344,
#   'order_id': 8,
#   'product_id': 517,
#   'quantity': 3,
#   'unit_price_cents': 9169},
#  {'id': 345,
#   'order_id': 8,
#   'product_id': 518,
#   'quantity': 4,
#   'unit_price_cents': 1845},
#  {'id': 346,
#   'order_id': 8,
#   'product_id': 519,
#   'quantity': 1,
#   'unit_price_cents': 504},
#  {'id': 347,
#   'order_id': 8,
#   'product_id': 520,
#   'quantity': 1,
#   'unit_price_cents': 5346},
#  {'id': 348,
#   'order_id': 8,
#   'product_id': 521,
#   'quantity': 1,
#   'unit_price_cents': 941},
#  {'id': 349,
#   'order_id': 8,
#   'product_id': 522,
#   'quantity': 5,
#   'unit_price_cents': 568},
#  {'id': 350,
#   'order_id': 8,
#   'product_id': 523,
#   'quantity': 3,
#   'unit_price_cents': 8235},
#  {'id': 351,
#   'order_id': 8,
#   'product_id': 524,
#   'quantity': 2,
#   'unit_price_cents': 3922},
#  {'id': 352,
#   'order_id': 8,
#   'product_id': 525,
#   'quantity': 1,
#   'unit_price_cents': 3522},
#  {'id': 353,
#   'order_id': 8,
#   'product_id': 526,
#   'quantity': 2,
#   'unit_price_cents': 9819},
#  {'id': 354,
#   'order_id': 8,
#   'product_id': 527,
#   'quantity': 2,
#   'unit_price_cents': 7015},
#  {'id': 355,
#   'order_id': 8,
#   'product_id': 528,
#   'quantity': 2,
#   'unit_price_cents': 7679},
#  {'id': 356,
#   'order_id': 8,
#   'product_id': 529,
#   'quantity': 4,
#   'unit_price_cents': 7893},
#  {'id': 357,
#   'order_id': 8,
#   'product_id': 530,
#   'quantity': 3,
#   'unit_price_cents': 4581},
#  {'id': 358,
#   'order_id': 8,
#   'product_id': 531,
#   'quantity': 1,
#   'unit_price_cents': 7328},
#  {'id': 359,
#   'order_id': 8,
#   'product_id': 532,
#   'quantity': 5,
#   'unit_price_cents': 5687},
#  {'id': 360,
#   'order_id': 8,
#   'product_id': 533,
#   'quantity': 2,
#   'unit_price_cents': 1956},
#  {'id': 361,
#   'order_id': 8,
#   'product_id': 534,
#   'quantity': 4,
#   'unit_price_cents': 4901},
#  {'id': 362,
#   'order_id': 8,
#   'product_id': 535,
#   'quantity': 3,
#   'unit_price_cents': 7428},
#  {'id': 363,
#   'order_id': 8,
#   'product_id': 536,
#   'quantity': 1,
#   'unit_price_cents': 3670},
#  {'id': 364,
#   'order_id': 8,
#   'product_id': 537,
#   'quantity': 2,
#   'unit_price_cents': 7368},
#  {'id': 365,
#   'order_id': 8,
#   'product_id': 538,
#   'quantity': 4,
#   'unit_price_cents': 5575},
#  {'id': 366,
#   'order_id': 8,
#   'product_id': 539,
#   'quantity': 2,
#   'unit_price_cents': 2948},
#  {'id': 367,
#   'order_id': 8,
#   'product_id': 540,
#   'quantity': 2,
#   'unit_price_cents': 8072},
#  {'id': 368,
#   'order_id': 8,
#   'product_id': 541,
#   'quantity': 4,
#   'unit_price_cents': 4570},
#  {'id': 369,
#   'order_id': 8,
#   'product_id': 542,
#   'quantity': 5,
#   'unit_price_cents': 7213},
#  {'id': 370,
#   'order_id': 8,
#   'product_id': 543,
#   'quantity': 3,
#   'unit_price_cents': 4403},
#  {'id': 371,
#   'order_id': 8,
#   'product_id': 544,
#   'quantity': 4,
#   'unit_price_cents': 7480},
#  {'id': 372,
#   'order_id': 8,
#   'product_id': 545,
#   'quantity': 4,
#   'unit_price_cents': 8795},
#  {'id': 373,
#   'order_id': 8,
#   'product_id': 546,
#   'quantity': 2,
#   'unit_price_cents': 5619},
#  {'id': 374,
#   'order_id': 8,
#   'product_id': 547,
#   'quantity': 1,
#   'unit_price_cents': 7987},
#  {'id': 375,
#   'order_id': 8,
#   'product_id': 548,
#   'quantity': 2,
#   'unit_price_cents': 357},
#  {'id': 376,
#   'order_id': 8,
#   'product_id': 549,
#   'quantity': 5,
#   'unit_price_cents': 4460},
#  {'id': 377,
#   'order_id': 8,
#   'product_id': 550,
#   'quantity': 4,
#   'unit_price_cents': 9361},
#  {'id': 378,
#   'order_id': 8,
#   'product_id': 551,
#   'quantity': 2,
#   'unit_price_cents': 9152},
#  {'id': 379,
#   'order_id': 8,
#   'product_id': 552,
#   'quantity': 1,
#   'unit_price_cents': 6722},
#  {'id': 380,
#   'order_id': 8,
#   'product_id': 553,
#   'quantity': 2,
#   'unit_price_cents': 8273},
#  {'id': 381,
#   'order_id': 8,
#   'product_id': 554,
#   'quantity': 3,
#   'unit_price_cents': 7499},
#  {'id': 382,
#   'order_id': 8,
#   'product_id': 555,
#   'quantity': 3,
#   'unit_price_cents': 9606},
#  {'id': 383,
#   'order_id': 8,
#   'product_id': 556,
#   'quantity': 3,
#   'unit_price_cents': 4456},
#  {'id': 384,
#   'order_id': 8,
#   'product_id': 557,
#   'quantity': 1,
#   'unit_price_cents': 2937},
#  {'id': 385,
#   'order_id': 8,
#   'product_id': 558,
#   'quantity': 3,
#   'unit_price_cents': 3879},
#  {'id': 386,
#   'order_id': 8,
#   'product_id': 559,
#   'quantity': 3,
#   'unit_price_cents': 5427},
#  {'id': 387,
#   'order_id': 8,
#   'product_id': 560,
#   'quantity': 3,
#   'unit_price_cents': 4074},
#  {'id': 388,
#   'order_id': 8,
#   'product_id': 561,
#   'quantity': 4,
#   'unit_price_cents': 4266},
#  {'id': 389,
#   'order_id': 8,
#   'product_id': 562,
#   'quantity': 5,
#   'unit_price_cents': 6334},
#  {'id': 390,
#   'order_id': 8,
#   'product_id': 563,
#   'quantity': 5,
#   'unit_price_cents': 4069},
#  {'id': 391,
#   'order_id': 8,
#   'product_id': 564,
#   'quantity': 1,
#   'unit_price_cents': 6934},
#  {'id': 392,
#   'order_id': 8,
#   'product_id': 565,
#   'quantity': 3,
#   'unit_price_cents': 9165},
#  {'id': 393,
#   'order_id': 8,
#   'product_id': 566,
#   'quantity': 2,
#   'unit_price_cents': 6648},
#  {'id': 394,
#   'order_id': 8,
#   'product_id': 567,
#   'quantity': 1,
#   'unit_price_cents': 7586},
#  {'id': 395,
#   'order_id': 8,
#   'product_id': 568,
#   'quantity': 4,
#   'unit_price_cents': 4717},
#  {'id': 396,
#   'order_id': 8,
#   'product_id': 569,
#   'quantity': 1,
#   'unit_price_cents': 2671},
#  {'id': 397,
#   'order_id': 8,
#   'product_id': 570,
#   'quantity': 2,
#   'unit_price_cents': 6177},
#  {'id': 398,
#   'order_id': 8,
#   'product_id': 571,
#   'quantity': 5,
#   'unit_price_cents': 7404},
#  {'id': 399,
#   'order_id': 8,
#   'product_id': 572,
#   'quantity': 4,
#   'unit_price_cents': 4013},
#  {'id': 400,
#   'order_id': 8,
#   'product_id': 573,
#   'quantity': 2,
#   'unit_price_cents': 1259},
#  {'id': 401,
#   'order_id': 8,
#   'product_id': 574,
#   'quantity': 2,
#   'unit_price_cents': 743},
#  {'id': 402,
#   'order_id': 8,
#   'product_id': 575,
#   'quantity': 5,
#   'unit_price_cents': 6762},
#  {'id': 403,
#   'order_id': 8,
#   'product_id': 576,
#   'quantity': 2,
#   'unit_price_cents': 5434},
#  {'id': 404,
#   'order_id': 8,
#   'product_id': 577,
#   'quantity': 2,
#   'unit_price_cents': 3518},
#  {'id': 405,
#   'order_id': 8,
#   'product_id': 578,
#   'quantity': 2,
#   'unit_price_cents': 6954},
#  {'id': 406,
#   'order_id': 8,
#   'product_id': 579,
#   'quantity': 1,
#   'unit_price_cents': 3539},
#  {'id': 407,
#   'order_id': 8,
#   'product_id': 580,
#   'quantity': 5,
#   'unit_price_cents': 5452},
#  {'id': 408,
#   'order_id': 8,
#   'product_id': 581,
#   'quantity': 5,
#   'unit_price_cents': 8218},
#  {'id': 409,
#   'order_id': 8,
#   'product_id': 582,
#   'quantity': 2,
#   'unit_price_cents': 9415},
#  {'id': 410,
#   'order_id': 8,
#   'product_id': 583,
#   'quantity': 3,
#   'unit_price_cents': 9594},
#  {'id': 411,
#   'order_id': 8,
#   'product_id': 584,
#   'quantity': 2,
#   'unit_price_cents': 1391}]

# %% [markdown]
# ## Step 5 - Check `/orders/pending-totals` includes this order with the right total

# %%
resp = requests.get(f"{BASE_URL}/orders/pending-totals")
assert resp.status_code == 200, resp.text
pending_totals = resp.json()
mine = next((row for row in pending_totals if row["order_id"] == order["id"]), None)
assert mine is not None, "order missing from pending-totals"
assert int(mine["total_cents"]) == expected_total_cents, (
    f"total mismatch: expected {expected_total_cents}, got {mine['total_cents']}"
)
print("Pending total row for this order:", mine)
# Out:
# Pending total row for this order: {'order_id': 8, 'email': 'hmurphy@example.org', 'status': 'pending', 'total_cents': '6220457'}

# %% [markdown]
# ## Step 6 - Customer's order list shows this order

# %%
resp = requests.get(f"{BASE_URL}/customers/{customer['id']}/orders")
assert resp.status_code == 200, resp.text
customer_orders = resp.json()
assert any(o["id"] == order["id"] for o in customer_orders)
print("Customer orders:", customer_orders)
# Out:
# Customer orders: [{'id': 8, 'customer_id': 107, 'status': 'pending', 'created_at': '2026-09-24T09:21:52.798Z'}]

# %% [markdown]
# ## Step 7 - Warehouse ships the order (`pending -> shipped`)

# %%
resp = requests.patch(f"{BASE_URL}/orders/{order['id']}", json={"status": "shipped"})
assert resp.status_code == 200, resp.text
order = resp.json()
assert order["status"] == "shipped"
print("Order after shipping:", order)
# Out:
# Order after shipping: {'id': 8, 'customer_id': 107, 'status': 'shipped', 'created_at': '2026-09-24T09:21:52.798Z'}

# %% [markdown]
# ## Step 8 - Order is delivered (`shipped -> delivered`)

# %%
resp = requests.patch(f"{BASE_URL}/orders/{order['id']}", json={"status": "delivered"})
assert resp.status_code == 200, resp.text
order = resp.json()
assert order["status"] == "delivered"
print("Order after delivery:", order)
# Out:
# Order after delivery: {'id': 8, 'customer_id': 107, 'status': 'delivered', 'created_at': '2026-09-24T09:21:52.798Z'}

# %% [markdown]
# ## Step 9 - `/orders/pending-totals` no longer includes this order

# %%
resp = requests.get(f"{BASE_URL}/orders/pending-totals")
assert resp.status_code == 200, resp.text
pending_totals = resp.json()
assert all(row["order_id"] != order["id"] for row in pending_totals), (
    "delivered order should not appear in pending-totals"
)
print("Confirmed delivered order is excluded from pending-totals")
print(f"Checkout flow complete for customer {customer['id']}, order {order['id']}")
# Out:
# Confirmed delivered order is excluded from pending-totals
# Checkout flow complete for customer 107, order 8
