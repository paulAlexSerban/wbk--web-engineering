# %%
import os
import requests

BASE_URL = "http://api-service:5000/api"
API_ENDPOINT = f"{BASE_URL}"

# %%
# GET root
requests.get(f"{BASE_URL}/hello")  # Get all posts
# Out:
# <Response [200]>

# %%
# POST root
requests.post(f"{BASE_URL}/hello", {"name": "Node.js w. Express"})  # Create a post
# Out:
# <Response [200]>

# %%
# PUT root
requests.put(f"{BASE_URL}/hello/1", {"name": "Node.js w. Express"})  # Update a post
# Out:
# <Response [200]>

# %%
# PATCH root
requests.patch(f"{BASE_URL}/hello/1", {"name": "Node.js w. Express"})  # Update a post
# Out:
# <Response [200]>

# %%
# DELETE root
requests.delete(f"{BASE_URL}/hello/1")  # Delete a post
# Out:
# <Response [200]>

# %%
# Customers
requests.get(f"{BASE_URL}/customers").json()
# Out:
# [{'id': 1,
#   'email': 'alice@example.com',
#   'created_at': '2026-09-23T09:54:39.422Z'},
#  {'id': 2,
#   'email': 'bob@example.com',
#   'created_at': '2026-09-23T09:54:39.422Z'},
#  {'id': 3,
#   'email': 'carol@example.com',
#   'created_at': '2026-09-23T09:54:39.422Z'},
#  {'id': 5,
#   'email': 'courtneyrodriguez@example.org',
#   'created_at': '2026-09-23T11:27:07.626Z'},
#  {'id': 6,
#   'email': 'robert91@example.com',
#   'created_at': '2026-09-23T11:27:07.714Z'},
#  {'id': 7,
#   'email': 'michael11@example.net',
#   'created_at': '2026-09-23T11:27:07.796Z'},
#  {'id': 8,
#   'email': 'qjordan@example.org',
#   'created_at': '2026-09-23T11:27:07.888Z'},
#  {'id': 9,
#   'email': 'lcurtis@example.org',
#   'created_at': '2026-09-23T11:27:07.972Z'},
#  {'id': 10,
#   'email': 'ccarter@example.org',
#   'created_at': '2026-09-23T11:27:08.055Z'},
#  {'id': 11,
#   'email': 'gloriamiller@example.com',
#   'created_at': '2026-09-23T11:27:08.148Z'},
#  {'id': 12,
# ...

# %%
# Products catalog
requests.get(f"{BASE_URL}/products").json()

# %%
# Customers and their orders
requests.get(f"{BASE_URL}/customers").json()
requests.get(f"{BASE_URL}/customers/1/orders").json()

# %%
# Orders with pending totals and line items
requests.get(f"{BASE_URL}/orders").json()
requests.get(f"{BASE_URL}/orders/pending-totals").json()
requests.get(f"{BASE_URL}/orders/1/items").json()

# %%
# Order items
requests.get(f"{BASE_URL}/order-items").json()
